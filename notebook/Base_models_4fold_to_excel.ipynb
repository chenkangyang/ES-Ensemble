# %%
import os
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append("..") 
from gcforest.gcforest import GCForest

import xlwt
# Out:
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# # 数据及参数

# %%
random_seed = 42
cv=4
score = 'f1_weighted'

# %%
def get_toy_config():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
path = os.getcwd()+'/../data/20122018freshwater_four_feature.csv'
data = pd.read_csv(path, na_values = np.nan)

# %%
X = data.drop(['本周水质'], axis=1).values # Series
y = data['本周水质'].values.reshape(-1,1) - 1

# 1. 中位数填充缺失值，2.Z-score标准化
clean_pipeline = Pipeline([('imputer', preprocessing.Imputer(missing_values='NaN',strategy="median")),
                           ('std_scaler', preprocessing.StandardScaler())])
X = clean_pipeline.fit_transform(X)

# %%
X.shape
# Out:
# (33612, 4)

# %% [markdown]
# # k折交叉验证

# %%
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1


def kftrain(X, y, model, cv):
    model_name = model.__class__.__name__

    n_samples = X.shape[0]
    n_features = X.shape[1]
    n_class = np.unique(y).shape[0]

    Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    cv_F1_weighted = np.zeros(cv) # 5次 test data 的F1_weighted
    _cv_F1_weighted = np.zeros(cv) # 5次 train data 的F1_weighted
    cv_Acc = np.zeros(cv) # 5次test data的Acc
    _cv_Acc = np.zeros(cv) # 5次train data的Acc
    # 各类别的Support，每个类别的support由5次fold后得到的5个support求平均得到，这里support：各类别样本占总样本的比列
    # 各类别的F1，由5次fold后得到的5个F1求平均得到
    # 所以，Weighted F1 等于“5次fold得到的5个 Weighted F1 求平均得到” ——等价于—— “6个support*6个F1”得到
    Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后test data各类别的support
    _Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后train data各类别的support
    
    # 各类别的Mean，SD
    Acc_mean_class = np.zeros(6)
    _Acc_mean_class = np.zeros(6)
    Acc_SD_class = np.zeros(6)
    _Acc_SD_class = np.zeros(6)
    F1_mean_class = np.zeros(6)
    _F1_mean_class = np.zeros(6)
    F1_SD_class = np.zeros(6)
    _F1_SD_class = np.zeros(6)
    
    k = 0
    skf = StratifiedKFold(n_splits=cv) # 定义5折分层划分器
    
    for train_index, test_index in skf.split(X, y):
        K_train_x, K_test_x = X[train_index], X[test_index]
        K_train_y, K_test_y = y[train_index], y[test_index]
        if model_name == 'GCForest':
            model.fit_transform(K_train_x, K_train_y.reshape(K_train_y.shape[0]))
        else:
            model.fit(K_train_x, K_train_y)
    
        K_test_y_pred = model.predict(K_test_x)
        K_train_y_pred = model.predict(K_train_x)
        
        # 由混淆矩阵计算各类别的Acc
        test_cm = confusion_matrix(K_test_y, K_test_y_pred)
        train_cm = confusion_matrix(K_train_y, K_train_y_pred)
        test_acc_all_class = np.zeros(n_class) # 6个类别上的测试acc
        train_acc_all_class = np.zeros(n_class) # 6个类别上的训练acc
        
        i = 0
        for c in test_cm:
            test_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        Acc_matrix[:,k] = test_acc_all_class
        
        i = 0
        for c in train_cm:
            train_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        _Acc_matrix[:,k] = train_acc_all_class
        
        # 由classification_report提取各类别的F1
        cr = classification_report(K_test_y, K_test_y_pred, digits=4)
        _cr = classification_report(K_train_y, K_train_y_pred, digits=4)
        test_f1_all_class = np.zeros(n_class) # test data 6个类别上的测试f1
        train_f1_all_class = np.zeros(n_class) # train data 6个类别上的训练f1
        support_all_class = np.zeros(n_class) # test data 6个类别的support
        _support_all_class = np.zeros(n_class) # train data 6个类别的support
        
        i = 0
        for l in range(2,8):
            test_f1_all_class[i] = float(cr.splitlines()[l].split()[3])
            train_f1_all_class[i] = float(_cr.splitlines()[l].split()[3])
            support_all_class[i] = float(cr.splitlines()[l].split()[4])/(n_samples/cv)
            _support_all_class[i] = float(_cr.splitlines()[l].split()[4])/(n_samples*(1-1/cv))
            i = i + 1
        F1_matrix[:,k] = test_f1_all_class
        _F1_matrix[:,k] = train_f1_all_class
        Support_matrix[:,k] = support_all_class
        _Support_matrix[:,k] = _support_all_class
        
        # cv_F1_weighted[k] = float(cr.splitlines()[9].split()[5]) # 第k折时的Weighted F1
        cv_F1_weighted[k] = f1_score(K_test_y, K_test_y_pred, average="weighted")
        _cv_F1_weighted[k] = f1_score(K_train_y, K_train_y_pred, average="weighted")
        cv_Acc[k] = accuracy_score(K_test_y, K_test_y_pred)
        _cv_Acc[k] = accuracy_score(K_train_y, K_train_y_pred)
        
        k += 1
    
    Acc_mean = np.mean(Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    _Acc_mean = np.mean(_Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    
    F1_mean = np.mean(F1_matrix, axis=1) # 6个类别的k-fold平均F1
    _F1_mean = np.mean(_F1_matrix, axis=1) # 6个类别的k-fold平均F1
    Support_mean = np.mean(Support_matrix, axis=1) # 6个类别的k-fold平均support
    _Support_mean = np.mean(_Support_matrix, axis=1) # 6个类别的k-fold平均support
    
    Acc = np.mean(Acc_mean)
    _Acc = np.mean(_Acc_mean)
    F1_weighted = np.mean(cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    _F1_weighted = np.mean(_cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    SD_Acc = np.std(cv_Acc)
    _SD_Acc = np.std(cv_Acc)
    SD_F1 = np.std(cv_F1_weighted)
    _SD_F1 = np.std(cv_F1_weighted)
    
    Acc_mean_class = np.mean(Acc_matrix, axis=1)
    _Acc_mean_class = np.mean(_Acc_matrix, axis=1)
    Acc_SD_class = np.std(Acc_matrix, axis=1)
    _Acc_SD_class = np.std(_Acc_matrix, axis=1)
    F1_mean_class = np.mean(F1_matrix, axis=1)
    _F1_mean_class = np.mean(_F1_matrix, axis=1)
    F1_SD_class = np.std(F1_matrix, axis=1)
    _F1_SD_class = np.std(_F1_matrix, axis=1)
    
    # return Acc_mean, F1_mean, Support_mean, Acc, F1_weighted, SD_Acc, SD_F1, Acc_mean_class, Acc_SD_class, F1_mean_class, F1_SD_class
    return Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_mean, _Acc_mean, F1_mean, _F1_mean, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class

# %%
config = get_toy_config()

models = [
    LogisticRegression(),
    LinearDiscriminantAnalysis(),
    SVC(probability=True),
    DecisionTreeClassifier(),
    ExtraTreeClassifier(),
    GaussianNB(),
    KNeighborsClassifier(),
    RandomForestClassifier(random_state=random_seed),
    ExtraTreesClassifier(random_state=random_seed),
    GCForest(config)
]

workbook = xlwt.Workbook(encoding = 'utf-8')  

for model in models:
    model_name = model.__class__.__name__
    print(model_name)
    # Acc_class, F1_class, Support_class, Acc, F1_weighted, SD_Acc, SD_F1, Acc_mean_class, Acc_SD_class, F1_mean_class, F1_SD_class = kftrain(X, y, model, 5)
    Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_class, _Acc_class, F1_class, _F1_class, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class = kftrain(X, y, model, cv)

    worksheet = workbook.add_sheet(model_name, cell_overwrite_ok=True)
    worksheet.write(0,0, "train_Acc_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+1, j, _Acc_matrix[i,j])

    worksheet.write(0,6, "test_Acc_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+1, j+7, Acc_matrix[i,j])



    worksheet.write(11,0, "train_F1_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+12, j, _F1_matrix[i,j])

    worksheet.write(11,6, "test_F1_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+12, j+7, F1_matrix[i,j])



    worksheet.write(20,0, "train_support_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+21, j, _Support_matrix[i,j])

    worksheet.write(20,6, "test_support_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+21, j+7, Support_matrix[i,j])
            
workbook.save("../res/basemodels_4flod.xls")
# Out:
# LogisticRegression
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# LinearDiscriminantAnalysis
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# SVC
# DecisionTreeClassifier
# ExtraTreeClassifier
# GaussianNB
# KNeighborsClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# RandomForestClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ExtraTreesClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# [ 2019-05-21 16:33:13,122][cascade_classifier.fit_transform] X_groups_train.shape=[(25207, 4)],y_train.shape=(25207,),X_groups_test.shape=no_test,y_test.shape=no_test
# [ 2019-05-21 16:33:13,124][cascade_classifier.fit_transform] group_dims=[4]
# [ 2019-05-21 16:33:13,125][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-05-21 16:33:13,126][cascade_classifier.fit_transform] group_ends=[4]
# [ 2019-05-21 16:33:13,126][cascade_classifier.fit_transform] X_train.shape=(25207, 4),X_test.shape=(0, 4)
# [ 2019-05-21 16:33:13,129][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(25207, 4), X_cur_test.shape=(0, 4)
# [ 2019-05-21 16:33:13,300][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_0.predict)=99.64%
# GCForest
# [ 2019-05-21 16:33:13,450][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_1.predict)=99.64%
# [ 2019-05-21 16:33:13,596][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_2.predict)=99.56%
# [ 2019-05-21 16:33:13,741][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_3.predict)=99.54%
# [ 2019-05-21 16:33:13,885][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_4.predict)=99.60%
# [ 2019-05-21 16:33:13,892][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_cv.predict)=99.60%
# [ 2019-05-21 16:33:14,053][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_0.predict)=99.68%
# [ 2019-05-21 16:33:14,197][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_1.predict)=99.56%
# [ 2019-05-21 16:33:14,338][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_2.predict)=99.66%
# [ 2019-05-21 16:33:14,492][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_3.predict)=99.64%
# [ 2019-05-21 16:33:14,660][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_4.predict)=99.74%
# [ 2019-05-21 16:33:14,667][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_cv.predict)=99.66%
# [ 2019-05-21 16:33:14,836][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_0.predict)=99.52%
# [ 2019-05-21 16:33:14,982][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_1.predict)=99.70%
# [ 2019-05-21 16:33:15,129][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_2.predict)=99.62%
# [ 2019-05-21 16:33:15,275][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_3.predict)=99.60%
# [ 2019-05-21 16:33:15,427][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_4.predict)=99.72%
# [ 2019-05-21 16:33:15,434][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_cv.predict)=99.63%
# [ 2019-05-21 16:33:15,590][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_0.predict)=99.74%
# [ 2019-05-21 16:33:15,738][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_1.predict)=99.66%
# [ 2019-05-21 16:33:15,880][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_2.predict)=99.60%
# [ 2019-05-21 16:33:16,027][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_3.predict)=99.64%
# [ 2019-05-21 16:33:16,169][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_4.predict)=99.58%
# [ 2019-05-21 16:33:16,175][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_cv.predict)=99.65%
# [ 2019-05-21 16:33:16,223][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-21 16:33:16,258][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_1.predict)=99.27%
# [ 2019-05-21 16:33:16,293][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-21 16:33:16,330][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_3.predict)=99.27%
# [ 2019-05-21 16:33:16,366][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_4.predict)=99.35%
# [ 2019-05-21 16:33:16,372][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-21 16:33:16,420][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-21 16:33:16,456][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_1.predict)=99.42%
# [ 2019-05-21 16:33:16,494][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_2.predict)=99.27%
# [ 2019-05-21 16:33:16,529][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:33:16,565][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_4.predict)=99.44%
# [ 2019-05-21 16:33:16,571][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_cv.predict)=99.38%
# [ 2019-05-21 16:33:16,621][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_0.predict)=99.39%
# [ 2019-05-21 16:33:16,656][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_1.predict)=99.40%
# [ 2019-05-21 16:33:16,691][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_2.predict)=99.54%
# [ 2019-05-21 16:33:16,725][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-21 16:33:16,761][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_4.predict)=99.44%
# [ 2019-05-21 16:33:16,767][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-21 16:33:16,885][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_0.predict)=61.19%
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [ 2019-05-21 16:33:16,993][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_1.predict)=60.86%
# [ 2019-05-21 16:33:17,096][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_2.predict)=61.85%
# [ 2019-05-21 16:33:17,205][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_3.predict)=61.88%
# [ 2019-05-21 16:33:17,314][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_4.predict)=61.90%
# [ 2019-05-21 16:33:17,320][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_cv.predict)=61.53%
# [ 2019-05-21 16:33:17,327][cascade_classifier.calc_f1] Weighted F1 (layer_0 - train.classifier_average)=99.67%
# [ 2019-05-21 16:33:17,337][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(25207, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:33:17,568][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_0.predict)=99.62%
# [ 2019-05-21 16:33:17,779][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_1.predict)=99.70%
# [ 2019-05-21 16:33:18,004][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_2.predict)=99.78%
# [ 2019-05-21 16:33:18,224][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_3.predict)=99.62%
# [ 2019-05-21 16:33:18,443][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_4.predict)=99.78%
# [ 2019-05-21 16:33:18,450][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:33:18,678][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_0.predict)=99.62%
# [ 2019-05-21 16:33:18,882][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_1.predict)=99.80%
# [ 2019-05-21 16:33:19,093][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_2.predict)=99.80%
# [ 2019-05-21 16:33:19,300][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_3.predict)=99.64%
# [ 2019-05-21 16:33:19,498][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:33:19,505][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:33:19,724][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_0.predict)=99.70%
# [ 2019-05-21 16:33:19,916][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_1.predict)=99.68%
# [ 2019-05-21 16:33:20,117][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_2.predict)=99.68%
# [ 2019-05-21 16:33:20,310][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_3.predict)=99.72%
# [ 2019-05-21 16:33:20,525][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-21 16:33:20,541][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:33:20,859][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_0.predict)=99.76%
# [ 2019-05-21 16:33:21,069][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_1.predict)=99.80%
# [ 2019-05-21 16:33:21,283][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_2.predict)=99.74%
# [ 2019-05-21 16:33:21,515][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_3.predict)=99.56%
# [ 2019-05-21 16:33:21,761][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:33:21,768][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:33:21,986][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_0.predict)=99.43%
# [ 2019-05-21 16:33:22,191][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_1.predict)=99.33%
# [ 2019-05-21 16:33:22,410][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_2.predict)=99.36%
# [ 2019-05-21 16:33:22,640][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_3.predict)=99.52%
# [ 2019-05-21 16:33:22,861][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_4.predict)=99.38%
# [ 2019-05-21 16:33:22,868][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_cv.predict)=99.40%
# [ 2019-05-21 16:33:23,097][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_0.predict)=99.23%
# [ 2019-05-21 16:33:23,334][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_1.predict)=99.43%
# [ 2019-05-21 16:33:23,561][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_2.predict)=99.33%
# [ 2019-05-21 16:33:23,769][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_3.predict)=99.48%
# [ 2019-05-21 16:33:24,002][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-21 16:33:24,009][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:33:24,230][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_0.predict)=99.38%
# [ 2019-05-21 16:33:24,457][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_1.predict)=99.33%
# [ 2019-05-21 16:33:24,664][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_2.predict)=99.35%
# [ 2019-05-21 16:33:24,912][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_3.predict)=99.37%
# [ 2019-05-21 16:33:25,136][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_4.predict)=99.56%
# [ 2019-05-21 16:33:25,143][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_cv.predict)=99.40%
# [ 2019-05-21 16:33:25,872][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_0.predict)=99.60%
# [ 2019-05-21 16:33:26,608][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_1.predict)=99.80%
# [ 2019-05-21 16:33:27,320][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_2.predict)=99.66%
# [ 2019-05-21 16:33:28,038][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_3.predict)=99.76%
# [ 2019-05-21 16:33:28,747][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-21 16:33:28,755][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:33:28,764][cascade_classifier.calc_f1] Weighted F1 (layer_1 - train.classifier_average)=99.70%
# [ 2019-05-21 16:33:28,771][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(25207, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:33:28,984][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_0.predict)=99.60%
# [ 2019-05-21 16:33:29,171][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_1.predict)=99.68%
# [ 2019-05-21 16:33:29,364][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_2.predict)=99.72%
# [ 2019-05-21 16:33:29,571][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_3.predict)=99.82%
# [ 2019-05-21 16:33:29,753][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_4.predict)=99.70%
# [ 2019-05-21 16:33:29,761][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:33:29,978][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_0.predict)=99.74%
# [ 2019-05-21 16:33:30,166][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_1.predict)=99.66%
# [ 2019-05-21 16:33:30,365][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_2.predict)=99.70%
# [ 2019-05-21 16:33:30,553][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_3.predict)=99.66%
# [ 2019-05-21 16:33:30,738][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_4.predict)=99.70%
# [ 2019-05-21 16:33:30,744][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:33:30,954][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_0.predict)=99.80%
# [ 2019-05-21 16:33:31,143][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_1.predict)=99.68%
# [ 2019-05-21 16:33:31,339][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_2.predict)=99.64%
# [ 2019-05-21 16:33:31,523][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_3.predict)=99.66%
# [ 2019-05-21 16:33:31,711][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_4.predict)=99.72%
# [ 2019-05-21 16:33:31,718][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:33:31,916][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_0.predict)=99.68%
# [ 2019-05-21 16:33:32,174][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_1.predict)=99.68%
# [ 2019-05-21 16:33:32,392][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_2.predict)=99.62%
# [ 2019-05-21 16:33:32,597][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_3.predict)=99.80%
# [ 2019-05-21 16:33:32,786][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-21 16:33:32,792][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:33:32,984][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_0.predict)=99.45%
# [ 2019-05-21 16:33:33,169][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_1.predict)=99.27%
# [ 2019-05-21 16:33:33,341][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_2.predict)=99.33%
# [ 2019-05-21 16:33:33,518][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_3.predict)=99.46%
# [ 2019-05-21 16:33:33,709][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_4.predict)=99.44%
# [ 2019-05-21 16:33:33,718][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_cv.predict)=99.39%
# [ 2019-05-21 16:33:34,019][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_0.predict)=99.27%
# [ 2019-05-21 16:33:34,218][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_1.predict)=99.44%
# [ 2019-05-21 16:33:34,445][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_2.predict)=99.56%
# [ 2019-05-21 16:33:34,626][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_3.predict)=99.23%
# [ 2019-05-21 16:33:34,809][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_4.predict)=99.30%
# [ 2019-05-21 16:33:34,818][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-21 16:33:35,045][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_0.predict)=99.37%
# [ 2019-05-21 16:33:35,221][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_1.predict)=99.29%
# [ 2019-05-21 16:33:35,409][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_2.predict)=99.42%
# [ 2019-05-21 16:33:35,640][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_3.predict)=99.56%
# [ 2019-05-21 16:33:35,846][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-21 16:33:35,854][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_cv.predict)=99.41%
# [ 2019-05-21 16:33:36,548][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_0.predict)=99.78%
# [ 2019-05-21 16:33:37,274][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_1.predict)=99.70%
# [ 2019-05-21 16:33:37,945][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_2.predict)=99.66%
# [ 2019-05-21 16:33:38,593][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_3.predict)=99.74%
# [ 2019-05-21 16:33:39,235][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_4.predict)=99.64%
# [ 2019-05-21 16:33:39,243][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:33:39,252][cascade_classifier.calc_f1] Weighted F1 (layer_2 - train.classifier_average)=99.72%
# [ 2019-05-21 16:33:39,259][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(25207, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:33:39,493][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_0.predict)=99.84%
# [ 2019-05-21 16:33:39,701][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_1.predict)=99.76%
# [ 2019-05-21 16:33:39,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_2.predict)=99.70%
# [ 2019-05-21 16:33:40,086][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_3.predict)=99.62%
# [ 2019-05-21 16:33:40,276][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_4.predict)=99.58%
# [ 2019-05-21 16:33:40,283][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:33:40,510][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_0.predict)=99.66%
# [ 2019-05-21 16:33:40,704][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_1.predict)=99.74%
# [ 2019-05-21 16:33:40,894][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_2.predict)=99.66%
# [ 2019-05-21 16:33:41,090][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_3.predict)=99.76%
# [ 2019-05-21 16:33:41,303][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:33:41,311][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:33:41,526][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_0.predict)=99.66%
# [ 2019-05-21 16:33:41,726][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_1.predict)=99.74%
# [ 2019-05-21 16:33:41,926][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_2.predict)=99.72%
# [ 2019-05-21 16:33:42,138][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_3.predict)=99.70%
# [ 2019-05-21 16:33:42,348][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-21 16:33:42,354][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:33:42,671][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_0.predict)=99.74%
# [ 2019-05-21 16:33:42,899][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_1.predict)=99.72%
# [ 2019-05-21 16:33:43,119][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_2.predict)=99.72%
# [ 2019-05-21 16:33:43,400][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_3.predict)=99.72%
# [ 2019-05-21 16:33:43,630][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_4.predict)=99.62%
# [ 2019-05-21 16:33:43,640][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:33:43,835][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_0.predict)=99.31%
# [ 2019-05-21 16:33:44,013][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_1.predict)=99.31%
# [ 2019-05-21 16:33:44,210][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_2.predict)=99.40%
# [ 2019-05-21 16:33:44,390][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:33:44,584][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-21 16:33:44,591][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_cv.predict)=99.35%
# [ 2019-05-21 16:33:44,802][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_0.predict)=99.27%
# [ 2019-05-21 16:33:44,973][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_1.predict)=99.37%
# [ 2019-05-21 16:33:45,179][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_2.predict)=99.40%
# [ 2019-05-21 16:33:45,366][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-21 16:33:45,541][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_4.predict)=99.54%
# [ 2019-05-21 16:33:45,548][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_cv.predict)=99.39%
# [ 2019-05-21 16:33:45,765][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_0.predict)=99.29%
# [ 2019-05-21 16:33:45,966][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_1.predict)=99.39%
# [ 2019-05-21 16:33:46,152][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_2.predict)=99.27%
# [ 2019-05-21 16:33:46,338][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_3.predict)=99.39%
# [ 2019-05-21 16:33:46,555][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_4.predict)=99.27%
# [ 2019-05-21 16:33:46,562][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_cv.predict)=99.32%
# [ 2019-05-21 16:33:47,238][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_0.predict)=99.66%
# [ 2019-05-21 16:33:47,940][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_1.predict)=99.72%
# [ 2019-05-21 16:33:48,691][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_2.predict)=99.74%
# [ 2019-05-21 16:33:49,381][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_3.predict)=99.64%
# [ 2019-05-21 16:33:50,038][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_4.predict)=99.78%
# [ 2019-05-21 16:33:50,046][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:33:50,054][cascade_classifier.calc_f1] Weighted F1 (layer_3 - train.classifier_average)=99.70%
# [ 2019-05-21 16:33:50,062][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(25207, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:33:50,291][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_0.predict)=99.86%
# [ 2019-05-21 16:33:50,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_1.predict)=99.68%
# [ 2019-05-21 16:33:50,677][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_2.predict)=99.78%
# [ 2019-05-21 16:33:50,858][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_3.predict)=99.62%
# [ 2019-05-21 16:33:51,045][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_4.predict)=99.58%
# [ 2019-05-21 16:33:51,052][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:33:51,292][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_0.predict)=99.64%
# [ 2019-05-21 16:33:51,525][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_1.predict)=99.62%
# [ 2019-05-21 16:33:51,713][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_2.predict)=99.70%
# [ 2019-05-21 16:33:51,893][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_3.predict)=99.80%
# [ 2019-05-21 16:33:52,078][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:33:52,085][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:33:52,301][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_0.predict)=99.66%
# [ 2019-05-21 16:33:52,500][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_1.predict)=99.78%
# [ 2019-05-21 16:33:52,708][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_2.predict)=99.74%
# [ 2019-05-21 16:33:52,910][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_3.predict)=99.74%
# [ 2019-05-21 16:33:53,099][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_4.predict)=99.56%
# [ 2019-05-21 16:33:53,106][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:33:53,322][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_0.predict)=99.82%
# [ 2019-05-21 16:33:53,521][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_1.predict)=99.74%
# [ 2019-05-21 16:33:53,720][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_2.predict)=99.58%
# [ 2019-05-21 16:33:53,908][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_3.predict)=99.66%
# [ 2019-05-21 16:33:54,103][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:33:54,110][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:33:54,311][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_0.predict)=99.37%
# [ 2019-05-21 16:33:54,482][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_1.predict)=99.33%
# [ 2019-05-21 16:33:54,672][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-21 16:33:54,857][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_3.predict)=99.47%
# [ 2019-05-21 16:33:55,033][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-21 16:33:55,041][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_cv.predict)=99.40%
# [ 2019-05-21 16:33:55,246][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_0.predict)=99.29%
# [ 2019-05-21 16:33:55,422][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_1.predict)=99.27%
# [ 2019-05-21 16:33:55,618][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_2.predict)=99.56%
# [ 2019-05-21 16:33:55,797][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_3.predict)=99.37%
# [ 2019-05-21 16:33:55,982][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_4.predict)=99.39%
# [ 2019-05-21 16:33:55,989][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:33:56,195][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_0.predict)=99.41%
# [ 2019-05-21 16:33:56,391][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_1.predict)=99.60%
# [ 2019-05-21 16:33:56,568][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_2.predict)=99.31%
# [ 2019-05-21 16:33:56,765][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_3.predict)=99.38%
# [ 2019-05-21 16:33:56,962][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_4.predict)=99.17%
# [ 2019-05-21 16:33:56,970][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:33:57,644][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_0.predict)=99.66%
# [ 2019-05-21 16:33:58,346][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_1.predict)=99.86%
# [ 2019-05-21 16:33:59,064][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_2.predict)=99.64%
# [ 2019-05-21 16:33:59,719][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_3.predict)=99.78%
# [ 2019-05-21 16:34:00,384][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_4.predict)=99.58%
# [ 2019-05-21 16:34:00,392][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:34:00,402][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=99.69%
# [ 2019-05-21 16:34:00,409][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(25207, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:34:00,671][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=99.68%
# [ 2019-05-21 16:34:00,885][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=99.66%
# [ 2019-05-21 16:34:01,095][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=99.74%
# [ 2019-05-21 16:34:01,282][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=99.72%
# [ 2019-05-21 16:34:01,537][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:34:01,546][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:34:01,801][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=99.58%
# [ 2019-05-21 16:34:02,014][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=99.72%
# [ 2019-05-21 16:34:02,229][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=99.72%
# [ 2019-05-21 16:34:02,428][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=99.80%
# [ 2019-05-21 16:34:02,647][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=99.64%
# [ 2019-05-21 16:34:02,654][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:34:02,860][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_0.predict)=99.66%
# [ 2019-05-21 16:34:03,077][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_1.predict)=99.68%
# [ 2019-05-21 16:34:03,276][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_2.predict)=99.70%
# [ 2019-05-21 16:34:03,472][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_3.predict)=99.68%
# [ 2019-05-21 16:34:03,667][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_4.predict)=99.74%
# [ 2019-05-21 16:34:03,674][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:34:03,891][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_0.predict)=99.64%
# [ 2019-05-21 16:34:04,094][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_1.predict)=99.68%
# [ 2019-05-21 16:34:04,379][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_2.predict)=99.80%
# [ 2019-05-21 16:34:04,581][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_3.predict)=99.74%
# [ 2019-05-21 16:34:04,794][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-21 16:34:04,801][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_cv.predict)=99.71%
# [ 2019-05-21 16:34:05,006][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_0.predict)=99.31%
# [ 2019-05-21 16:34:05,189][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-21 16:34:05,361][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_2.predict)=99.38%
# [ 2019-05-21 16:34:05,564][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_3.predict)=99.23%
# [ 2019-05-21 16:34:05,747][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_4.predict)=99.58%
# [ 2019-05-21 16:34:05,758][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:34:05,970][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_0.predict)=99.39%
# [ 2019-05-21 16:34:06,229][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_1.predict)=99.15%
# [ 2019-05-21 16:34:06,416][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_2.predict)=99.40%
# [ 2019-05-21 16:34:06,606][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_3.predict)=99.48%
# [ 2019-05-21 16:34:06,786][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_4.predict)=99.46%
# [ 2019-05-21 16:34:06,794][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_cv.predict)=99.38%
# [ 2019-05-21 16:34:06,990][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_0.predict)=99.54%
# [ 2019-05-21 16:34:07,167][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_1.predict)=99.37%
# [ 2019-05-21 16:34:07,347][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=99.41%
# [ 2019-05-21 16:34:07,545][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=99.50%
# [ 2019-05-21 16:34:07,728][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-21 16:34:07,736][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=99.45%
# [ 2019-05-21 16:34:08,399][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.62%
# [ 2019-05-21 16:34:09,125][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.80%
# [ 2019-05-21 16:34:09,803][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.66%
# [ 2019-05-21 16:34:10,542][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.70%
# [ 2019-05-21 16:34:11,230][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.70%
# [ 2019-05-21 16:34:11,238][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:34:11,246][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.70%
# [ 2019-05-21 16:34:11,247][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=3, weighted_f1_train=99.72%, weighted_f1_test=0.00%
# [ 2019-05-21 16:34:11,252][cascade_classifier.transform] X_groups_test.shape=[(8405, 4)]
# [ 2019-05-21 16:34:11,254][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-21 16:34:11,256][cascade_classifier.transform] X_test.shape=(8405, 4)
# [ 2019-05-21 16:34:11,258][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(8405, 4)
# [ 2019-05-21 16:34:11,454][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(8405, 52)
# [ 2019-05-21 16:34:11,677][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(8405, 52)
# [ 2019-05-21 16:34:11,893][cascade_classifier.transform] X_groups_test.shape=[(25207, 4)]
# [ 2019-05-21 16:34:11,895][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-21 16:34:11,896][cascade_classifier.transform] X_test.shape=(25207, 4)
# [ 2019-05-21 16:34:11,898][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(25207, 4)
# [ 2019-05-21 16:34:12,444][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(25207, 52)
# [ 2019-05-21 16:34:13,049][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(25207, 52)
# [ 2019-05-21 16:34:13,723][cascade_classifier.fit_transform] X_groups_train.shape=[(25208, 4)],y_train.shape=(25208,),X_groups_test.shape=no_test,y_test.shape=no_test
# [ 2019-05-21 16:34:13,725][cascade_classifier.fit_transform] group_dims=[4]
# [ 2019-05-21 16:34:13,726][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-05-21 16:34:13,727][cascade_classifier.fit_transform] group_ends=[4]
# [ 2019-05-21 16:34:13,729][cascade_classifier.fit_transform] X_train.shape=(25208, 4),X_test.shape=(0, 4)
# [ 2019-05-21 16:34:13,731][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(25208, 4), X_cur_test.shape=(0, 4)
# [ 2019-05-21 16:34:13,917][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_0.predict)=99.37%
# [ 2019-05-21 16:34:14,075][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_1.predict)=99.01%
# [ 2019-05-21 16:34:14,268][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_2.predict)=99.03%
# [ 2019-05-21 16:34:14,436][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_3.predict)=99.38%
# [ 2019-05-21 16:34:14,629][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_4.predict)=99.25%
# [ 2019-05-21 16:34:14,636][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_cv.predict)=99.21%
# [ 2019-05-21 16:34:14,827][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_0.predict)=99.25%
# [ 2019-05-21 16:34:15,004][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_1.predict)=99.23%
# [ 2019-05-21 16:34:15,178][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_2.predict)=98.97%
# [ 2019-05-21 16:34:15,342][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:34:15,532][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_4.predict)=99.27%
# [ 2019-05-21 16:34:15,539][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_cv.predict)=99.20%
# [ 2019-05-21 16:34:15,718][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_0.predict)=99.29%
# [ 2019-05-21 16:34:15,883][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-21 16:34:16,046][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_2.predict)=99.25%
# [ 2019-05-21 16:34:16,211][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_3.predict)=99.19%
# [ 2019-05-21 16:34:16,372][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_4.predict)=99.17%
# [ 2019-05-21 16:34:16,379][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_cv.predict)=99.25%
# [ 2019-05-21 16:34:16,558][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_0.predict)=99.35%
# [ 2019-05-21 16:34:16,725][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_1.predict)=99.27%
# [ 2019-05-21 16:34:16,902][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_2.predict)=99.11%
# [ 2019-05-21 16:34:17,088][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_3.predict)=99.23%
# [ 2019-05-21 16:34:17,278][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_4.predict)=99.18%
# [ 2019-05-21 16:34:17,286][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_cv.predict)=99.23%
# [ 2019-05-21 16:34:17,350][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_0.predict)=98.41%
# [ 2019-05-21 16:34:17,398][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_1.predict)=98.24%
# [ 2019-05-21 16:34:17,443][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_2.predict)=98.51%
# ...
# [ 2019-05-21 16:37:34,206][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=98.93%
# [ 2019-05-21 16:37:34,443][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=99.01%
# [ 2019-05-21 16:37:34,689][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=99.05%
# [ 2019-05-21 16:37:34,696][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=98.92%
# [ 2019-05-21 16:37:35,329][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.27%
# [ 2019-05-21 16:37:35,953][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.50%
# [ 2019-05-21 16:37:36,574][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.29%
# [ 2019-05-21 16:37:37,201][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.62%
# [ 2019-05-21 16:37:37,839][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-21 16:37:37,846][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-21 16:37:37,853][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.42%
# [ 2019-05-21 16:37:37,859][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(25211, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:37:38,100][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_0.predict)=99.52%
# [ 2019-05-21 16:37:38,313][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_1.predict)=99.45%
# [ 2019-05-21 16:37:38,554][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_2.predict)=99.27%
# [ 2019-05-21 16:37:38,765][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_3.predict)=99.50%
# [ 2019-05-21 16:37:38,994][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_4.predict)=99.36%
# [ 2019-05-21 16:37:39,002][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-21 16:37:39,247][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_0.predict)=99.47%
# [ 2019-05-21 16:37:39,463][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_1.predict)=99.43%
# [ 2019-05-21 16:37:39,680][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_2.predict)=99.48%
# [ 2019-05-21 16:37:39,887][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_3.predict)=99.23%
# [ 2019-05-21 16:37:40,104][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_4.predict)=99.44%
# [ 2019-05-21 16:37:40,110][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_cv.predict)=99.41%
# [ 2019-05-21 16:37:40,334][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_0.predict)=99.39%
# [ 2019-05-21 16:37:40,545][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_1.predict)=99.42%
# [ 2019-05-21 16:37:40,761][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_2.predict)=99.44%
# [ 2019-05-21 16:37:40,974][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_3.predict)=99.29%
# [ 2019-05-21 16:37:41,184][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_4.predict)=99.48%
# [ 2019-05-21 16:37:41,191][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_cv.predict)=99.41%
# [ 2019-05-21 16:37:41,439][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_0.predict)=99.45%
# [ 2019-05-21 16:37:41,667][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_1.predict)=99.46%
# [ 2019-05-21 16:37:41,884][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-21 16:37:42,103][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:37:42,338][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_4.predict)=99.33%
# [ 2019-05-21 16:37:42,354][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_cv.predict)=99.40%
# [ 2019-05-21 16:37:42,603][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_0.predict)=98.89%
# [ 2019-05-21 16:37:42,839][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_1.predict)=98.71%
# [ 2019-05-21 16:37:43,103][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_2.predict)=99.11%
# [ 2019-05-21 16:37:43,331][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_3.predict)=98.59%
# [ 2019-05-21 16:37:43,565][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_4.predict)=98.59%
# [ 2019-05-21 16:37:43,572][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_cv.predict)=98.78%
# [ 2019-05-21 16:37:43,805][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_0.predict)=99.05%
# [ 2019-05-21 16:37:44,037][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_1.predict)=98.67%
# [ 2019-05-21 16:37:44,280][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_2.predict)=98.93%
# [ 2019-05-21 16:37:44,515][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_3.predict)=98.65%
# [ 2019-05-21 16:37:44,740][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_4.predict)=98.83%
# [ 2019-05-21 16:37:44,747][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_cv.predict)=98.83%
# [ 2019-05-21 16:37:44,978][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_0.predict)=98.77%
# [ 2019-05-21 16:37:45,227][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_1.predict)=98.65%
# [ 2019-05-21 16:37:45,496][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_2.predict)=98.93%
# [ 2019-05-21 16:37:45,723][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_3.predict)=98.87%
# [ 2019-05-21 16:37:46,009][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_4.predict)=98.61%
# [ 2019-05-21 16:37:46,020][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_cv.predict)=98.77%
# [ 2019-05-21 16:37:46,765][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-21 16:37:47,373][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_1.predict)=99.29%
# [ 2019-05-21 16:37:48,036][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_2.predict)=99.41%
# [ 2019-05-21 16:37:48,681][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_3.predict)=99.43%
# [ 2019-05-21 16:37:49,349][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_4.predict)=99.50%
# [ 2019-05-21 16:37:49,356][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-21 16:37:49,364][cascade_classifier.calc_f1] Weighted F1 (layer_6 - train.classifier_average)=99.43%
# [ 2019-05-21 16:37:49,370][cascade_classifier.fit_transform] [layer=7] look_indexs=[0], X_cur_train.shape=(25211, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:37:49,604][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_0.predict)=99.35%
# [ 2019-05-21 16:37:49,802][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_1.predict)=99.45%
# [ 2019-05-21 16:37:50,010][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_2.predict)=99.41%
# [ 2019-05-21 16:37:50,213][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_3.predict)=99.37%
# [ 2019-05-21 16:37:50,451][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_4.predict)=99.52%
# [ 2019-05-21 16:37:50,459][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-21 16:37:50,691][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_0.predict)=99.45%
# [ 2019-05-21 16:37:50,911][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_1.predict)=99.48%
# [ 2019-05-21 16:37:51,129][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_2.predict)=99.29%
# [ 2019-05-21 16:37:51,354][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_3.predict)=99.46%
# [ 2019-05-21 16:37:51,593][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-21 16:37:51,600][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-21 16:37:51,845][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_2 - 5_folds.train_0.predict)=99.48%
# [ 2019-05-21 16:37:52,056][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_2 - 5_folds.train_1.predict)=99.39%
# [ 2019-05-21 16:37:52,265][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_2 - 5_folds.train_2.predict)=99.48%
# [ 2019-05-21 16:37:52,488][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_2 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-21 16:37:52,704][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_2 - 5_folds.train_4.predict)=99.41%
# [ 2019-05-21 16:37:52,713][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_2 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-21 16:37:53,031][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_3 - 5_folds.train_0.predict)=99.60%
# [ 2019-05-21 16:37:53,284][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_3 - 5_folds.train_1.predict)=99.41%
# [ 2019-05-21 16:37:53,552][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_3 - 5_folds.train_2.predict)=99.37%
# [ 2019-05-21 16:37:53,872][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_3 - 5_folds.train_3.predict)=99.25%
# [ 2019-05-21 16:37:54,117][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_3 - 5_folds.train_4.predict)=99.48%
# [ 2019-05-21 16:37:54,124][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_3 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-21 16:37:54,415][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_4 - 5_folds.train_0.predict)=98.53%
# [ 2019-05-21 16:37:54,645][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_4 - 5_folds.train_1.predict)=98.73%
# [ 2019-05-21 16:37:54,875][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_4 - 5_folds.train_2.predict)=98.95%
# [ 2019-05-21 16:37:55,092][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_4 - 5_folds.train_3.predict)=98.81%
# [ 2019-05-21 16:37:55,331][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_4 - 5_folds.train_4.predict)=98.57%
# [ 2019-05-21 16:37:55,337][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_4 - 5_folds.train_cv.predict)=98.72%
# [ 2019-05-21 16:37:55,590][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_5 - 5_folds.train_0.predict)=98.53%
# [ 2019-05-21 16:37:55,822][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_5 - 5_folds.train_1.predict)=98.75%
# [ 2019-05-21 16:37:56,042][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_5 - 5_folds.train_2.predict)=98.69%
# [ 2019-05-21 16:37:56,296][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_5 - 5_folds.train_3.predict)=98.73%
# [ 2019-05-21 16:37:56,555][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_5 - 5_folds.train_4.predict)=98.81%
# [ 2019-05-21 16:37:56,564][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_5 - 5_folds.train_cv.predict)=98.70%
# [ 2019-05-21 16:37:56,879][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_6 - 5_folds.train_0.predict)=98.51%
# [ 2019-05-21 16:37:57,132][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_6 - 5_folds.train_1.predict)=98.73%
# [ 2019-05-21 16:37:57,391][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_6 - 5_folds.train_2.predict)=98.81%
# [ 2019-05-21 16:37:57,668][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_6 - 5_folds.train_3.predict)=98.85%
# [ 2019-05-21 16:37:57,907][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_6 - 5_folds.train_4.predict)=98.79%
# [ 2019-05-21 16:37:57,913][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_6 - 5_folds.train_cv.predict)=98.74%
# [ 2019-05-21 16:37:58,638][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_7 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-21 16:37:59,288][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_7 - 5_folds.train_1.predict)=99.41%
# [ 2019-05-21 16:37:59,978][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_7 - 5_folds.train_2.predict)=99.52%
# [ 2019-05-21 16:38:00,634][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_7 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:38:01,299][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_7 - 5_folds.train_4.predict)=99.46%
# [ 2019-05-21 16:38:01,307][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_7 - 5_folds.train_cv.predict)=99.43%
# [ 2019-05-21 16:38:01,315][cascade_classifier.calc_f1] Weighted F1 (layer_7 - train.classifier_average)=99.43%
# [ 2019-05-21 16:38:01,315][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=5, weighted_f1_train=99.43%, weighted_f1_test=0.00%
# [ 2019-05-21 16:38:01,321][cascade_classifier.transform] X_groups_test.shape=[(8401, 4)]
# [ 2019-05-21 16:38:01,323][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-21 16:38:01,324][cascade_classifier.transform] X_test.shape=(8401, 4)
# [ 2019-05-21 16:38:01,326][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(8401, 4)
# [ 2019-05-21 16:38:01,524][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(8401, 52)
# [ 2019-05-21 16:38:01,729][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(8401, 52)
# [ 2019-05-21 16:38:01,927][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(8401, 52)
# [ 2019-05-21 16:38:02,125][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(8401, 52)
# [ 2019-05-21 16:38:02,328][cascade_classifier.transform] X_groups_test.shape=[(25211, 4)]
# [ 2019-05-21 16:38:02,329][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-21 16:38:02,330][cascade_classifier.transform] X_test.shape=(25211, 4)
# [ 2019-05-21 16:38:02,332][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(25211, 4)
# [ 2019-05-21 16:38:02,828][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(25211, 52)
# [ 2019-05-21 16:38:03,401][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(25211, 52)
# [ 2019-05-21 16:38:03,979][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(25211, 52)
# [ 2019-05-21 16:38:04,545][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(25211, 52)
