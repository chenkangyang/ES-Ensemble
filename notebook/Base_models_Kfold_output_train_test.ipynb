# %%
import os
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append("..") 
from gcforest.gcforest import GCForest

import xlwt
# Out:
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# # 数据及参数

# %%
random_seed = 42
cv=5
score = 'f1_weighted'

# %%
def get_toy_config():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
path = os.getcwd()+'/../data/20122018freshwater_four_feature.csv'
data = pd.read_csv(path, na_values = np.nan)

# %%
X = data.drop(['本周水质'], axis=1).values # Series
y = data['本周水质'].values.reshape(-1,1) - 1

# 1. 中位数填充缺失值，2.Z-score标准化
clean_pipeline = Pipeline([('imputer', preprocessing.Imputer(missing_values='NaN',strategy="median")),
                           ('std_scaler', preprocessing.StandardScaler())])
X = clean_pipeline.fit_transform(X)

# %%
X.shape
# Out:
# (33612, 4)

# %% [markdown]
# # k折交叉验证

# %%
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1


def kftrain(X, y, model, cv):
    model_name = model.__class__.__name__

    n_samples = X.shape[0]
    n_features = X.shape[1]
    n_class = np.unique(y).shape[0]

    Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    cv_F1_weighted = np.zeros(cv) # 5次 test data 的F1_weighted
    _cv_F1_weighted = np.zeros(cv) # 5次 train data 的F1_weighted
    cv_Acc = np.zeros(cv) # 5次test data的Acc
    _cv_Acc = np.zeros(cv) # 5次train data的Acc
    # 各类别的Support，每个类别的support由5次fold后得到的5个support求平均得到，这里support：各类别样本占总样本的比列
    # 各类别的F1，由5次fold后得到的5个F1求平均得到
    # 所以，Weighted F1 等于“5次fold得到的5个 Weighted F1 求平均得到” ——等价于—— “6个support*6个F1”得到
    Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后test data各类别的support
    _Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后train data各类别的support
    
    # 各类别的Mean，SD
    Acc_mean_class = np.zeros(6)
    _Acc_mean_class = np.zeros(6)
    Acc_SD_class = np.zeros(6)
    _Acc_SD_class = np.zeros(6)
    F1_mean_class = np.zeros(6)
    _F1_mean_class = np.zeros(6)
    F1_SD_class = np.zeros(6)
    _F1_SD_class = np.zeros(6)
    
    k = 0
    skf = StratifiedKFold(n_splits=cv) # 定义5折分层划分器
    
    for train_index, test_index in skf.split(X, y):
        K_train_x, K_test_x = X[train_index], X[test_index]
        K_train_y, K_test_y = y[train_index], y[test_index]
        if model_name == 'GCForest':
            model.fit_transform(K_train_x, K_train_y.reshape(K_train_y.shape[0]))
        else:
            model.fit(K_train_x, K_train_y)
    
        K_test_y_pred = model.predict(K_test_x)
        K_train_y_pred = model.predict(K_train_x)
        
        # 由混淆矩阵计算各类别的Acc
        test_cm = confusion_matrix(K_test_y, K_test_y_pred)
        train_cm = confusion_matrix(K_train_y, K_train_y_pred)
        test_acc_all_class = np.zeros(n_class) # 6个类别上的测试acc
        train_acc_all_class = np.zeros(n_class) # 6个类别上的训练acc
        
        i = 0
        for c in test_cm:
            test_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        Acc_matrix[:,k] = test_acc_all_class
        
        i = 0
        for c in train_cm:
            train_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        _Acc_matrix[:,k] = train_acc_all_class
        
        # 由classification_report提取各类别的F1
        cr = classification_report(K_test_y, K_test_y_pred, digits=4)
        _cr = classification_report(K_train_y, K_train_y_pred, digits=4)
        test_f1_all_class = np.zeros(n_class) # test data 6个类别上的测试f1
        train_f1_all_class = np.zeros(n_class) # train data 6个类别上的训练f1
        support_all_class = np.zeros(n_class) # test data 6个类别的support
        _support_all_class = np.zeros(n_class) # train data 6个类别的support
        
        i = 0
        for l in range(2,8):
            test_f1_all_class[i] = float(cr.splitlines()[l].split()[3])
            train_f1_all_class[i] = float(_cr.splitlines()[l].split()[3])
            support_all_class[i] = float(cr.splitlines()[l].split()[4])/(n_samples*0.2)
            _support_all_class[i] = float(_cr.splitlines()[l].split()[4])/(n_samples*0.8)
            i = i + 1
        F1_matrix[:,k] = test_f1_all_class
        _F1_matrix[:,k] = train_f1_all_class
        Support_matrix[:,k] = support_all_class
        _Support_matrix[:,k] = _support_all_class
        
        # cv_F1_weighted[k] = float(cr.splitlines()[9].split()[5]) # 第k折时的Weighted F1
        cv_F1_weighted[k] = f1_score(K_test_y, K_test_y_pred, average="weighted")
        _cv_F1_weighted[k] = f1_score(K_train_y, K_train_y_pred, average="weighted")
        cv_Acc[k] = accuracy_score(K_test_y, K_test_y_pred)
        _cv_Acc[k] = accuracy_score(K_train_y, K_train_y_pred)
        
        k += 1
    
    Acc_mean = np.mean(Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    _Acc_mean = np.mean(_Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    
    F1_mean = np.mean(F1_matrix, axis=1) # 6个类别的k-fold平均F1
    _F1_mean = np.mean(_F1_matrix, axis=1) # 6个类别的k-fold平均F1
    Support_mean = np.mean(Support_matrix, axis=1) # 6个类别的k-fold平均support
    _Support_mean = np.mean(_Support_matrix, axis=1) # 6个类别的k-fold平均support
    
    Acc = np.mean(Acc_mean)
    _Acc = np.mean(_Acc_mean)
    F1_weighted = np.mean(cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    _F1_weighted = np.mean(_cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    SD_Acc = np.std(cv_Acc)
    _SD_Acc = np.std(cv_Acc)
    SD_F1 = np.std(cv_F1_weighted)
    _SD_F1 = np.std(cv_F1_weighted)
    
    Acc_mean_class = np.mean(Acc_matrix, axis=1)
    _Acc_mean_class = np.mean(_Acc_matrix, axis=1)
    Acc_SD_class = np.std(Acc_matrix, axis=1)
    _Acc_SD_class = np.std(_Acc_matrix, axis=1)
    F1_mean_class = np.mean(F1_matrix, axis=1)
    _F1_mean_class = np.mean(_F1_matrix, axis=1)
    F1_SD_class = np.std(F1_matrix, axis=1)
    _F1_SD_class = np.std(_F1_matrix, axis=1)
    
    # return Acc_mean, F1_mean, Support_mean, Acc, F1_weighted, SD_Acc, SD_F1, Acc_mean_class, Acc_SD_class, F1_mean_class, F1_SD_class
    return Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_mean, _Acc_mean, F1_mean, _F1_mean, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class

# %%
config = get_toy_config()

models = [
    LogisticRegression(),
    LinearDiscriminantAnalysis(),
    SVC(probability=True),
    DecisionTreeClassifier(),
    ExtraTreeClassifier(),
    GaussianNB(),
    KNeighborsClassifier(),
    RandomForestClassifier(random_state=random_seed),
    ExtraTreesClassifier(random_state=random_seed),
    GCForest(config)
]

workbook = xlwt.Workbook(encoding = 'utf-8')  

for model in models:
    model_name = model.__class__.__name__
    print(model_name)
    # Acc_class, F1_class, Support_class, Acc, F1_weighted, SD_Acc, SD_F1, Acc_mean_class, Acc_SD_class, F1_mean_class, F1_SD_class = kftrain(X, y, model, 5)
    Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_class, _Acc_class, F1_class, _F1_class, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class = kftrain(X, y, model, 5)

    worksheet = workbook.add_sheet(model_name, cell_overwrite_ok=True)
    worksheet.write(0,0, "train_Acc_matrix")
    for i in range(6):
        for j in range(5):
            worksheet.write(i+1, j, _Acc_matrix[i,j])

    worksheet.write(0,6, "test_Acc_matrix")
    for i in range(6):
        for j in range(5):
            worksheet.write(i+1, j+7, Acc_matrix[i,j])



    worksheet.write(11,0, "train_F1_matrix")
    for i in range(6):
        for j in range(5):
            worksheet.write(i+12, j, _F1_matrix[i,j])

    worksheet.write(11,6, "test_F1_matrix")
    for i in range(6):
        for j in range(5):
            worksheet.write(i+12, j+7, F1_matrix[i,j])



    worksheet.write(20,0, "train_support_matrix")
    for i in range(6):
        for j in range(5):
            worksheet.write(i+21, j, _Support_matrix[i,j])

    worksheet.write(20,6, "test_support_matrix")
    for i in range(6):
        for j in range(5):
            worksheet.write(i+21, j+7, Support_matrix[i,j])
            
workbook.save("../res/basemodels.xls")

#     print("===Test Accuracy===")
#     for i in range(len(Acc_class)):
#         print("Class %d: %.2f%%" %(i, Acc_class[i]*100))
#         print("Mean±SD: %.2f±%.2f%%" %(Acc_mean_class[i]*100,Acc_SD_class[i]*100))
    
#     print("Overall: %.2f%%" %(Acc*100))
#     print("Mean±SD: %.2f±%.2f%%" %(Acc*100,SD_Acc*100))
    
#     print("===Train Accuracy===")
#     for i in range(len(_Acc_class)):
#         print("Class %d: %.2f%%" %(i, _Acc_class[i]*100))
#         print("Mean±SD: %.2f±%.2f%%" %(_Acc_mean_class[i]*100, _Acc_SD_class[i]*100))
        
#     print("Overall: %.2f%%" %(_Acc*100))
#     print("Mean±SD: %.2f±%.2f%%" %(_Acc*100, _SD_Acc*100))

#     print("===  Test F1  ===")
#     for i in range(len(F1_class)):
#         print("Class %d: %.2f%%" %(i, F1_class[i]*100))
#         print("Mean±SD: %.2f±%.2f%%" %(F1_mean_class[i]*100,F1_SD_class[i]*100))
        
#     print("F{beta}: %.2f%%" %(F1_weighted*100))
#     print("Mean±SD: %.2f±%.2f%%" %(F1_weighted*100,SD_F1*100))
    
    
#     print("===  Train F1  ===")
#     for i in range(len(_F1_class)):
#         print("Class %d: %.2f%%" %(i, _F1_class[i]*100))
#         print("Mean±SD: %.2f±%.2f%%" %(_F1_mean_class[i]*100, _F1_SD_class[i]*100))
        
#     print("F{beta}: %.2f%%" %(_F1_weighted*100))
#     print("Mean±SD: %.2f±%.2f%%" %(_F1_weighted*100, _SD_F1*100))
#     print("\n===============\n")
    
    
#     print("=== Train Acc_matrix===")
#     print(_Acc_matrix)
#     print("=== Train F1_matrix===")
#     print(_F1_matrix)
#     print("=== Train Support_matrix===")
#     print(_Support_matrix)
    
#     print("=== Test Acc_matrix===")
#     print(Acc_matrix)
#     print("=== Test F1_matrix===")
#     print(F1_matrix)
#     print("=== Test Support_matrix===")
#     print(Support_matrix)
# Out:
# LogisticRegression
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# LinearDiscriminantAnalysis
# SVC
# DecisionTreeClassifier
# ExtraTreeClassifier
# GaussianNB
# KNeighborsClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# RandomForestClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ExtraTreesClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# [ 2019-05-11 17:07:23,670][cascade_classifier.fit_transform] X_groups_train.shape=[(26886, 4)],y_train.shape=(26886,),X_groups_test.shape=no_test,y_test.shape=no_test
# [ 2019-05-11 17:07:23,671][cascade_classifier.fit_transform] group_dims=[4]
# [ 2019-05-11 17:07:23,672][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-05-11 17:07:23,673][cascade_classifier.fit_transform] group_ends=[4]
# [ 2019-05-11 17:07:23,675][cascade_classifier.fit_transform] X_train.shape=(26886, 4),X_test.shape=(0, 4)
# [ 2019-05-11 17:07:23,678][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(26886, 4), X_cur_test.shape=(0, 4)
# [ 2019-05-11 17:07:23,849][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_0.predict)=99.52%
# GCForest
# [ 2019-05-11 17:07:24,015][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-11 17:07:24,169][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-11 17:07:24,325][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_3.predict)=99.50%
# [ 2019-05-11 17:07:24,481][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-11 17:07:24,487][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_cv.predict)=99.49%
# [ 2019-05-11 17:07:24,670][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_0.predict)=99.52%
# [ 2019-05-11 17:07:24,827][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-11 17:07:24,989][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_2.predict)=99.63%
# [ 2019-05-11 17:07:25,150][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_3.predict)=99.57%
# [ 2019-05-11 17:07:25,306][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_4.predict)=99.44%
# [ 2019-05-11 17:07:25,312][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_cv.predict)=99.54%
# [ 2019-05-11 17:07:25,479][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_0.predict)=99.41%
# [ 2019-05-11 17:07:25,630][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-11 17:07:25,788][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_2.predict)=99.33%
# [ 2019-05-11 17:07:25,954][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_3.predict)=99.63%
# [ 2019-05-11 17:07:26,108][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_4.predict)=99.53%
# [ 2019-05-11 17:07:26,115][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_cv.predict)=99.49%
# [ 2019-05-11 17:07:26,283][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_0.predict)=99.37%
# [ 2019-05-11 17:07:26,440][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_1.predict)=99.42%
# [ 2019-05-11 17:07:26,594][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_2.predict)=99.63%
# [ 2019-05-11 17:07:26,745][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_3.predict)=99.61%
# [ 2019-05-11 17:07:26,894][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_4.predict)=99.53%
# [ 2019-05-11 17:07:26,900][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_cv.predict)=99.51%
# [ 2019-05-11 17:07:26,955][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_0.predict)=99.05%
# [ 2019-05-11 17:07:26,996][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_1.predict)=99.14%
# [ 2019-05-11 17:07:27,037][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_2.predict)=99.13%
# [ 2019-05-11 17:07:27,076][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_3.predict)=99.20%
# [ 2019-05-11 17:07:27,115][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_4.predict)=99.35%
# [ 2019-05-11 17:07:27,123][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_cv.predict)=99.17%
# [ 2019-05-11 17:07:27,176][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_0.predict)=99.05%
# [ 2019-05-11 17:07:27,215][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_1.predict)=99.11%
# [ 2019-05-11 17:07:27,255][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_2.predict)=99.09%
# [ 2019-05-11 17:07:27,295][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_3.predict)=99.13%
# [ 2019-05-11 17:07:27,336][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_4.predict)=98.98%
# [ 2019-05-11 17:07:27,343][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_cv.predict)=99.07%
# [ 2019-05-11 17:07:27,398][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_0.predict)=98.92%
# [ 2019-05-11 17:07:27,437][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_1.predict)=99.11%
# [ 2019-05-11 17:07:27,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_2.predict)=99.05%
# [ 2019-05-11 17:07:27,519][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_3.predict)=99.24%
# [ 2019-05-11 17:07:27,562][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_4.predict)=99.13%
# [ 2019-05-11 17:07:27,569][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_cv.predict)=99.09%
# [ 2019-05-11 17:07:27,692][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_0.predict)=62.55%
# [ 2019-05-11 17:07:27,830][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_1.predict)=61.41%
# [ 2019-05-11 17:07:27,960][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_2.predict)=62.69%
# [ 2019-05-11 17:07:28,088][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_3.predict)=61.26%
# [ 2019-05-11 17:07:28,199][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_4.predict)=62.56%
# [ 2019-05-11 17:07:28,205][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_cv.predict)=62.09%
# [ 2019-05-11 17:07:28,212][cascade_classifier.calc_f1] Weighted F1 (layer_0 - train.classifier_average)=99.52%
# [ 2019-05-11 17:07:28,223][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-11 17:07:28,486][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_0.predict)=99.61%
# [ 2019-05-11 17:07:28,732][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_1.predict)=99.48%
# [ 2019-05-11 17:07:28,983][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_2.predict)=99.53%
# [ 2019-05-11 17:07:29,246][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_3.predict)=99.48%
# [ 2019-05-11 17:07:29,516][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-11 17:07:29,525][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:07:29,818][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_0.predict)=99.67%
# [ 2019-05-11 17:07:30,090][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_1.predict)=99.54%
# [ 2019-05-11 17:07:30,360][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-11 17:07:30,631][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_3.predict)=99.61%
# [ 2019-05-11 17:07:30,893][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_4.predict)=99.46%
# [ 2019-05-11 17:07:30,900][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:07:31,176][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-11 17:07:31,436][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_1.predict)=99.61%
# [ 2019-05-11 17:07:31,702][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_2.predict)=99.57%
# [ 2019-05-11 17:07:31,962][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_3.predict)=99.55%
# [ 2019-05-11 17:07:32,239][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-11 17:07:32,246][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:07:32,523][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_0.predict)=99.50%
# [ 2019-05-11 17:07:32,784][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_1.predict)=99.59%
# [ 2019-05-11 17:07:33,052][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_2.predict)=99.59%
# [ 2019-05-11 17:07:33,317][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_3.predict)=99.57%
# [ 2019-05-11 17:07:33,591][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_4.predict)=99.57%
# [ 2019-05-11 17:07:33,600][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:07:33,891][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_0.predict)=98.98%
# [ 2019-05-11 17:07:34,152][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_1.predict)=98.98%
# [ 2019-05-11 17:07:34,433][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_2.predict)=99.11%
# [ 2019-05-11 17:07:34,700][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_3.predict)=99.26%
# [ 2019-05-11 17:07:34,955][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_4.predict)=99.05%
# [ 2019-05-11 17:07:34,962][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_cv.predict)=99.07%
# [ 2019-05-11 17:07:35,222][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_0.predict)=99.07%
# [ 2019-05-11 17:07:35,466][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_1.predict)=99.18%
# [ 2019-05-11 17:07:35,746][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_2.predict)=99.05%
# [ 2019-05-11 17:07:35,991][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_3.predict)=99.05%
# [ 2019-05-11 17:07:36,264][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_4.predict)=99.16%
# [ 2019-05-11 17:07:36,271][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_cv.predict)=99.10%
# [ 2019-05-11 17:07:36,560][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_0.predict)=99.05%
# [ 2019-05-11 17:07:36,830][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_1.predict)=98.92%
# [ 2019-05-11 17:07:37,133][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_2.predict)=99.09%
# [ 2019-05-11 17:07:37,420][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_3.predict)=99.18%
# [ 2019-05-11 17:07:37,698][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_4.predict)=99.16%
# [ 2019-05-11 17:07:37,705][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_cv.predict)=99.08%
# [ 2019-05-11 17:07:38,619][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_0.predict)=99.59%
# [ 2019-05-11 17:07:39,487][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_1.predict)=99.48%
# [ 2019-05-11 17:07:40,331][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_2.predict)=99.68%
# [ 2019-05-11 17:07:41,135][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_3.predict)=99.46%
# [ 2019-05-11 17:07:41,899][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_4.predict)=99.59%
# [ 2019-05-11 17:07:41,906][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:07:41,916][cascade_classifier.calc_f1] Weighted F1 (layer_1 - train.classifier_average)=99.56%
# [ 2019-05-11 17:07:41,925][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-11 17:07:42,225][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_0.predict)=99.63%
# [ 2019-05-11 17:07:42,456][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-11 17:07:42,677][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_2.predict)=99.50%
# [ 2019-05-11 17:07:42,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_3.predict)=99.50%
# [ 2019-05-11 17:07:43,133][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_4.predict)=99.67%
# [ 2019-05-11 17:07:43,140][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-11 17:07:43,409][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_0.predict)=99.59%
# [ 2019-05-11 17:07:43,743][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_1.predict)=99.54%
# [ 2019-05-11 17:07:43,981][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_2.predict)=99.67%
# [ 2019-05-11 17:07:44,210][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_3.predict)=99.46%
# [ 2019-05-11 17:07:44,532][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-11 17:07:44,553][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-11 17:07:45,027][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_0.predict)=99.72%
# [ 2019-05-11 17:07:45,411][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_1.predict)=99.61%
# [ 2019-05-11 17:07:45,707][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_2.predict)=99.59%
# [ 2019-05-11 17:07:45,929][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_3.predict)=99.33%
# [ 2019-05-11 17:07:46,184][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_4.predict)=99.55%
# [ 2019-05-11 17:07:46,190][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:07:46,551][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_0.predict)=99.52%
# [ 2019-05-11 17:07:46,793][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_1.predict)=99.50%
# [ 2019-05-11 17:07:47,019][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_2.predict)=99.54%
# [ 2019-05-11 17:07:47,255][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_3.predict)=99.53%
# [ 2019-05-11 17:07:47,487][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_4.predict)=99.70%
# [ 2019-05-11 17:07:47,494][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:07:47,756][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_0.predict)=99.18%
# [ 2019-05-11 17:07:48,015][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_1.predict)=99.26%
# [ 2019-05-11 17:07:48,270][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_2.predict)=99.27%
# [ 2019-05-11 17:07:48,505][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_3.predict)=99.09%
# [ 2019-05-11 17:07:48,751][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_4.predict)=99.07%
# [ 2019-05-11 17:07:48,758][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_cv.predict)=99.17%
# [ 2019-05-11 17:07:49,005][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_0.predict)=99.00%
# [ 2019-05-11 17:07:49,253][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_1.predict)=98.94%
# [ 2019-05-11 17:07:49,490][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_2.predict)=98.98%
# [ 2019-05-11 17:07:49,740][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_3.predict)=99.14%
# [ 2019-05-11 17:07:49,969][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_4.predict)=99.13%
# [ 2019-05-11 17:07:49,976][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_cv.predict)=99.04%
# [ 2019-05-11 17:07:50,237][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_0.predict)=99.11%
# [ 2019-05-11 17:07:50,461][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_1.predict)=99.18%
# [ 2019-05-11 17:07:50,691][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_2.predict)=99.03%
# [ 2019-05-11 17:07:50,931][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_3.predict)=99.20%
# [ 2019-05-11 17:07:51,157][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_4.predict)=99.07%
# [ 2019-05-11 17:07:51,164][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_cv.predict)=99.12%
# [ 2019-05-11 17:07:51,791][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_0.predict)=99.57%
# [ 2019-05-11 17:07:52,428][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-11 17:07:53,069][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_2.predict)=99.67%
# [ 2019-05-11 17:07:53,682][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_3.predict)=99.50%
# [ 2019-05-11 17:07:54,314][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_4.predict)=99.57%
# [ 2019-05-11 17:07:54,321][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_cv.predict)=99.58%
# [ 2019-05-11 17:07:54,328][cascade_classifier.calc_f1] Weighted F1 (layer_2 - train.classifier_average)=99.56%
# [ 2019-05-11 17:07:54,335][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-11 17:07:54,560][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_0.predict)=99.55%
# [ 2019-05-11 17:07:54,770][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_1.predict)=99.59%
# [ 2019-05-11 17:07:54,978][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_2.predict)=99.59%
# [ 2019-05-11 17:07:55,195][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_3.predict)=99.54%
# [ 2019-05-11 17:07:55,410][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_4.predict)=99.59%
# [ 2019-05-11 17:07:55,416][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-11 17:07:55,636][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_0.predict)=99.48%
# [ 2019-05-11 17:07:55,840][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_1.predict)=99.63%
# [ 2019-05-11 17:07:56,060][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_2.predict)=99.59%
# [ 2019-05-11 17:07:56,289][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_3.predict)=99.55%
# [ 2019-05-11 17:07:56,504][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_4.predict)=99.55%
# [ 2019-05-11 17:07:56,510][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:07:56,744][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-11 17:07:56,963][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_1.predict)=99.61%
# [ 2019-05-11 17:07:57,181][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_2.predict)=99.53%
# [ 2019-05-11 17:07:57,416][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_3.predict)=99.68%
# [ 2019-05-11 17:07:57,639][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_4.predict)=99.57%
# [ 2019-05-11 17:07:57,646][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-11 17:07:57,878][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-11 17:07:58,099][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_1.predict)=99.59%
# [ 2019-05-11 17:07:58,318][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_2.predict)=99.53%
# [ 2019-05-11 17:07:58,536][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_3.predict)=99.63%
# [ 2019-05-11 17:07:58,767][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_4.predict)=99.57%
# [ 2019-05-11 17:07:58,774][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:07:59,014][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_0.predict)=99.13%
# [ 2019-05-11 17:07:59,246][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_1.predict)=98.90%
# [ 2019-05-11 17:07:59,467][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_2.predict)=99.16%
# [ 2019-05-11 17:07:59,708][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_3.predict)=99.24%
# [ 2019-05-11 17:07:59,917][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_4.predict)=99.14%
# [ 2019-05-11 17:07:59,924][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_cv.predict)=99.12%
# [ 2019-05-11 17:08:00,169][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_0.predict)=98.96%
# [ 2019-05-11 17:08:00,406][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_1.predict)=99.28%
# [ 2019-05-11 17:08:00,618][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_2.predict)=99.20%
# [ 2019-05-11 17:08:00,862][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_3.predict)=98.98%
# [ 2019-05-11 17:08:01,092][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_4.predict)=99.22%
# [ 2019-05-11 17:08:01,099][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_cv.predict)=99.13%
# [ 2019-05-11 17:08:01,328][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_0.predict)=99.00%
# [ 2019-05-11 17:08:01,570][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_1.predict)=99.05%
# [ 2019-05-11 17:08:01,803][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_2.predict)=99.03%
# [ 2019-05-11 17:08:02,029][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_3.predict)=98.90%
# [ 2019-05-11 17:08:02,252][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_4.predict)=99.13%
# [ 2019-05-11 17:08:02,259][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_cv.predict)=99.02%
# [ 2019-05-11 17:08:02,932][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_0.predict)=99.68%
# [ 2019-05-11 17:08:03,563][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-11 17:08:04,174][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_2.predict)=99.61%
# [ 2019-05-11 17:08:04,786][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_3.predict)=99.50%
# [ 2019-05-11 17:08:05,407][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_4.predict)=99.52%
# [ 2019-05-11 17:08:05,413][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-11 17:08:05,420][cascade_classifier.calc_f1] Weighted F1 (layer_3 - train.classifier_average)=99.56%
# [ 2019-05-11 17:08:05,426][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-11 17:08:05,651][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_0.predict)=99.61%
# [ 2019-05-11 17:08:05,855][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-11 17:08:06,060][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_2.predict)=99.40%
# [ 2019-05-11 17:08:06,272][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_3.predict)=99.65%
# [ 2019-05-11 17:08:06,479][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_4.predict)=99.52%
# [ 2019-05-11 17:08:06,486][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:08:06,711][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_0.predict)=99.50%
# [ 2019-05-11 17:08:06,932][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_1.predict)=99.68%
# [ 2019-05-11 17:08:07,151][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_2.predict)=99.57%
# [ 2019-05-11 17:08:07,363][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_3.predict)=99.59%
# [ 2019-05-11 17:08:07,576][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_4.predict)=99.46%
# [ 2019-05-11 17:08:07,583][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:08:07,823][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_0.predict)=99.50%
# [ 2019-05-11 17:08:08,036][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_1.predict)=99.46%
# [ 2019-05-11 17:08:08,260][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_2.predict)=99.52%
# [ 2019-05-11 17:08:08,491][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_3.predict)=99.55%
# [ 2019-05-11 17:08:08,721][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_4.predict)=99.67%
# [ 2019-05-11 17:08:08,728][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_cv.predict)=99.54%
# [ 2019-05-11 17:08:08,941][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_0.predict)=99.61%
# [ 2019-05-11 17:08:09,159][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_1.predict)=99.63%
# [ 2019-05-11 17:08:09,374][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_2.predict)=99.61%
# [ 2019-05-11 17:08:09,582][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_3.predict)=99.41%
# [ 2019-05-11 17:08:09,796][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_4.predict)=99.50%
# [ 2019-05-11 17:08:09,802][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:08:10,053][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_0.predict)=99.27%
# [ 2019-05-11 17:08:10,278][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_1.predict)=99.18%
# [ 2019-05-11 17:08:10,504][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_2.predict)=99.09%
# [ 2019-05-11 17:08:10,722][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_3.predict)=99.01%
# [ 2019-05-11 17:08:10,924][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_4.predict)=98.79%
# [ 2019-05-11 17:08:10,931][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_cv.predict)=99.07%
# [ 2019-05-11 17:08:11,179][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_0.predict)=99.22%
# [ 2019-05-11 17:08:11,402][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_1.predict)=99.09%
# [ 2019-05-11 17:08:11,621][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_2.predict)=99.18%
# [ 2019-05-11 17:08:11,834][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_3.predict)=99.01%
# [ 2019-05-11 17:08:12,033][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_4.predict)=98.98%
# [ 2019-05-11 17:08:12,040][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_cv.predict)=99.10%
# [ 2019-05-11 17:08:12,292][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_0.predict)=99.29%
# [ 2019-05-11 17:08:12,516][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_1.predict)=99.13%
# [ 2019-05-11 17:08:12,733][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_2.predict)=98.94%
# [ 2019-05-11 17:08:12,952][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_3.predict)=99.07%
# [ 2019-05-11 17:08:13,163][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_4.predict)=98.98%
# [ 2019-05-11 17:08:13,169][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_cv.predict)=99.08%
# [ 2019-05-11 17:08:13,813][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_0.predict)=99.67%
# [ 2019-05-11 17:08:14,420][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_1.predict)=99.44%
# [ 2019-05-11 17:08:15,048][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_2.predict)=99.52%
# [ 2019-05-11 17:08:15,666][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_3.predict)=99.65%
# [ 2019-05-11 17:08:16,291][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_4.predict)=99.59%
# [ 2019-05-11 17:08:16,297][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-11 17:08:16,304][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=99.55%
# [ 2019-05-11 17:08:16,310][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-11 17:08:16,547][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=99.67%
# [ 2019-05-11 17:08:16,754][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=99.42%
# [ 2019-05-11 17:08:16,993][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=99.55%
# [ 2019-05-11 17:08:17,204][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=99.63%
# [ 2019-05-11 17:08:17,412][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=99.50%
# [ 2019-05-11 17:08:17,419][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:08:17,643][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=99.50%
# [ 2019-05-11 17:08:17,855][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=99.50%
# [ 2019-05-11 17:08:18,068][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=99.52%
# [ 2019-05-11 17:08:18,283][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=99.57%
# [ 2019-05-11 17:08:18,499][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-11 17:08:18,506][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:08:18,739][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_0.predict)=99.55%
# [ 2019-05-11 17:08:18,951][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_1.predict)=99.59%
# [ 2019-05-11 17:08:19,172][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_2.predict)=99.59%
# [ 2019-05-11 17:08:19,382][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_3.predict)=99.42%
# [ 2019-05-11 17:08:19,591][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-11 17:08:19,598][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:08:19,835][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_0.predict)=99.57%
# [ 2019-05-11 17:08:20,054][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-11 17:08:20,261][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_2.predict)=99.54%
# [ 2019-05-11 17:08:20,473][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_3.predict)=99.55%
# [ 2019-05-11 17:08:20,691][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_4.predict)=99.53%
# [ 2019-05-11 17:08:20,698][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:08:20,925][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_0.predict)=98.92%
# [ 2019-05-11 17:08:21,149][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_1.predict)=99.03%
# [ 2019-05-11 17:08:21,343][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_2.predict)=99.01%
# [ 2019-05-11 17:08:21,548][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_3.predict)=99.03%
# [ 2019-05-11 17:08:21,782][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_4.predict)=99.29%
# [ 2019-05-11 17:08:21,788][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_cv.predict)=99.06%
# [ 2019-05-11 17:08:22,024][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_0.predict)=99.03%
# [ 2019-05-11 17:08:22,245][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_1.predict)=99.26%
# [ 2019-05-11 17:08:22,461][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_2.predict)=99.13%
# [ 2019-05-11 17:08:22,668][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_3.predict)=99.05%
# [ 2019-05-11 17:08:22,896][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_4.predict)=99.22%
# [ 2019-05-11 17:08:22,903][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_cv.predict)=99.14%
# [ 2019-05-11 17:08:23,151][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_0.predict)=99.05%
# [ 2019-05-11 17:08:23,350][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_1.predict)=99.22%
# [ 2019-05-11 17:08:23,544][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=99.14%
# [ 2019-05-11 17:08:23,767][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=99.16%
# [ 2019-05-11 17:08:23,966][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=99.01%
# [ 2019-05-11 17:08:23,973][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=99.12%
# [ 2019-05-11 17:08:24,609][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.63%
# [ 2019-05-11 17:08:25,287][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-11 17:08:25,911][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.42%
# [ 2019-05-11 17:08:26,517][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.52%
# [ 2019-05-11 17:08:27,153][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-11 17:08:27,159][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:08:27,166][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.56%
# [ 2019-05-11 17:08:27,172][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-11 17:08:27,406][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_0.predict)=99.61%
# [ 2019-05-11 17:08:27,615][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_1.predict)=99.46%
# [ 2019-05-11 17:08:27,825][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_2.predict)=99.42%
# [ 2019-05-11 17:08:28,046][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_3.predict)=99.74%
# [ 2019-05-11 17:08:28,272][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-11 17:08:28,279][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-11 17:08:28,512][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_0.predict)=99.57%
# [ 2019-05-11 17:08:28,721][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-11 17:08:28,940][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_2.predict)=99.55%
# [ 2019-05-11 17:08:29,157][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_3.predict)=99.55%
# [ 2019-05-11 17:08:29,380][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_4.predict)=99.55%
# [ 2019-05-11 17:08:29,387][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-11 17:08:29,623][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_0.predict)=99.59%
# [ 2019-05-11 17:08:29,842][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_1.predict)=99.48%
# [ 2019-05-11 17:08:30,062][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_2.predict)=99.50%
# [ 2019-05-11 17:08:30,285][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_3.predict)=99.57%
# [ 2019-05-11 17:08:30,504][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_4.predict)=99.59%
# [ 2019-05-11 17:08:30,511][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:08:30,754][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_0.predict)=99.59%
# [ 2019-05-11 17:08:30,983][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_1.predict)=99.67%
# [ 2019-05-11 17:08:31,199][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_2.predict)=99.55%
# [ 2019-05-11 17:08:31,415][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_3.predict)=99.39%
# [ 2019-05-11 17:08:31,639][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_4.predict)=99.57%
# [ 2019-05-11 17:08:31,646][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-11 17:08:31,878][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_0.predict)=99.05%
# [ 2019-05-11 17:08:32,087][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_1.predict)=99.16%
# [ 2019-05-11 17:08:32,324][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_2.predict)=99.16%
# [ 2019-05-11 17:08:32,543][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_3.predict)=99.18%
# [ 2019-05-11 17:08:32,758][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_4.predict)=99.07%
# [ 2019-05-11 17:08:32,765][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_cv.predict)=99.13%
# [ 2019-05-11 17:08:32,996][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_0.predict)=99.26%
# [ 2019-05-11 17:08:33,207][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_1.predict)=99.14%
# [ 2019-05-11 17:08:33,422][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_2.predict)=99.20%
# [ 2019-05-11 17:08:33,648][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_3.predict)=98.98%
# [ 2019-05-11 17:08:33,867][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_4.predict)=99.18%
# [ 2019-05-11 17:08:33,874][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_cv.predict)=99.15%
# [ 2019-05-11 17:08:34,100][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_0.predict)=98.98%
# [ 2019-05-11 17:08:34,317][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_1.predict)=99.03%
# [ 2019-05-11 17:08:34,532][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_2.predict)=99.27%
# [ 2019-05-11 17:08:34,730][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_3.predict)=98.92%
# [ 2019-05-11 17:08:34,944][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_4.predict)=99.27%
# ...
# [ 2019-05-11 17:13:23,816][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_1.predict)=98.55%
# [ 2019-05-11 17:13:24,077][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_2.predict)=98.61%
# [ 2019-05-11 17:13:24,353][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_3.predict)=98.44%
# [ 2019-05-11 17:13:24,612][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_4.predict)=98.58%
# [ 2019-05-11 17:13:24,619][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_cv.predict)=98.57%
# [ 2019-05-11 17:13:25,258][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_0.predict)=99.52%
# [ 2019-05-11 17:13:25,897][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_1.predict)=99.41%
# [ 2019-05-11 17:13:26,493][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_2.predict)=99.33%
# [ 2019-05-11 17:13:27,095][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_3.predict)=99.18%
# [ 2019-05-11 17:13:27,723][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_4.predict)=99.52%
# [ 2019-05-11 17:13:27,730][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_cv.predict)=99.39%
# [ 2019-05-11 17:13:27,737][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=99.37%
# [ 2019-05-11 17:13:27,743][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(26892, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-11 17:13:27,997][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=99.29%
# [ 2019-05-11 17:13:28,241][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-11 17:13:28,475][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=99.42%
# [ 2019-05-11 17:13:28,719][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=99.24%
# [ 2019-05-11 17:13:28,953][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=99.52%
# [ 2019-05-11 17:13:28,960][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-11 17:13:29,224][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-11 17:13:29,477][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=99.37%
# [ 2019-05-11 17:13:29,725][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=99.50%
# [ 2019-05-11 17:13:29,975][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=99.18%
# [ 2019-05-11 17:13:30,218][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=99.35%
# [ 2019-05-11 17:13:30,225][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-11 17:13:30,499][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_0.predict)=99.33%
# [ 2019-05-11 17:13:30,744][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_1.predict)=99.33%
# [ 2019-05-11 17:13:30,999][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_2.predict)=99.28%
# [ 2019-05-11 17:13:31,242][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_3.predict)=99.54%
# [ 2019-05-11 17:13:31,484][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_4.predict)=99.39%
# [ 2019-05-11 17:13:31,490][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-11 17:13:31,761][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_0.predict)=99.50%
# [ 2019-05-11 17:13:32,000][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_1.predict)=99.26%
# [ 2019-05-11 17:13:32,231][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_2.predict)=99.39%
# [ 2019-05-11 17:13:32,474][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-11 17:13:32,710][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_4.predict)=99.37%
# [ 2019-05-11 17:13:32,717][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-11 17:13:32,984][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_0.predict)=98.53%
# [ 2019-05-11 17:13:33,233][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_1.predict)=98.42%
# [ 2019-05-11 17:13:33,476][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_2.predict)=98.72%
# [ 2019-05-11 17:13:33,746][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_3.predict)=98.86%
# [ 2019-05-11 17:13:33,995][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_4.predict)=98.76%
# [ 2019-05-11 17:13:34,002][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_cv.predict)=98.66%
# [ 2019-05-11 17:13:34,266][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_0.predict)=98.64%
# [ 2019-05-11 17:13:34,524][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_1.predict)=98.72%
# [ 2019-05-11 17:13:34,766][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_2.predict)=98.50%
# [ 2019-05-11 17:13:35,010][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_3.predict)=98.59%
# [ 2019-05-11 17:13:35,259][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_4.predict)=98.49%
# [ 2019-05-11 17:13:35,265][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_cv.predict)=98.59%
# [ 2019-05-11 17:13:35,522][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_0.predict)=98.35%
# [ 2019-05-11 17:13:35,797][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_1.predict)=98.89%
# [ 2019-05-11 17:13:36,038][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=99.01%
# [ 2019-05-11 17:13:36,303][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=98.70%
# [ 2019-05-11 17:13:36,553][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=98.62%
# [ 2019-05-11 17:13:36,560][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=98.71%
# [ 2019-05-11 17:13:37,205][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.28%
# [ 2019-05-11 17:13:37,840][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.41%
# [ 2019-05-11 17:13:38,463][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.44%
# [ 2019-05-11 17:13:39,110][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.37%
# [ 2019-05-11 17:13:39,741][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-11 17:13:39,748][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.38%
# [ 2019-05-11 17:13:39,755][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.36%
# [ 2019-05-11 17:13:39,762][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(26892, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-11 17:13:40,039][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_0.predict)=99.48%
# [ 2019-05-11 17:13:40,283][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_1.predict)=99.48%
# [ 2019-05-11 17:13:40,530][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_2.predict)=99.37%
# [ 2019-05-11 17:13:40,771][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_3.predict)=99.24%
# [ 2019-05-11 17:13:41,005][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_4.predict)=99.24%
# [ 2019-05-11 17:13:41,011][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-11 17:13:41,265][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_0.predict)=99.28%
# [ 2019-05-11 17:13:41,513][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_1.predict)=99.39%
# [ 2019-05-11 17:13:41,740][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_2.predict)=99.35%
# [ 2019-05-11 17:13:41,988][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_3.predict)=99.41%
# [ 2019-05-11 17:13:42,234][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_4.predict)=99.33%
# [ 2019-05-11 17:13:42,241][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_cv.predict)=99.35%
# [ 2019-05-11 17:13:42,508][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_0.predict)=99.42%
# [ 2019-05-11 17:13:42,755][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_1.predict)=99.42%
# [ 2019-05-11 17:13:42,989][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_2.predict)=99.41%
# [ 2019-05-11 17:13:43,229][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_3.predict)=99.29%
# [ 2019-05-11 17:13:43,472][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_4.predict)=99.28%
# [ 2019-05-11 17:13:43,479][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-11 17:13:43,743][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_0.predict)=99.24%
# [ 2019-05-11 17:13:44,002][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_1.predict)=99.46%
# [ 2019-05-11 17:13:44,260][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_2.predict)=99.44%
# [ 2019-05-11 17:13:44,515][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_3.predict)=99.44%
# [ 2019-05-11 17:13:44,746][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_4.predict)=99.22%
# [ 2019-05-11 17:13:44,752][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-11 17:13:45,018][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_0.predict)=98.57%
# [ 2019-05-11 17:13:45,289][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_1.predict)=98.46%
# [ 2019-05-11 17:13:45,586][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_2.predict)=98.53%
# [ 2019-05-11 17:13:45,846][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_3.predict)=98.72%
# [ 2019-05-11 17:13:46,103][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_4.predict)=98.77%
# [ 2019-05-11 17:13:46,110][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_cv.predict)=98.61%
# [ 2019-05-11 17:13:46,398][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_0.predict)=98.42%
# [ 2019-05-11 17:13:46,669][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_1.predict)=98.75%
# [ 2019-05-11 17:13:46,962][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_2.predict)=98.62%
# [ 2019-05-11 17:13:47,247][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_3.predict)=98.49%
# [ 2019-05-11 17:13:47,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_4.predict)=98.55%
# [ 2019-05-11 17:13:47,485][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_cv.predict)=98.57%
# [ 2019-05-11 17:13:47,778][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_0.predict)=98.42%
# [ 2019-05-11 17:13:48,034][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_1.predict)=98.62%
# [ 2019-05-11 17:13:48,289][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_2.predict)=98.57%
# [ 2019-05-11 17:13:48,557][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_3.predict)=98.68%
# [ 2019-05-11 17:13:48,824][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_4.predict)=98.72%
# [ 2019-05-11 17:13:48,831][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_cv.predict)=98.60%
# [ 2019-05-11 17:13:49,485][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-11 17:13:50,108][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_1.predict)=99.37%
# [ 2019-05-11 17:13:50,736][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_2.predict)=99.52%
# [ 2019-05-11 17:13:51,361][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_3.predict)=99.18%
# [ 2019-05-11 17:13:52,011][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_4.predict)=99.37%
# [ 2019-05-11 17:13:52,018][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_cv.predict)=99.38%
# [ 2019-05-11 17:13:52,025][cascade_classifier.calc_f1] Weighted F1 (layer_6 - train.classifier_average)=99.36%
# [ 2019-05-11 17:13:52,026][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=4, weighted_f1_train=99.38%, weighted_f1_test=0.00%
# [ 2019-05-11 17:13:52,033][cascade_classifier.transform] X_groups_test.shape=[(6720, 4)]
# [ 2019-05-11 17:13:52,035][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-11 17:13:52,036][cascade_classifier.transform] X_test.shape=(6720, 4)
# [ 2019-05-11 17:13:52,037][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6720, 4)
# [ 2019-05-11 17:13:52,192][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6720, 52)
# [ 2019-05-11 17:13:52,362][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(6720, 52)
# [ 2019-05-11 17:13:52,527][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(6720, 52)
# [ 2019-05-11 17:13:52,694][cascade_classifier.transform] X_groups_test.shape=[(26892, 4)]
# [ 2019-05-11 17:13:52,695][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-11 17:13:52,696][cascade_classifier.transform] X_test.shape=(26892, 4)
# [ 2019-05-11 17:13:52,697][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(26892, 4)
# [ 2019-05-11 17:13:53,236][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(26892, 52)
# [ 2019-05-11 17:13:54,212][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(26892, 52)
# [ 2019-05-11 17:13:54,930][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(26892, 52)

# %%
m=LogisticRegression()

# %%
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1


def kftrain_copy(X, y, model, cv):
    model_name = model.__class__.__name__

    n_samples = X.shape[0]
    n_features = X.shape[1]
    n_class = np.unique(y).shape[0]
    print(n_samples)
    
    Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    cv_F1_weighted = np.zeros(cv) # 5次 test data 的F1_weighted
    _cv_F1_weighted = np.zeros(cv) # 5次 train data 的F1_weighted
    cv_Acc = np.zeros(cv) # 5次test data的Acc
    _cv_Acc = np.zeros(cv) # 5次train data的Acc
    # 各类别的Support，每个类别的support由5次fold后得到的5个support求平均得到，这里support：各类别样本占总样本的比列
    # 各类别的F1，由5次fold后得到的5个F1求平均得到
    # 所以，Weighted F1 等于“5次fold得到的5个 Weighted F1 求平均得到” ——等价于—— “6个support*6个F1”得到
    Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后test data各类别的support
    _Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后train data各类别的support
    
    # 各类别的Mean，SD
    Acc_mean_class = np.zeros(6)
    _Acc_mean_class = np.zeros(6)
    Acc_SD_class = np.zeros(6)
    _Acc_SD_class = np.zeros(6)
    F1_mean_class = np.zeros(6)
    _F1_mean_class = np.zeros(6)
    F1_SD_class = np.zeros(6)
    _F1_SD_class = np.zeros(6)
    
    k = 0
    skf = StratifiedKFold(n_splits=cv) # 定义5折分层划分器
    
    for train_index, test_index in skf.split(X, y):
        K_train_x, K_test_x = X[train_index], X[test_index]
        K_train_y, K_test_y = y[train_index], y[test_index]
        print(K_train_x.shape[0])
        print(K_test_x.shape[0])
        if model_name == 'GCForest':
            model.fit_transform(K_train_x, K_train_y.reshape(K_train_y.shape[0]))
        else:
            model.fit(K_train_x, K_train_y)
    
        K_test_y_pred = model.predict(K_test_x)
        K_train_y_pred = model.predict(K_train_x)
        
        # 由混淆矩阵计算各类别的Acc
        test_cm = confusion_matrix(K_test_y, K_test_y_pred)
        train_cm = confusion_matrix(K_train_y, K_train_y_pred)
        test_acc_all_class = np.zeros(n_class) # 6个类别上的测试acc
        train_acc_all_class = np.zeros(n_class) # 6个类别上的训练acc
        
        i = 0
        for c in test_cm:
            test_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        Acc_matrix[:,k] = test_acc_all_class
        
        i = 0
        for c in train_cm:
            train_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        _Acc_matrix[:,k] = train_acc_all_class
        
        # 由classification_report提取各类别的F1
        cr = classification_report(K_test_y, K_test_y_pred, digits=4)
        _cr = classification_report(K_train_y, K_train_y_pred, digits=4)
        test_f1_all_class = np.zeros(n_class) # test data 6个类别上的测试f1
        train_f1_all_class = np.zeros(n_class) # train data 6个类别上的训练f1
        support_all_class = np.zeros(n_class) # test data 6个类别的support
        _support_all_class = np.zeros(n_class) # train data 6个类别的support
        print(cr)
        print(_cr)
        i = 0
        for l in range(2,8):
            test_f1_all_class[i] = float(cr.splitlines()[l].split()[3])
            train_f1_all_class[i] = float(_cr.splitlines()[l].split()[3])
            support_all_class[i] = float(cr.splitlines()[l].split()[4])/(n_samples*0.2)
            _support_all_class[i] = float(_cr.splitlines()[l].split()[4])/(n_samples*0.8)
            i = i + 1
        F1_matrix[:,k] = test_f1_all_class
        _F1_matrix[:,k] = train_f1_all_class
        Support_matrix[:,k] = support_all_class
        _Support_matrix[:,k] = _support_all_class
        
        # cv_F1_weighted[k] = float(cr.splitlines()[9].split()[5]) # 第k折时的Weighted F1
        cv_F1_weighted[k] = f1_score(K_test_y, K_test_y_pred, average="weighted")
        _cv_F1_weighted[k] = f1_score(K_train_y, K_train_y_pred, average="weighted")
        cv_Acc[k] = accuracy_score(K_test_y, K_test_y_pred)
        _cv_Acc[k] = accuracy_score(K_train_y, K_train_y_pred)
        
        k += 1
    
    Acc_mean = np.mean(Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    _Acc_mean = np.mean(_Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    
    F1_mean = np.mean(F1_matrix, axis=1) # 6个类别的k-fold平均F1
    _F1_mean = np.mean(_F1_matrix, axis=1) # 6个类别的k-fold平均F1
    Support_mean = np.mean(Support_matrix, axis=1) # 6个类别的k-fold平均support
    _Support_mean = np.mean(_Support_matrix, axis=1) # 6个类别的k-fold平均support
    
    Acc = np.mean(Acc_mean)
    _Acc = np.mean(_Acc_mean)
    F1_weighted = np.mean(cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    _F1_weighted = np.mean(_cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    SD_Acc = np.std(cv_Acc)
    _SD_Acc = np.std(cv_Acc)
    SD_F1 = np.std(cv_F1_weighted)
    _SD_F1 = np.std(cv_F1_weighted)
    
    Acc_mean_class = np.mean(Acc_matrix, axis=1)
    _Acc_mean_class = np.mean(_Acc_matrix, axis=1)
    Acc_SD_class = np.std(Acc_matrix, axis=1)
    _Acc_SD_class = np.std(_Acc_matrix, axis=1)
    F1_mean_class = np.mean(F1_matrix, axis=1)
    _F1_mean_class = np.mean(_F1_matrix, axis=1)
    F1_SD_class = np.std(F1_matrix, axis=1)
    _F1_SD_class = np.std(_F1_matrix, axis=1)
    
    # return Acc_mean, F1_mean, Support_mean, Acc, F1_weighted, SD_Acc, SD_F1, Acc_mean_class, Acc_SD_class, F1_mean_class, F1_SD_class
    return Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_mean, _Acc_mean, F1_mean, _F1_mean, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class

# %%
kftrain_copy(X, y, m, 5)
# Out:
# 33612
# 26886
# 6726
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#              precision    recall  f1-score   support
#
#           0     0.8269    0.0881    0.1593       488
#           1     0.6759    0.9857    0.8019      2655
#           2     0.6098    0.5915    0.6005      1760
#           3     0.6150    0.3808    0.4704      1095
#           4     0.0000    0.0000    0.0000       298
#           5     0.7050    0.6837    0.6942       430
#
# avg / total     0.6316    0.6560    0.6062      6726
#
#              precision    recall  f1-score   support
#
#           0     0.9559    0.0667    0.1246      1950
#           1     0.6813    0.9928    0.8081     10617
#           2     0.6482    0.5892    0.6173      7037
#           3     0.6211    0.4542    0.5247      4377
#           4     0.0000    0.0000    0.0000      1189
#           5     0.7984    0.7780    0.7881      1716
#
# avg / total     0.6601    0.6747    0.6254     26886
#
# 26887
# 6725
#              precision    recall  f1-score   support
#
#           0     1.0000    0.0082    0.0163       488
#           1     0.6816    0.9925    0.8082      2655
#           2     0.6540    0.6080    0.6302      1760
#           3     0.6531    0.4968    0.5643      1095
#           4     0.0000    0.0000    0.0000       298
#           5     0.8342    0.7506    0.7902       429
#
# avg / total     0.6724    0.6803    0.6274      6725
#
#              precision    recall  f1-score   support
#
#           0     0.9032    0.0431    0.0822      1950
#           1     0.6709    0.9916    0.8003     10617
#           2     0.6345    0.5814    0.6067      7037
#           3     0.6238    0.4224    0.5037      4377
#           4     0.0000    0.0000    0.0000      1189
#           5     0.7863    0.7734    0.7798      1717
#
# avg / total     0.6483    0.6650    0.6126     26887
#
# 26891
# 6721
#              precision    recall  f1-score   support
#
#           0     1.0000    0.0307    0.0596       488
#           1     0.6826    0.9917    0.8086      2654
#           2     0.6453    0.5998    0.6217      1759
#           3     0.6164    0.4260    0.5038      1094
#           4     0.0000    0.0000    0.0000       297
#           5     0.7974    0.8531    0.8243       429
#
# avg / total     0.6623    0.6746    0.6210      6721
#
#              precision    recall  f1-score   support
#
#           0     0.8800    0.0338    0.0652      1950
#           1     0.6696    0.9921    0.7996     10618
#           2     0.6491    0.5655    0.6044      7038
#           3     0.6266    0.4692    0.5366      4378
#           4     0.0000    0.0000    0.0000      1190
#           5     0.7773    0.7583    0.7677      1717
#
# avg / total     0.6497    0.6670    0.6150     26891
#
# 26892
# 6720
#              precision    recall  f1-score   support
#
#           0     0.8696    0.0821    0.1501       487
#           1     0.6663    0.9932    0.7976      2654
#           2     0.6444    0.5378    0.5863      1759
#           3     0.6160    0.4516    0.5211      1094
#           4     0.0000    0.0000    0.0000       297
#           5     0.7991    0.8345    0.8164       429
#
# avg / total     0.6461    0.6658    0.6163      6720
#
#              precision    recall  f1-score   support
#
#           0     0.9417    0.0497    0.0944      1951
#           1     0.6738    0.9933    0.8029     10618
#           2     0.6467    0.5759    0.6092      7038
#           3     0.6101    0.4418    0.5125      4378
#           4     0.0000    0.0000    0.0000      1190
#           5     0.7715    0.7630    0.7672      1717
#
# avg / total     0.6522    0.6672    0.6157     26892
#
# 26892
# 6720
#              precision    recall  f1-score   support
#
#           0     0.9744    0.0780    0.1445       487
#           1     0.6643    0.9955    0.7969      2654
#           2     0.6445    0.5452    0.5907      1759
#           3     0.5902    0.4516    0.5117      1094
#           4     0.0000    0.0000    0.0000       297
#           5     0.7619    0.6713    0.7138       429
#
# avg / total     0.6464    0.6579    0.6087      6720
#
#              precision    recall  f1-score   support
#
#           0     0.9107    0.0523    0.0989      1951
#           1     0.6730    0.9922    0.8020     10618
#           2     0.6552    0.5683    0.6087      7038
#           3     0.6310    0.4913    0.5525      4378
#           4     0.0000    0.0000    0.0000      1190
#           5     0.8029    0.7542    0.7778      1717
#
# avg / total     0.6573    0.6724    0.6227     26892
# (array([[0.08811475, 0.00819672, 0.0307377 , 0.08213552, 0.07802875],
#         [0.98568738, 0.99246704, 0.99171063, 0.99321778, 0.99547852],
#         [0.59147727, 0.60795455, 0.5997726 , 0.53780557, 0.54519613],
#         [0.38082192, 0.49680365, 0.42595978, 0.45155393, 0.45155393],
#         [0.        , 0.        , 0.        , 0.        , 0.        ],
#         [0.68372093, 0.75058275, 0.85314685, 0.83449883, 0.67132867]]),
#  array([[0.1593, 0.0163, 0.0596, 0.1501, 0.1445],
#         [0.8019, 0.8082, 0.8086, 0.7976, 0.7969],
#         [0.6005, 0.6302, 0.6217, 0.5863, 0.5907],
#         [0.4704, 0.5643, 0.5038, 0.5211, 0.5117],
#         [0.    , 0.    , 0.    , 0.    , 0.    ],
#         [0.6942, 0.7902, 0.8243, 0.8164, 0.7138]]),
#  array([[0.07259312, 0.07259312, 0.07259312, 0.07244437, 0.07244437],
#         [0.39494823, 0.39494823, 0.39479948, 0.39479948, 0.39479948],
#         [0.26181126, 0.26181126, 0.2616625 , 0.2616625 , 0.2616625 ],
#         [0.16288825, 0.16288825, 0.1627395 , 0.1627395 , 0.1627395 ],
#         [0.04432941, 0.04432941, 0.04418065, 0.04418065, 0.04418065],
#         [0.06396525, 0.06381649, 0.06381649, 0.06381649, 0.06381649]]),
#  array([[0.06666667, 0.04307692, 0.03384615, 0.04971809, 0.05228088],
#         [0.99284167, 0.99161722, 0.99208891, 0.99331324, 0.99218309],
#         [0.58917152, 0.58135569, 0.56550156, 0.57587383, 0.56834328],
#         [0.45419237, 0.42243546, 0.469164  , 0.44175423, 0.49132024],
#         [0.        , 0.        , 0.        , 0.        , 0.        ],
#         [0.77797203, 0.77344205, 0.75829936, 0.76295865, 0.75422248]]),
#  array([[0.1246, 0.0822, 0.0652, 0.0944, 0.0989],
#         [0.8081, 0.8003, 0.7996, 0.8029, 0.802 ],
#         [0.6173, 0.6067, 0.6044, 0.6092, 0.6087],
#         [0.5247, 0.5037, 0.5366, 0.5125, 0.5525],
#         [0.    , 0.    , 0.    , 0.    , 0.    ],
#         [0.7881, 0.7798, 0.7677, 0.7672, 0.7778]]),
#  array([[0.07251874, 0.07251874, 0.07251874, 0.07255593, 0.07255593],
#         [0.39483667, 0.39483667, 0.39487385, 0.39487385, 0.39487385],
#         [0.26169969, 0.26169969, 0.26173688, 0.26173688, 0.26173688],
#         [0.16277669, 0.16277669, 0.16281388, 0.16281388, 0.16281388],
#         [0.04421784, 0.04421784, 0.04425503, 0.04425503, 0.04425503],
#         [0.06381649, 0.06385368, 0.06385368, 0.06385368, 0.06385368]]),
#  array([0.05744269, 0.99171227, 0.57644122, 0.44133864, 0.        ,
#         0.75865561]),
#  array([0.04911774, 0.99240882, 0.57604918, 0.45577326, 0.        ,
#         0.76537891]),
#  array([0.10596, 0.80264, 0.60588, 0.51426, 0.     , 0.76778]),
#  array([0.09306, 0.80258, 0.60926, 0.526  , 0.     , 0.77612]),
#  0.4709317394643266,
#  0.4731213193594515,
#  0.6159117082268315,
#  0.6183006208171393,
#  0.00939101967110771,
#  0.00939101967110771,
#  0.007817937690985804,
#  0.007817937690985804,
#  array([0.05744269, 0.99171227, 0.57644122, 0.44133864, 0.        ,
#         0.75865561]),
#  array([0.04911774, 0.99240882, 0.57604918, 0.45577326, 0.        ,
#         0.76537891]),
#  array([0.03197693, 0.00326558, 0.02909465, 0.03790476, 0.        ,
#         0.07481599]),
#  array([0.01084475, 0.00059754, 0.00861416, 0.02346632, 0.        ,
#         0.00898938]),
#  array([0.10596, 0.80264, 0.60588, 0.51426, 0.     , 0.76778]),
#  array([0.09306, 0.80258, 0.60926, 0.526  , 0.     , 0.77612]),
#  array([0.05738814, 0.00500664, 0.01723072, 0.03030001, 0.        ,
#         0.053645  ]),
#  array([0.01962036, 0.0029996 , 0.00436193, 0.01729647, 0.        ,
#         0.00787843]))
