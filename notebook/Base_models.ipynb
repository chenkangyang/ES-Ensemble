# %%
import os
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append("..") 
from gcforest.gcforest import GCForest
# Out:
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# hyperparameters

# %%
random_seed = 42
cv=5
score = 'f1_weighted'

# %% [markdown]
# #### somte sampling

# %%
def Smoter(X, y, is_random=False):
    if is_random == True:
        random_lst = list(np.random.randint(0, 1000, 4))
    elif is_random == False:
        random_lst = [0] * 4

    print("rs:", random_lst)
    sm = SMOTE(random_state=random_lst[2], kind = 0.24)
    X_smote, y_smote = sm.fit_sample(X, y)

    return X_smote, y_smote

# %%
def get_toy_config():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 20
    ca_config["early_stopping_rounds"] = 5
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %% [markdown]
# # load data_four_features

# %%
path = os.getcwd()+'/../data/20122018freshwater_four_feature.csv'
data_four_features = pd.read_csv(path, na_values = np.nan)

print(data_four_features.dtypes)
print(data_four_features.shape)
# Out:
# pH             float64
# DO(mg/l)       float64
# CODMn(mg/l)    float64
# NH3-N(mg/l)    float64
# 本周水质             int64
# dtype: object
# (33612, 5)

# %%
X = data_four_features.drop(['本周水质'], axis=1) # Series
y = data_four_features['本周水质']-1 # Series

# %%
print("水质分布情况:")
print(y.value_counts())
print("\n各特征类型分布情况:")
print(data_four_features.dtypes.value_counts())
# Out:
# 水质分布情况:
# 1    13272
# 2     8797
# 3     5472
# 0     2438
# 5     2146
# 4     1487
# Name: 本周水质, dtype: int64
#
# 各特征类型分布情况:
# float64    4
# int64      1
# dtype: int64

# %%
data_four_features.head()
# Out:
#      pH  DO(mg/l)  CODMn(mg/l)  NH3-N(mg/l)  本周水质
# 0  7.09      10.0          5.7         0.33     3
# 1  6.94      12.0          5.4         0.40     3
# 2  7.20       9.6          4.9         0.34     3
# 3  6.80      11.6          6.3         0.59     4
# 4  6.75      11.0          6.2         0.64     4

# %% [markdown]
# train 80%, test 20%

# %%
print("============ train_test_split ============")
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                       stratify = y, random_state = random_seed)
print("80%% train: %d/%d, 20%% test: %d/%d" %(X_train.shape[0], X.shape[0], X_test.shape[0], X.shape[0]))
# Out:
# ============ train_test_split ============
# 80% train: 26889/33612, 20% test: 6723/33612

# %% [markdown]
# ### normalize  train data
#
# fulfill the Na with median, then standardized the data, output type ndarray

# %%
clean_pipeline = Pipeline([('imputer', preprocessing.Imputer(missing_values='NaN',strategy="median")),
                           ('std_scaler', preprocessing.StandardScaler()),])
X_train = clean_pipeline.fit_transform(X_train)
X_test = clean_pipeline.fit_transform(X_test)

# %% [markdown]
# # model train & test

# %%
y_train = y_train.values
y_test = y_test.values

# %%
config = get_toy_config()

models = [
    LogisticRegression(),
    LinearDiscriminantAnalysis(),
    SVC(probability=True),
    DecisionTreeClassifier(),
    ExtraTreeClassifier(),
    GaussianNB(),
    KNeighborsClassifier(),
    RandomForestClassifier(random_state=random_seed),
    ExtraTreesClassifier(random_state=random_seed),
    GCForest(config)
]

# %%
test_entries = []
train_entries = []

for model in models:
    model_name = model.__class__.__name__
    if model_name == 'GCForest':
        model.fit_transform(X_train, y_train, X_test, y_test)
    else:
        model.fit(X_train, y_train)
    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    f1_train = f1_score(y_train, y_train_pred, average='weighted')
    f1_test = f1_score(y_test, y_test_pred, average='weighted')
    acc_train = accuracy_score(y_train, y_train_pred)
    acc_test = accuracy_score(y_test, y_test_pred)
    train_entries.append((model_name, f1_train, acc_train))
    test_entries.append((model_name, f1_test, acc_test))
    # print("%s, test set: weighted F1 score:%f, Accuracy:%f" %(model_name, f1_score(y_valid, y_pred, average="weighted"), accuracy_score(y_valid, y_pred)))
    
train_df = pd.DataFrame(train_entries, columns=['model_name', 'train_f1_weighted', 'train_accuracy'])
test_df = pd.DataFrame(test_entries, columns=['model_name', 'test_f1_weighted', 'test_accuracy'])
# Out:
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [ 2019-04-02 23:36:24,565][cascade_classifier.fit_transform] X_groups_train.shape=[(26889, 4)],y_train.shape=(26889,),X_groups_test.shape=[(6723, 4)],y_test.shape=(6723,)
# [ 2019-04-02 23:36:24,566][cascade_classifier.fit_transform] group_dims=[4]
# [ 2019-04-02 23:36:24,567][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-04-02 23:36:24,568][cascade_classifier.fit_transform] group_ends=[4]
# [ 2019-04-02 23:36:24,570][cascade_classifier.fit_transform] X_train.shape=(26889, 4),X_test.shape=(6723, 4)
# [ 2019-04-02 23:36:24,577][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(26889, 4), X_cur_test.shape=(6723, 4)
# [ 2019-04-02 23:36:24,975][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_0.predict)=99.42%
# [ 2019-04-02 23:36:25,223][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_1.predict)=99.33%
# [ 2019-04-02 23:36:25,420][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_2.predict)=99.35%
# [ 2019-04-02 23:36:25,596][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_3.predict)=99.57%
# [ 2019-04-02 23:36:25,768][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_4.predict)=99.40%
# [ 2019-04-02 23:36:25,784][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:36:25,787][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:36:25,982][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_0.predict)=99.44%
# [ 2019-04-02 23:36:26,160][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_1.predict)=99.29%
# [ 2019-04-02 23:36:26,332][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_2.predict)=99.46%
# [ 2019-04-02 23:36:26,543][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_3.predict)=99.24%
# [ 2019-04-02 23:36:26,752][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_4.predict)=99.37%
# [ 2019-04-02 23:36:26,774][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_cv.predict)=99.36%
# [ 2019-04-02 23:36:26,777][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:36:27,025][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_0.predict)=99.39%
# [ 2019-04-02 23:36:27,241][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_1.predict)=99.37%
# [ 2019-04-02 23:36:27,418][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_2.predict)=99.37%
# [ 2019-04-02 23:36:27,611][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_3.predict)=99.55%
# [ 2019-04-02 23:36:27,805][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_4.predict)=99.35%
# [ 2019-04-02 23:36:27,819][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_cv.predict)=99.40%
# [ 2019-04-02 23:36:27,822][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:36:28,020][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_0.predict)=99.52%
# [ 2019-04-02 23:36:28,235][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_1.predict)=99.42%
# [ 2019-04-02 23:36:28,446][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_2.predict)=99.42%
# [ 2019-04-02 23:36:28,630][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_3.predict)=99.35%
# [ 2019-04-02 23:36:28,863][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_4.predict)=99.39%
# [ 2019-04-02 23:36:28,876][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:36:28,879][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:36:28,934][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_0.predict)=98.83%
# [ 2019-04-02 23:36:28,977][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_1.predict)=98.87%
# [ 2019-04-02 23:36:29,021][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_2.predict)=98.72%
# [ 2019-04-02 23:36:29,077][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_3.predict)=98.85%
# [ 2019-04-02 23:36:29,146][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_4.predict)=98.75%
# [ 2019-04-02 23:36:29,158][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_cv.predict)=98.80%
# [ 2019-04-02 23:36:29,166][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.test.predict)=97.34%
# [ 2019-04-02 23:36:29,252][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_0.predict)=98.87%
# [ 2019-04-02 23:36:29,320][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_1.predict)=98.59%
# [ 2019-04-02 23:36:29,376][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_2.predict)=99.01%
# [ 2019-04-02 23:36:29,420][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_3.predict)=98.88%
# [ 2019-04-02 23:36:29,467][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_4.predict)=98.70%
# [ 2019-04-02 23:36:29,475][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_cv.predict)=98.81%
# [ 2019-04-02 23:36:29,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.test.predict)=97.38%
# [ 2019-04-02 23:36:29,536][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_0.predict)=98.77%
# [ 2019-04-02 23:36:29,591][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_1.predict)=98.83%
# [ 2019-04-02 23:36:29,634][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_2.predict)=98.79%
# [ 2019-04-02 23:36:29,688][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_3.predict)=98.72%
# [ 2019-04-02 23:36:29,730][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_4.predict)=98.85%
# [ 2019-04-02 23:36:29,738][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_cv.predict)=98.79%
# [ 2019-04-02 23:36:29,741][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.test.predict)=97.35%
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [ 2019-04-02 23:36:29,863][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_0.predict)=60.47%
# [ 2019-04-02 23:36:30,034][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_1.predict)=61.23%
# [ 2019-04-02 23:36:30,217][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_2.predict)=62.50%
# [ 2019-04-02 23:36:30,342][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_3.predict)=62.05%
# [ 2019-04-02 23:36:30,451][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_4.predict)=61.41%
# [ 2019-04-02 23:36:30,459][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_cv.predict)=61.53%
# [ 2019-04-02 23:36:30,465][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.test.predict)=62.14%
# [ 2019-04-02 23:36:30,481][cascade_classifier.calc_f1] Weighted F1 (layer_0 - train.classifier_average)=99.36%
# [ 2019-04-02 23:36:30,483][cascade_classifier.calc_f1] Weighted F1 (layer_0 - test.classifier_average)=97.56%
# [ 2019-04-02 23:36:30,495][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(26889, 52), X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:36:30,922][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_0.predict)=99.46%
# [ 2019-04-02 23:36:31,282][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_1.predict)=99.44%
# [ 2019-04-02 23:36:31,558][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_2.predict)=99.46%
# [ 2019-04-02 23:36:31,918][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_3.predict)=99.39%
# [ 2019-04-02 23:36:32,280][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_4.predict)=99.48%
# [ 2019-04-02 23:36:32,302][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_cv.predict)=99.45%
# [ 2019-04-02 23:36:32,306][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:36:32,960][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_0.predict)=99.44%
# [ 2019-04-02 23:36:33,299][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_1.predict)=99.50%
# [ 2019-04-02 23:36:33,574][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_2.predict)=99.41%
# [ 2019-04-02 23:36:33,881][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_3.predict)=99.52%
# [ 2019-04-02 23:36:34,164][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_4.predict)=99.39%
# [ 2019-04-02 23:36:34,179][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_cv.predict)=99.45%
# [ 2019-04-02 23:36:34,182][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:36:34,486][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_0.predict)=99.35%
# [ 2019-04-02 23:36:34,814][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_1.predict)=99.39%
# [ 2019-04-02 23:36:35,214][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_2.predict)=99.59%
# [ 2019-04-02 23:36:35,573][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_3.predict)=99.44%
# [ 2019-04-02 23:36:35,862][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_4.predict)=99.44%
# [ 2019-04-02 23:36:35,878][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:36:35,881][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:36:36,206][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_0.predict)=99.46%
# [ 2019-04-02 23:36:36,550][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_1.predict)=99.33%
# [ 2019-04-02 23:36:36,828][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_2.predict)=99.40%
# [ 2019-04-02 23:36:37,110][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_3.predict)=99.50%
# [ 2019-04-02 23:36:37,439][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_4.predict)=99.52%
# [ 2019-04-02 23:36:37,454][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:36:37,458][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:36:37,757][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_0.predict)=98.55%
# [ 2019-04-02 23:36:38,052][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_1.predict)=98.96%
# [ 2019-04-02 23:36:38,401][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_2.predict)=98.64%
# [ 2019-04-02 23:36:38,782][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_3.predict)=99.00%
# [ 2019-04-02 23:36:39,099][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_4.predict)=98.81%
# [ 2019-04-02 23:36:39,108][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_cv.predict)=98.79%
# [ 2019-04-02 23:36:39,111][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.test.predict)=97.47%
# [ 2019-04-02 23:36:39,437][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_0.predict)=98.85%
# [ 2019-04-02 23:36:39,753][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_1.predict)=98.85%
# [ 2019-04-02 23:36:40,083][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_2.predict)=98.75%
# [ 2019-04-02 23:36:40,419][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_3.predict)=98.85%
# [ 2019-04-02 23:36:40,784][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_4.predict)=98.94%
# [ 2019-04-02 23:36:40,794][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_cv.predict)=98.85%
# [ 2019-04-02 23:36:40,797][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.test.predict)=97.50%
# [ 2019-04-02 23:36:41,119][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_0.predict)=98.64%
# [ 2019-04-02 23:36:41,459][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_1.predict)=98.77%
# [ 2019-04-02 23:36:41,777][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_2.predict)=98.76%
# [ 2019-04-02 23:36:42,077][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_3.predict)=98.66%
# [ 2019-04-02 23:36:42,408][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_4.predict)=99.05%
# [ 2019-04-02 23:36:42,417][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_cv.predict)=98.78%
# [ 2019-04-02 23:36:42,428][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.test.predict)=97.44%
# [ 2019-04-02 23:36:43,457][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_0.predict)=99.39%
# [ 2019-04-02 23:36:44,422][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_1.predict)=99.42%
# [ 2019-04-02 23:36:45,381][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_2.predict)=99.40%
# [ 2019-04-02 23:36:46,388][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_3.predict)=99.52%
# [ 2019-04-02 23:36:47,294][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_4.predict)=99.41%
# [ 2019-04-02 23:36:47,306][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:36:47,311][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:36:47,331][cascade_classifier.calc_f1] Weighted F1 (layer_1 - train.classifier_average)=99.44%
# [ 2019-04-02 23:36:47,337][cascade_classifier.calc_f1] Weighted F1 (layer_1 - test.classifier_average)=97.59%
# [ 2019-04-02 23:36:47,346][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(26889, 52), X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:36:47,614][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_0.predict)=99.26%
# [ 2019-04-02 23:36:47,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_1.predict)=99.50%
# [ 2019-04-02 23:36:48,189][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_2.predict)=99.44%
# [ 2019-04-02 23:36:48,460][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_3.predict)=99.54%
# [ 2019-04-02 23:36:48,740][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_4.predict)=99.48%
# [ 2019-04-02 23:36:48,755][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:36:48,760][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:36:49,044][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_0.predict)=99.33%
# [ 2019-04-02 23:36:49,316][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_1.predict)=99.57%
# [ 2019-04-02 23:36:49,597][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_2.predict)=99.35%
# [ 2019-04-02 23:36:49,870][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_3.predict)=99.50%
# [ 2019-04-02 23:36:50,140][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_4.predict)=99.46%
# [ 2019-04-02 23:36:50,155][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:36:50,159][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:36:50,449][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_0.predict)=99.55%
# [ 2019-04-02 23:36:50,708][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_1.predict)=99.44%
# [ 2019-04-02 23:36:50,969][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_2.predict)=99.55%
# [ 2019-04-02 23:36:51,253][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_3.predict)=99.42%
# [ 2019-04-02 23:36:51,512][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_4.predict)=99.26%
# [ 2019-04-02 23:36:51,528][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_cv.predict)=99.45%
# [ 2019-04-02 23:36:51,532][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:36:51,823][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_0.predict)=99.50%
# [ 2019-04-02 23:36:52,085][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_1.predict)=99.39%
# [ 2019-04-02 23:36:52,331][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_2.predict)=99.44%
# [ 2019-04-02 23:36:52,604][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_3.predict)=99.50%
# [ 2019-04-02 23:36:52,879][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_4.predict)=99.37%
# [ 2019-04-02 23:36:52,896][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:36:52,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:36:53,204][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_0.predict)=98.89%
# [ 2019-04-02 23:36:53,581][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_1.predict)=98.90%
# [ 2019-04-02 23:36:54,089][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_2.predict)=99.07%
# [ 2019-04-02 23:36:54,366][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_3.predict)=98.66%
# [ 2019-04-02 23:36:54,642][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_4.predict)=98.96%
# [ 2019-04-02 23:36:54,650][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_cv.predict)=98.90%
# [ 2019-04-02 23:36:54,653][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:36:54,981][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_0.predict)=98.68%
# [ 2019-04-02 23:36:55,278][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_1.predict)=98.77%
# [ 2019-04-02 23:36:55,511][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_2.predict)=98.46%
# [ 2019-04-02 23:36:55,801][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_3.predict)=98.94%
# [ 2019-04-02 23:36:56,149][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_4.predict)=98.85%
# [ 2019-04-02 23:36:56,157][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_cv.predict)=98.74%
# [ 2019-04-02 23:36:56,160][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:36:56,483][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_0.predict)=98.85%
# [ 2019-04-02 23:36:56,742][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_1.predict)=98.62%
# [ 2019-04-02 23:36:57,003][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_2.predict)=98.98%
# [ 2019-04-02 23:36:57,288][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_3.predict)=99.03%
# [ 2019-04-02 23:36:57,598][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_4.predict)=98.79%
# [ 2019-04-02 23:36:57,607][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_cv.predict)=98.85%
# [ 2019-04-02 23:36:57,609][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:36:58,389][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_0.predict)=99.33%
# [ 2019-04-02 23:36:59,234][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_1.predict)=99.39%
# [ 2019-04-02 23:37:00,135][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_2.predict)=99.55%
# [ 2019-04-02 23:37:00,832][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_3.predict)=99.42%
# [ 2019-04-02 23:37:01,533][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_4.predict)=99.54%
# [ 2019-04-02 23:37:01,542][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_cv.predict)=99.45%
# [ 2019-04-02 23:37:01,545][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:01,553][cascade_classifier.calc_f1] Weighted F1 (layer_2 - train.classifier_average)=99.43%
# [ 2019-04-02 23:37:01,556][cascade_classifier.calc_f1] Weighted F1 (layer_2 - test.classifier_average)=97.62%
# [ 2019-04-02 23:37:01,563][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(26889, 52), X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:37:01,820][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_0.predict)=99.39%
# [ 2019-04-02 23:37:02,083][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_1.predict)=99.44%
# [ 2019-04-02 23:37:02,339][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_2.predict)=99.48%
# [ 2019-04-02 23:37:02,593][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_3.predict)=99.37%
# [ 2019-04-02 23:37:02,844][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_4.predict)=99.50%
# [ 2019-04-02 23:37:02,858][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:37:02,862][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:37:03,115][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_0.predict)=99.39%
# [ 2019-04-02 23:37:03,365][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_1.predict)=99.37%
# [ 2019-04-02 23:37:03,627][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_2.predict)=99.50%
# [ 2019-04-02 23:37:03,884][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_3.predict)=99.44%
# [ 2019-04-02 23:37:04,141][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_4.predict)=99.50%
# [ 2019-04-02 23:37:04,155][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:37:04,159][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:37:04,429][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_0.predict)=99.55%
# [ 2019-04-02 23:37:04,678][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_1.predict)=99.41%
# [ 2019-04-02 23:37:04,933][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_2.predict)=99.57%
# [ 2019-04-02 23:37:05,188][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_3.predict)=99.29%
# [ 2019-04-02 23:37:05,423][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_4.predict)=99.33%
# [ 2019-04-02 23:37:05,437][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:37:05,440][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:05,675][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_0.predict)=99.39%
# [ 2019-04-02 23:37:05,908][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_1.predict)=99.44%
# [ 2019-04-02 23:37:06,140][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_2.predict)=99.31%
# [ 2019-04-02 23:37:06,380][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_3.predict)=99.57%
# [ 2019-04-02 23:37:06,621][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_4.predict)=99.50%
# [ 2019-04-02 23:37:06,636][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:37:06,639][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:06,921][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_0.predict)=98.66%
# [ 2019-04-02 23:37:07,180][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_1.predict)=98.75%
# [ 2019-04-02 23:37:07,436][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_2.predict)=98.85%
# [ 2019-04-02 23:37:07,670][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_3.predict)=98.87%
# [ 2019-04-02 23:37:07,928][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_4.predict)=98.75%
# [ 2019-04-02 23:37:07,936][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_cv.predict)=98.78%
# [ 2019-04-02 23:37:07,939][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.test.predict)=97.52%
# [ 2019-04-02 23:37:08,203][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_0.predict)=98.70%
# [ 2019-04-02 23:37:08,455][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_1.predict)=98.92%
# [ 2019-04-02 23:37:08,692][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_2.predict)=99.05%
# [ 2019-04-02 23:37:08,964][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_3.predict)=98.88%
# [ 2019-04-02 23:37:09,205][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_4.predict)=98.73%
# [ 2019-04-02 23:37:09,213][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_cv.predict)=98.86%
# [ 2019-04-02 23:37:09,216][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.test.predict)=97.50%
# [ 2019-04-02 23:37:09,474][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_0.predict)=98.81%
# [ 2019-04-02 23:37:09,708][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_1.predict)=98.83%
# [ 2019-04-02 23:37:09,967][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_2.predict)=98.79%
# [ 2019-04-02 23:37:10,220][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_3.predict)=98.77%
# [ 2019-04-02 23:37:10,455][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_4.predict)=98.62%
# [ 2019-04-02 23:37:10,463][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_cv.predict)=98.76%
# [ 2019-04-02 23:37:10,466][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.test.predict)=97.47%
# [ 2019-04-02 23:37:11,193][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_0.predict)=99.52%
# [ 2019-04-02 23:37:11,907][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_1.predict)=99.40%
# [ 2019-04-02 23:37:12,616][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_2.predict)=99.42%
# [ 2019-04-02 23:37:13,315][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_3.predict)=99.39%
# [ 2019-04-02 23:37:14,020][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_4.predict)=99.48%
# [ 2019-04-02 23:37:14,029][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:37:14,032][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:37:14,041][cascade_classifier.calc_f1] Weighted F1 (layer_3 - train.classifier_average)=99.44%
# [ 2019-04-02 23:37:14,044][cascade_classifier.calc_f1] Weighted F1 (layer_3 - test.classifier_average)=97.59%
# [ 2019-04-02 23:37:14,052][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(26889, 52), X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:37:14,302][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_0.predict)=99.37%
# [ 2019-04-02 23:37:14,547][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_1.predict)=99.50%
# [ 2019-04-02 23:37:14,778][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_2.predict)=99.41%
# [ 2019-04-02 23:37:15,020][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_3.predict)=99.40%
# [ 2019-04-02 23:37:15,262][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_4.predict)=99.53%
# [ 2019-04-02 23:37:15,277][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:37:15,280][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:37:15,530][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_0.predict)=99.50%
# [ 2019-04-02 23:37:15,774][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_1.predict)=99.54%
# [ 2019-04-02 23:37:16,016][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_2.predict)=99.44%
# [ 2019-04-02 23:37:16,252][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_3.predict)=99.24%
# [ 2019-04-02 23:37:16,501][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_4.predict)=99.48%
# [ 2019-04-02 23:37:16,516][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:37:16,519][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:16,766][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_0.predict)=99.37%
# [ 2019-04-02 23:37:17,014][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_1.predict)=99.50%
# [ 2019-04-02 23:37:17,298][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_2.predict)=99.41%
# [ 2019-04-02 23:37:17,588][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_3.predict)=99.59%
# [ 2019-04-02 23:37:17,834][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_4.predict)=99.31%
# [ 2019-04-02 23:37:17,848][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:37:17,852][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:18,106][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_0.predict)=99.46%
# [ 2019-04-02 23:37:18,418][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_1.predict)=99.57%
# [ 2019-04-02 23:37:18,661][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_2.predict)=99.40%
# [ 2019-04-02 23:37:18,894][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_3.predict)=99.31%
# [ 2019-04-02 23:37:19,136][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_4.predict)=99.42%
# [ 2019-04-02 23:37:19,151][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:37:19,154][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:19,424][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_0.predict)=98.92%
# [ 2019-04-02 23:37:19,670][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_1.predict)=98.55%
# [ 2019-04-02 23:37:19,918][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_2.predict)=98.72%
# [ 2019-04-02 23:37:20,179][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_3.predict)=98.72%
# [ 2019-04-02 23:37:20,434][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_4.predict)=98.49%
# [ 2019-04-02 23:37:20,443][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_cv.predict)=98.68%
# [ 2019-04-02 23:37:20,446][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:37:20,710][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_0.predict)=98.76%
# [ 2019-04-02 23:37:20,959][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_1.predict)=98.79%
# [ 2019-04-02 23:37:21,227][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_2.predict)=98.94%
# [ 2019-04-02 23:37:21,490][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_3.predict)=98.98%
# [ 2019-04-02 23:37:21,755][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_4.predict)=98.96%
# [ 2019-04-02 23:37:21,764][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_cv.predict)=98.88%
# [ 2019-04-02 23:37:21,767][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.test.predict)=97.56%
# [ 2019-04-02 23:37:22,104][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_0.predict)=99.02%
# [ 2019-04-02 23:37:22,386][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_1.predict)=98.88%
# [ 2019-04-02 23:37:22,651][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_2.predict)=98.63%
# [ 2019-04-02 23:37:22,951][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_3.predict)=98.75%
# [ 2019-04-02 23:37:23,201][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_4.predict)=98.83%
# [ 2019-04-02 23:37:23,210][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_cv.predict)=98.82%
# [ 2019-04-02 23:37:23,213][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.test.predict)=97.56%
# [ 2019-04-02 23:37:24,082][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_0.predict)=99.50%
# [ 2019-04-02 23:37:24,906][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_1.predict)=99.41%
# [ 2019-04-02 23:37:25,609][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_2.predict)=99.54%
# [ 2019-04-02 23:37:26,284][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_3.predict)=99.39%
# [ 2019-04-02 23:37:26,937][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_4.predict)=99.37%
# [ 2019-04-02 23:37:26,945][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:37:26,948][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:26,959][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=99.43%
# [ 2019-04-02 23:37:26,965][cascade_classifier.calc_f1] Weighted F1 (layer_4 - test.classifier_average)=97.59%
# [ 2019-04-02 23:37:26,973][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(26889, 52), X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:37:27,227][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=99.53%
# [ 2019-04-02 23:37:27,482][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=99.41%
# [ 2019-04-02 23:37:27,719][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=99.24%
# [ 2019-04-02 23:37:27,968][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=99.33%
# [ 2019-04-02 23:37:28,218][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=99.63%
# [ 2019-04-02 23:37:28,233][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:37:28,236][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:37:28,490][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=99.54%
# [ 2019-04-02 23:37:28,734][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=99.52%
# [ 2019-04-02 23:37:28,963][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=99.29%
# [ 2019-04-02 23:37:29,219][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=99.35%
# [ 2019-04-02 23:37:29,452][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=99.50%
# [ 2019-04-02 23:37:29,467][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=99.44%
# [ 2019-04-02 23:37:29,471][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:37:29,723][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_0.predict)=99.46%
# [ 2019-04-02 23:37:29,959][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_1.predict)=99.46%
# [ 2019-04-02 23:37:30,314][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_2.predict)=99.35%
# [ 2019-04-02 23:37:30,565][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_3.predict)=99.50%
# [ 2019-04-02 23:37:30,819][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_4.predict)=99.35%
# [ 2019-04-02 23:37:30,833][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:37:30,837][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:37:31,185][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_0.predict)=99.33%
# [ 2019-04-02 23:37:31,431][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_1.predict)=99.59%
# [ 2019-04-02 23:37:31,692][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_2.predict)=99.29%
# [ 2019-04-02 23:37:31,950][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_3.predict)=99.52%
# [ 2019-04-02 23:37:32,222][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_4.predict)=99.40%
# [ 2019-04-02 23:37:32,245][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:37:32,253][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:37:32,680][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_0.predict)=99.03%
# [ 2019-04-02 23:37:32,992][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_1.predict)=98.72%
# [ 2019-04-02 23:37:33,245][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_2.predict)=98.59%
# [ 2019-04-02 23:37:33,506][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_3.predict)=98.79%
# [ 2019-04-02 23:37:33,880][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_4.predict)=98.72%
# [ 2019-04-02 23:37:33,892][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_cv.predict)=98.77%
# [ 2019-04-02 23:37:33,897][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:34,192][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_0.predict)=98.92%
# [ 2019-04-02 23:37:34,464][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_1.predict)=99.03%
# [ 2019-04-02 23:37:34,790][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_2.predict)=98.70%
# [ 2019-04-02 23:37:35,069][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_3.predict)=99.01%
# [ 2019-04-02 23:37:35,379][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_4.predict)=98.83%
# [ 2019-04-02 23:37:35,392][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_cv.predict)=98.90%
# [ 2019-04-02 23:37:35,399][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:37:35,752][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_0.predict)=98.77%
# [ 2019-04-02 23:37:36,048][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_1.predict)=98.85%
# [ 2019-04-02 23:37:36,315][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=98.85%
# [ 2019-04-02 23:37:36,636][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=98.90%
# [ 2019-04-02 23:37:36,949][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=99.01%
# [ 2019-04-02 23:37:36,964][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=98.88%
# [ 2019-04-02 23:37:36,969][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.test.predict)=97.59%
# [ 2019-04-02 23:37:37,875][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.52%
# [ 2019-04-02 23:37:38,950][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.39%
# [ 2019-04-02 23:37:39,813][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.57%
# [ 2019-04-02 23:37:40,504][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.29%
# [ 2019-04-02 23:37:41,456][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.40%
# [ 2019-04-02 23:37:41,464][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:37:41,467][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:37:41,476][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.45%
# [ 2019-04-02 23:37:41,478][cascade_classifier.calc_f1] Weighted F1 (layer_5 - test.classifier_average)=97.62%
# [ 2019-04-02 23:37:41,486][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(26889, 52), X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:37:41,844][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_0.predict)=99.35%
# [ 2019-04-02 23:37:42,111][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_1.predict)=99.44%
# [ 2019-04-02 23:37:42,359][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_2.predict)=99.44%
# [ 2019-04-02 23:37:42,672][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_3.predict)=99.50%
# [ 2019-04-02 23:37:42,984][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_4.predict)=99.35%
# [ 2019-04-02 23:37:43,011][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:37:43,022][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:37:43,325][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_0.predict)=99.37%
# [ 2019-04-02 23:37:43,675][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_1.predict)=99.35%
# [ 2019-04-02 23:37:43,934][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_2.predict)=99.61%
# [ 2019-04-02 23:37:44,204][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_3.predict)=99.50%
# [ 2019-04-02 23:37:44,524][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_4.predict)=99.33%
# [ 2019-04-02 23:37:44,545][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_cv.predict)=99.43%
# ...
# [ 2019-04-02 23:38:29,332][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_1 - 5_folds.train_1.predict)=99.41%
# [ 2019-04-02 23:38:29,583][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_1 - 5_folds.train_2.predict)=99.42%
# [ 2019-04-02 23:38:29,859][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_1 - 5_folds.train_3.predict)=99.48%
# [ 2019-04-02 23:38:30,118][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_1 - 5_folds.train_4.predict)=99.39%
# [ 2019-04-02 23:38:30,133][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_1 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:38:30,136][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_1 - 5_folds.test.predict)=97.65%
# [ 2019-04-02 23:38:30,413][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_2 - 5_folds.train_0.predict)=99.53%
# [ 2019-04-02 23:38:30,661][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_2 - 5_folds.train_1.predict)=99.46%
# [ 2019-04-02 23:38:30,923][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_2 - 5_folds.train_2.predict)=99.37%
# [ 2019-04-02 23:38:31,173][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_2 - 5_folds.train_3.predict)=99.33%
# [ 2019-04-02 23:38:31,455][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_2 - 5_folds.train_4.predict)=99.41%
# [ 2019-04-02 23:38:31,471][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_2 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:38:31,474][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_2 - 5_folds.test.predict)=97.65%
# [ 2019-04-02 23:38:31,738][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_3 - 5_folds.train_0.predict)=99.24%
# [ 2019-04-02 23:38:32,002][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_3 - 5_folds.train_1.predict)=99.46%
# [ 2019-04-02 23:38:32,253][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_3 - 5_folds.train_2.predict)=99.44%
# [ 2019-04-02 23:38:32,507][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_3 - 5_folds.train_3.predict)=99.52%
# [ 2019-04-02 23:38:32,766][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_3 - 5_folds.train_4.predict)=99.48%
# [ 2019-04-02 23:38:32,781][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_3 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:38:32,785][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_3 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:33,068][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_4 - 5_folds.train_0.predict)=98.57%
# [ 2019-04-02 23:38:33,308][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_4 - 5_folds.train_1.predict)=98.49%
# [ 2019-04-02 23:38:33,569][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_4 - 5_folds.train_2.predict)=98.96%
# [ 2019-04-02 23:38:33,844][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_4 - 5_folds.train_3.predict)=98.66%
# [ 2019-04-02 23:38:34,130][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_4 - 5_folds.train_4.predict)=98.96%
# [ 2019-04-02 23:38:34,139][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_4 - 5_folds.train_cv.predict)=98.73%
# [ 2019-04-02 23:38:34,142][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_4 - 5_folds.test.predict)=97.65%
# [ 2019-04-02 23:38:34,410][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_5 - 5_folds.train_0.predict)=98.96%
# [ 2019-04-02 23:38:34,665][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_5 - 5_folds.train_1.predict)=98.66%
# [ 2019-04-02 23:38:34,954][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_5 - 5_folds.train_2.predict)=99.00%
# [ 2019-04-02 23:38:35,218][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_5 - 5_folds.train_3.predict)=98.77%
# [ 2019-04-02 23:38:35,514][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_5 - 5_folds.train_4.predict)=98.70%
# [ 2019-04-02 23:38:35,523][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_5 - 5_folds.train_cv.predict)=98.82%
# [ 2019-04-02 23:38:35,526][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_5 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:35,796][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_6 - 5_folds.train_0.predict)=98.83%
# [ 2019-04-02 23:38:36,064][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_6 - 5_folds.train_1.predict)=98.66%
# [ 2019-04-02 23:38:36,332][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_6 - 5_folds.train_2.predict)=98.74%
# [ 2019-04-02 23:38:36,610][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_6 - 5_folds.train_3.predict)=98.73%
# [ 2019-04-02 23:38:36,894][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_6 - 5_folds.train_4.predict)=98.59%
# [ 2019-04-02 23:38:36,903][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_6 - 5_folds.train_cv.predict)=98.71%
# [ 2019-04-02 23:38:36,905][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_6 - 5_folds.test.predict)=97.62%
# [ 2019-04-02 23:38:37,766][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_7 - 5_folds.train_0.predict)=99.39%
# [ 2019-04-02 23:38:38,600][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_7 - 5_folds.train_1.predict)=99.35%
# [ 2019-04-02 23:38:39,625][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_7 - 5_folds.train_2.predict)=99.59%
# [ 2019-04-02 23:38:40,821][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_7 - 5_folds.train_3.predict)=99.55%
# [ 2019-04-02 23:38:41,706][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_7 - 5_folds.train_4.predict)=99.27%
# [ 2019-04-02 23:38:41,714][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_7 - 5_folds.train_cv.predict)=99.43%
# [ 2019-04-02 23:38:41,717][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_9 - estimator_7 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:41,727][cascade_classifier.calc_f1] Weighted F1 (layer_9 - train.classifier_average)=99.42%
# [ 2019-04-02 23:38:41,729][cascade_classifier.calc_f1] Weighted F1 (layer_9 - test.classifier_average)=97.63%
# [ 2019-04-02 23:38:41,740][cascade_classifier.fit_transform] [layer=10] look_indexs=[0], X_cur_train.shape=(26889, 52), X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:38:42,047][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_0 - 5_folds.train_0.predict)=99.48%
# [ 2019-04-02 23:38:42,316][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_0 - 5_folds.train_1.predict)=99.33%
# [ 2019-04-02 23:38:42,622][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_0 - 5_folds.train_2.predict)=99.46%
# [ 2019-04-02 23:38:42,992][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_0 - 5_folds.train_3.predict)=99.31%
# [ 2019-04-02 23:38:43,282][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_0 - 5_folds.train_4.predict)=99.50%
# [ 2019-04-02 23:38:43,297][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_0 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:38:43,301][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_0 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:43,649][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_1 - 5_folds.train_0.predict)=99.54%
# [ 2019-04-02 23:38:43,991][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_1 - 5_folds.train_1.predict)=99.46%
# [ 2019-04-02 23:38:44,296][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_1 - 5_folds.train_2.predict)=99.48%
# [ 2019-04-02 23:38:44,630][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_1 - 5_folds.train_3.predict)=99.27%
# [ 2019-04-02 23:38:44,907][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_1 - 5_folds.train_4.predict)=99.35%
# [ 2019-04-02 23:38:44,922][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_1 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:38:44,925][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_1 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:45,213][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_2 - 5_folds.train_0.predict)=99.48%
# [ 2019-04-02 23:38:45,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_2 - 5_folds.train_1.predict)=99.26%
# [ 2019-04-02 23:38:45,772][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_2 - 5_folds.train_2.predict)=99.52%
# [ 2019-04-02 23:38:46,030][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_2 - 5_folds.train_3.predict)=99.40%
# [ 2019-04-02 23:38:46,411][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_2 - 5_folds.train_4.predict)=99.44%
# [ 2019-04-02 23:38:46,438][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_2 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:38:46,446][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_2 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:46,763][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_3 - 5_folds.train_0.predict)=99.54%
# [ 2019-04-02 23:38:47,042][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_3 - 5_folds.train_1.predict)=99.26%
# [ 2019-04-02 23:38:47,328][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_3 - 5_folds.train_2.predict)=99.39%
# [ 2019-04-02 23:38:47,618][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_3 - 5_folds.train_3.predict)=99.44%
# [ 2019-04-02 23:38:47,907][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_3 - 5_folds.train_4.predict)=99.46%
# [ 2019-04-02 23:38:47,921][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_3 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:38:47,924][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_3 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:48,258][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_4 - 5_folds.train_0.predict)=98.79%
# [ 2019-04-02 23:38:48,597][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_4 - 5_folds.train_1.predict)=98.87%
# [ 2019-04-02 23:38:48,873][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_4 - 5_folds.train_2.predict)=98.66%
# [ 2019-04-02 23:38:49,171][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_4 - 5_folds.train_3.predict)=98.58%
# [ 2019-04-02 23:38:49,481][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_4 - 5_folds.train_4.predict)=98.92%
# [ 2019-04-02 23:38:49,490][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_4 - 5_folds.train_cv.predict)=98.76%
# [ 2019-04-02 23:38:49,493][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_4 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:49,812][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_5 - 5_folds.train_0.predict)=98.87%
# [ 2019-04-02 23:38:50,114][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_5 - 5_folds.train_1.predict)=99.01%
# [ 2019-04-02 23:38:50,429][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_5 - 5_folds.train_2.predict)=98.73%
# [ 2019-04-02 23:38:50,753][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_5 - 5_folds.train_3.predict)=98.64%
# [ 2019-04-02 23:38:51,052][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_5 - 5_folds.train_4.predict)=98.66%
# [ 2019-04-02 23:38:51,061][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_5 - 5_folds.train_cv.predict)=98.78%
# [ 2019-04-02 23:38:51,064][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_5 - 5_folds.test.predict)=97.60%
# [ 2019-04-02 23:38:51,376][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_6 - 5_folds.train_0.predict)=98.77%
# [ 2019-04-02 23:38:51,664][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_6 - 5_folds.train_1.predict)=98.79%
# [ 2019-04-02 23:38:51,936][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_6 - 5_folds.train_2.predict)=98.94%
# [ 2019-04-02 23:38:52,259][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_6 - 5_folds.train_3.predict)=98.73%
# [ 2019-04-02 23:38:52,649][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_6 - 5_folds.train_4.predict)=98.66%
# [ 2019-04-02 23:38:52,659][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_6 - 5_folds.train_cv.predict)=98.78%
# [ 2019-04-02 23:38:52,662][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_6 - 5_folds.test.predict)=97.63%
# [ 2019-04-02 23:38:53,580][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_7 - 5_folds.train_0.predict)=99.33%
# [ 2019-04-02 23:38:54,435][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_7 - 5_folds.train_1.predict)=99.42%
# [ 2019-04-02 23:38:55,263][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_7 - 5_folds.train_2.predict)=99.55%
# [ 2019-04-02 23:38:56,157][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_7 - 5_folds.train_3.predict)=99.42%
# [ 2019-04-02 23:38:57,023][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_7 - 5_folds.train_4.predict)=99.39%
# [ 2019-04-02 23:38:57,032][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_7 - 5_folds.train_cv.predict)=99.42%
# [ 2019-04-02 23:38:57,035][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_10 - estimator_7 - 5_folds.test.predict)=97.65%
# [ 2019-04-02 23:38:57,043][cascade_classifier.calc_f1] Weighted F1 (layer_10 - train.classifier_average)=99.42%
# [ 2019-04-02 23:38:57,046][cascade_classifier.calc_f1] Weighted F1 (layer_10 - test.classifier_average)=97.63%
# [ 2019-04-02 23:38:57,047][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=6, weighted_f1_train=99.45%, weighted_f1_test=97.62%
# [ 2019-04-02 23:38:57,060][cascade_classifier.transform] X_groups_test.shape=[(26889, 4)]
# [ 2019-04-02 23:38:57,064][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-02 23:38:57,067][cascade_classifier.transform] X_test.shape=(26889, 4)
# [ 2019-04-02 23:38:57,069][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(26889, 4)
# [ 2019-04-02 23:38:57,687][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:38:58,443][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:38:59,199][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:38:59,928][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:39:00,665][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:39:01,405][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-04-02 23:39:01,406][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-02 23:39:01,407][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-04-02 23:39:01,408][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-04-02 23:39:01,569][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:39:01,761][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:39:01,946][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:39:02,125][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:39:02,315][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(6723, 52)

# %%
train_df
# Out:
#                    model_name  train_f1_weighted  train_accuracy
# 0          LogisticRegression           0.617887        0.668712
# 1  LinearDiscriminantAnalysis           0.570242        0.619956
# 2                         SVC           0.899929        0.901038
# 3      DecisionTreeClassifier           1.000000        1.000000
# 4         ExtraTreeClassifier           1.000000        1.000000
# 5                  GaussianNB           0.815955        0.817807
# 6        KNeighborsClassifier           0.943844        0.943992
# 7      RandomForestClassifier           0.999182        0.999182
# 8        ExtraTreesClassifier           1.000000        1.000000
# 9                    GCForest           0.998030        0.998029

# %%
test_df
# Out:
#                    model_name  test_f1_weighted  test_accuracy
# 0          LogisticRegression          0.624301       0.672765
# 1  LinearDiscriminantAnalysis          0.580324       0.628440
# 2                         SVC          0.897883       0.898855
# 3      DecisionTreeClassifier          0.970668       0.970549
# 4         ExtraTreeClassifier          0.875281       0.875056
# 5                  GaussianNB          0.826875       0.828797
# 6        KNeighborsClassifier          0.903135       0.903019
# 7      RandomForestClassifier          0.975880       0.975755
# 8        ExtraTreesClassifier          0.967961       0.967871
# 9                    GCForest          0.976190       0.976052

# %%
for model in models:
    model_name = model.__class__.__name__
    y_pred = model.predict(X_test)
    print("=================" + model_name + "=================")
    print(classification_report(y_test, y_pred, digits=4))

    cm = confusion_matrix(y_test, y_pred)
    i=0
    acc_all = np.zeros(6)
    for c in cm:
        acc_all[i] = c[i]/np.sum(c)
        print("%d accuaracy: %f" %(i, acc_all[i]))
        i=i+1
    print("acc:", np.sum(y_test == y_pred)/y_pred.shape[0])
    print('f1_weighted', f1_score(y_test, y_pred, average='weighted'))
# Out:
# =================LogisticRegression=================
#              precision    recall  f1-score   support
#
#           0     0.9524    0.0820    0.1509       488
#           1     0.6700    0.9951    0.8008      2655
#           2     0.6630    0.5534    0.6033      1760
#           3     0.6325    0.4799    0.5457      1094
#           4     0.0000    0.0000    0.0000       297
#           5     0.7808    0.7972    0.7889       429
#
# avg / total     0.6601    0.6728    0.6243      6723
#
# 0 accuaracy: 0.081967
# 1 accuaracy: 0.995104
# 2 accuaracy: 0.553409
# 3 accuaracy: 0.479890
# 4 accuaracy: 0.000000
# 5 accuaracy: 0.797203
# acc: 0.6727651346125242
# f1_weighted 0.6243014542088469
# =================LinearDiscriminantAnalysis=================
#              precision    recall  f1-score   support
#
#           0     0.0000    0.0000    0.0000       488
#           1     0.6057    0.9985    0.7540      2655
#           2     0.6062    0.3989    0.4812      1760
#           3     0.7087    0.5293    0.6060      1094
#           4     0.5366    0.2963    0.3818       297
#           5     0.9903    0.4779    0.6447       429
#
# avg / total     0.6001    0.6284    0.5803      6723
#
# 0 accuaracy: 0.000000
# 1 accuaracy: 0.998493
# 2 accuaracy: 0.398864
# 3 accuaracy: 0.529250
# 4 accuaracy: 0.296296
# 5 accuaracy: 0.477855
# acc: 0.6284396846645842
# f1_weighted 0.5803241666905137
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# =================SVC=================
#              precision    recall  f1-score   support
#
#           0     0.7791    0.6721    0.7217       488
#           1     0.8829    0.9311    0.9063      2655
#           2     0.9089    0.8784    0.8934      1760
#           3     0.9388    0.9260    0.9324      1094
#           4     0.9201    0.8923    0.9060       297
#           5     0.9654    0.9767    0.9710       429
#
# avg / total     0.8982    0.8989    0.8979      6723
#
# 0 accuaracy: 0.672131
# 1 accuaracy: 0.931073
# 2 accuaracy: 0.878409
# 3 accuaracy: 0.925960
# 4 accuaracy: 0.892256
# 5 accuaracy: 0.976690
# acc: 0.8988546779711438
# f1_weighted 0.8978825354498516
# =================DecisionTreeClassifier=================
#              precision    recall  f1-score   support
#
#           0     0.9009    0.9877    0.9423       488
#           1     0.9866    0.9729    0.9797      2655
#           2     0.9788    0.9716    0.9752      1760
#           3     0.9714    0.9634    0.9674      1094
#           4     0.9254    0.9192    0.9223       297
#           5     0.9549    0.9860    0.9702       429
#
# avg / total     0.9712    0.9705    0.9707      6723
#
# 0 accuaracy: 0.987705
# 1 accuaracy: 0.972881
# 2 accuaracy: 0.971591
# 3 accuaracy: 0.963437
# 4 accuaracy: 0.919192
# 5 accuaracy: 0.986014
# acc: 0.9705488621151271
# f1_weighted 0.9706683119948953
# =================ExtraTreeClassifier=================
#              precision    recall  f1-score   support
#
#           0     0.7847    0.9262    0.8496       488
#           1     0.9347    0.9009    0.9175      2655
#           2     0.8684    0.8659    0.8671      1760
#           3     0.8403    0.8464    0.8434      1094
#           4     0.7071    0.6667    0.6863       297
#           5     0.8670    0.9114    0.8886       429
#
# avg / total     0.8767    0.8751    0.8753      6723
#
# 0 accuaracy: 0.926230
# 1 accuaracy: 0.900942
# 2 accuaracy: 0.865909
# 3 accuaracy: 0.846435
# 4 accuaracy: 0.666667
# 5 accuaracy: 0.911422
# acc: 0.8750557786702365
# f1_weighted 0.8752805349299579
# =================GaussianNB=================
#              precision    recall  f1-score   support
#
#           0     0.8012    0.7930    0.7971       488
#           1     0.8655    0.9164    0.8902      2655
#           2     0.8013    0.8409    0.8206      1760
#           3     0.7876    0.7221    0.7535      1094
#           4     0.6546    0.5488    0.5971       297
#           5     0.9667    0.7436    0.8406       429
#
# avg / total     0.8285    0.8288    0.8269      6723
#
# 0 accuaracy: 0.793033
# 1 accuaracy: 0.916384
# 2 accuaracy: 0.840909
# 3 accuaracy: 0.722121
# 4 accuaracy: 0.548822
# 5 accuaracy: 0.743590
# acc: 0.8287966681540979
# f1_weighted 0.8268746436709529
# =================KNeighborsClassifier=================
#              precision    recall  f1-score   support
#
#           0     0.7607    0.8012    0.7804       488
#           1     0.9077    0.9333    0.9203      2655
#           2     0.9206    0.8898    0.9049      1760
#           3     0.9269    0.9040    0.9153      1094
#           4     0.8556    0.8182    0.8365       297
#           5     0.9461    0.9417    0.9439       429
#
# avg / total     0.9037    0.9030    0.9031      6723
#
# 0 accuaracy: 0.801230
# 1 accuaracy: 0.933333
# 2 accuaracy: 0.889773
# 3 accuaracy: 0.904022
# 4 accuaracy: 0.818182
# 5 accuaracy: 0.941725
# acc: 0.9030194853488026
# f1_weighted 0.9031348194338711
# =================RandomForestClassifier=================
#              precision    recall  f1-score   support
#
#           0     0.9082    0.9939    0.9491       488
#           1     0.9923    0.9759    0.9840      2655
#           2     0.9835    0.9801    0.9818      1760
#           3     0.9778    0.9680    0.9729      1094
#           4     0.9262    0.9293    0.9277       297
#           5     0.9571    0.9883    0.9725       429
#
# avg / total     0.9764    0.9758    0.9759      6723
#
# 0 accuaracy: 0.993852
# 1 accuaracy: 0.975895
# 2 accuaracy: 0.980114
# 3 accuaracy: 0.968007
# 4 accuaracy: 0.929293
# 5 accuaracy: 0.988345
# acc: 0.9757548713372006
# f1_weighted 0.975880473298256
# =================ExtraTreesClassifier=================
# [ 2019-04-02 23:53:25,827][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-04-02 23:53:25,830][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-02 23:53:25,831][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-04-02 23:53:25,835][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
#              precision    recall  f1-score   support
#
#           0     0.9049    0.9754    0.9389       488
#           1     0.9829    0.9755    0.9792      2655
#           2     0.9737    0.9670    0.9704      1760
#           3     0.9656    0.9506    0.9581      1094
#           4     0.9231    0.9293    0.9262       297
#           5     0.9658    0.9860    0.9758       429
#
# avg / total     0.9683    0.9679    0.9680      6723
#
# 0 accuaracy: 0.975410
# 1 accuaracy: 0.975518
# 2 accuaracy: 0.967045
# 3 accuaracy: 0.950640
# 4 accuaracy: 0.929293
# 5 accuaracy: 0.986014
# acc: 0.9678714859437751
# f1_weighted 0.9679610964861342
# [ 2019-04-02 23:53:26,161][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:53:26,578][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:53:26,959][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:53:27,393][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-04-02 23:53:27,740][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(6723, 52)
# =================GCForest=================
#              precision    recall  f1-score   support
#
#           0     0.9065    0.9939    0.9482       488
#           1     0.9927    0.9755    0.9840      2655
#           2     0.9835    0.9801    0.9818      1760
#           3     0.9788    0.9689    0.9738      1094
#           4     0.9267    0.9360    0.9313       297
#           5     0.9593    0.9883    0.9736       429
#
# avg / total     0.9767    0.9761    0.9762      6723
#
# 0 accuaracy: 0.993852
# 1 accuaracy: 0.975518
# 2 accuaracy: 0.980114
# 3 accuaracy: 0.968921
# 4 accuaracy: 0.936027
# 5 accuaracy: 0.988345
# acc: 0.976052357578462
# f1_weighted 0.9761901664502985

# %%
for model in models:
    model_name = model.__class__.__name__
    y_pred = model.predict(X_train)
    print("=================" + model_name + "=================")
    print(classification_report(y_train, y_pred, digits=4))

    cm = confusion_matrix(y_train, y_pred)
    i=0
    acc_all = np.zeros(6)
    for c in cm:
        acc_all[i] = c[i]/np.sum(c)
        print("%d accuaracy: %f" %(i, acc_all[i]))
        i=i+1
    print("acc:", np.sum(y_train == y_pred)/y_pred.shape[0])
    print('f1_weighted', f1_score(y_train, y_pred, average='weighted'))
# Out:
# =================LogisticRegression=================
#              precision    recall  f1-score   support
#
#           0     0.9182    0.0518    0.0981      1950
#           1     0.6734    0.9919    0.8022     10617
#           2     0.6428    0.5761    0.6076      7037
#           3     0.6242    0.4504    0.5233      4378
#           4     0.0000    0.0000    0.0000      1190
#           5     0.7899    0.7705    0.7801      1717
#
# avg / total     0.6528    0.6687    0.6179     26889
#
# 0 accuaracy: 0.051795
# 1 accuaracy: 0.991900
# 2 accuaracy: 0.576098
# 3 accuaracy: 0.450434
# 4 accuaracy: 0.000000
# 5 accuaracy: 0.770530
# acc: 0.6687121127598646
# f1_weighted 0.6178872582244622
# =================LinearDiscriminantAnalysis=================
#              precision    recall  f1-score   support
#
#           0     0.0000    0.0000    0.0000      1950
#           1     0.6017    0.9986    0.7509     10617
#           2     0.5950    0.3879    0.4697      7037
#           3     0.6923    0.5114    0.5883      4378
#           4     0.4900    0.2689    0.3473      1190
#           5     0.9861    0.4537    0.6215      1717
#
# avg / total     0.5907    0.6200    0.5702     26889
#
# 0 accuaracy: 0.000000
# 1 accuaracy: 0.998587
# 2 accuaracy: 0.387949
# 3 accuaracy: 0.511421
# 4 accuaracy: 0.268908
# 5 accuaracy: 0.453698
# acc: 0.6199561158838187
# f1_weighted 0.5702421295788672
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# =================SVC=================
#              precision    recall  f1-score   support
#
#           0     0.8553    0.6759    0.7551      1950
#           1     0.8906    0.9358    0.9126     10617
#           2     0.8862    0.8957    0.8909      7037
#           3     0.9419    0.9073    0.9243      4378
#           4     0.8997    0.8891    0.8943      1190
#           5     0.9733    0.9563    0.9647      1717
#
# avg / total     0.9009    0.9010    0.8999     26889
#
# 0 accuaracy: 0.675897
# 1 accuaracy: 0.935763
# 2 accuaracy: 0.895694
# 3 accuaracy: 0.907264
# 4 accuaracy: 0.889076
# 5 accuaracy: 0.956319
# acc: 0.9010375990181859
# f1_weighted 0.8999290952737513
# =================DecisionTreeClassifier=================
#              precision    recall  f1-score   support
#
#           0     1.0000    1.0000    1.0000      1950
#           1     1.0000    1.0000    1.0000     10617
#           2     1.0000    1.0000    1.0000      7037
#           3     1.0000    1.0000    1.0000      4378
#           4     1.0000    1.0000    1.0000      1190
#           5     1.0000    1.0000    1.0000      1717
#
# avg / total     1.0000    1.0000    1.0000     26889
#
# 0 accuaracy: 1.000000
# 1 accuaracy: 1.000000
# 2 accuaracy: 1.000000
# 3 accuaracy: 1.000000
# 4 accuaracy: 1.000000
# 5 accuaracy: 1.000000
# acc: 1.0
# f1_weighted 1.0
# =================ExtraTreeClassifier=================
#              precision    recall  f1-score   support
#
#           0     1.0000    1.0000    1.0000      1950
#           1     1.0000    1.0000    1.0000     10617
#           2     1.0000    1.0000    1.0000      7037
#           3     1.0000    1.0000    1.0000      4378
#           4     1.0000    1.0000    1.0000      1190
#           5     1.0000    1.0000    1.0000      1717
#
# avg / total     1.0000    1.0000    1.0000     26889
#
# 0 accuaracy: 1.000000
# 1 accuaracy: 1.000000
# 2 accuaracy: 1.000000
# 3 accuaracy: 1.000000
# 4 accuaracy: 1.000000
# 5 accuaracy: 1.000000
# acc: 1.0
# f1_weighted 1.0
# =================GaussianNB=================
#              precision    recall  f1-score   support
#
#           0     0.8406    0.7872    0.8130      1950
#           1     0.8579    0.9150    0.8856     10617
#           2     0.7716    0.8218    0.7959      7037
#           3     0.7751    0.7012    0.7363      4378
#           4     0.6546    0.5908    0.6210      1190
#           5     0.9793    0.6896    0.8093      1717
#
# avg / total     0.8193    0.8178    0.8160     26889
#
# 0 accuaracy: 0.787179
# 1 accuaracy: 0.915042
# 2 accuaracy: 0.821799
# 3 accuaracy: 0.701233
# 4 accuaracy: 0.590756
# 5 accuaracy: 0.689575
# acc: 0.8178065379895124
# f1_weighted 0.8159545446983343
# =================KNeighborsClassifier=================
#              precision    recall  f1-score   support
#
#           0     0.8896    0.8636    0.8764      1950
#           1     0.9432    0.9680    0.9554     10617
#           2     0.9499    0.9413    0.9456      7037
#           3     0.9557    0.9454    0.9505      4378
#           4     0.9082    0.8731    0.8903      1190
#           5     0.9806    0.9435    0.9617      1717
#
# avg / total     0.9439    0.9440    0.9438     26889
#
# 0 accuaracy: 0.863590
# 1 accuaracy: 0.967976
# 2 accuaracy: 0.941310
# 3 accuaracy: 0.945409
# 4 accuaracy: 0.873109
# 5 accuaracy: 0.943506
# acc: 0.943991966975343
# f1_weighted 0.9438441498177579
# =================RandomForestClassifier=================
#              precision    recall  f1-score   support
#
#           0     0.9974    0.9995    0.9985      1950
#           1     0.9996    0.9992    0.9994     10617
#           2     0.9990    0.9993    0.9991      7037
#           3     0.9991    0.9998    0.9994      4378
#           4     0.9983    0.9966    0.9975      1190
#           5     1.0000    0.9988    0.9994      1717
#
# avg / total     0.9992    0.9992    0.9992     26889
#
# 0 accuaracy: 0.999487
# 1 accuaracy: 0.999152
# 2 accuaracy: 0.999289
# 3 accuaracy: 0.999772
# 4 accuaracy: 0.996639
# 5 accuaracy: 0.998835
# acc: 0.9991818215627208
# [ 2019-04-02 23:53:39,533][cascade_classifier.transform] X_groups_test.shape=[(26889, 4)]
# [ 2019-04-02 23:53:39,540][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-02 23:53:39,545][cascade_classifier.transform] X_test.shape=(26889, 4)
# [ 2019-04-02 23:53:39,548][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(26889, 4)
# f1_weighted 0.999181826982915
# =================ExtraTreesClassifier=================
#              precision    recall  f1-score   support
#
#           0     1.0000    1.0000    1.0000      1950
#           1     1.0000    1.0000    1.0000     10617
#           2     1.0000    1.0000    1.0000      7037
#           3     1.0000    1.0000    1.0000      4378
#           4     1.0000    1.0000    1.0000      1190
#           5     1.0000    1.0000    1.0000      1717
#
# avg / total     1.0000    1.0000    1.0000     26889
#
# 0 accuaracy: 1.000000
# 1 accuaracy: 1.000000
# 2 accuaracy: 1.000000
# 3 accuaracy: 1.000000
# 4 accuaracy: 1.000000
# 5 accuaracy: 1.000000
# acc: 1.0
# f1_weighted 1.0
# [ 2019-04-02 23:53:40,717][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:53:42,164][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:53:43,573][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:53:44,700][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(26889, 52)
# [ 2019-04-02 23:53:45,725][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(26889, 52)
# =================GCForest=================
#              precision    recall  f1-score   support
#
#           0     0.9949    0.9990    0.9969      1950
#           1     0.9999    0.9968    0.9983     10617
#           2     0.9970    0.9989    0.9979      7037
#           3     0.9973    0.9989    0.9981      4378
#           4     0.9933    0.9992    0.9962      1190
#           5     0.9994    0.9983    0.9988      1717
#
# avg / total     0.9980    0.9980    0.9980     26889
#
# 0 accuaracy: 0.998974
# 1 accuaracy: 0.996798
# 2 accuaracy: 0.998863
# 3 accuaracy: 0.998858
# 4 accuaracy: 0.999160
# 5 accuaracy: 0.998253
# acc: 0.9980289337647366
# f1_weighted 0.9980295751139766

# %% [markdown]
# MeanSD

# %% [markdown]
# 1. MeanSD weighted F1

# %%
from sklearn.model_selection import StratifiedKFold

for model in models:
    model_name = model.__class__.__name__
    
    # Kfold
    scores = []
    skf = StratifiedKFold(n_splits=5)
    for train_index, test_index in skf.split(X_train, y_train):
        K_train_x, K_test_x = X_train[train_index], X_train[test_index]
        K_train_y, K_test_y = y_train[train_index], y_train[test_index]
        
        y_pred = model.predict(K_test_x)
        scores.append(f1_score(K_test_y, y_pred,average="weighted"))
    print("%s    Weighted F1: %0.2f ± %0.2f %%" % (model_name, np.mean(scores)*100, np.std(scores)*100))
# Out:
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# LogisticRegression    Weighted F1: 61.78 ± 0.96 %
# LinearDiscriminantAnalysis    Weighted F1: 57.02 ± 0.25 %
# SVC    Weighted F1: 89.99 ± 0.32 %
# DecisionTreeClassifier    Weighted F1: 100.00 ± 0.00 %
# ExtraTreeClassifier    Weighted F1: 100.00 ± 0.00 %
# GaussianNB    Weighted F1: 81.59 ± 0.41 %
# [ 2019-04-03 00:10:16,654][cascade_classifier.transform] X_groups_test.shape=[(5380, 4)]
# [ 2019-04-03 00:10:16,657][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:10:16,658][cascade_classifier.transform] X_test.shape=(5380, 4)
# [ 2019-04-03 00:10:16,660][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5380, 4)
# KNeighborsClassifier    Weighted F1: 94.38 ± 0.30 %
# RandomForestClassifier    Weighted F1: 99.92 ± 0.03 %
# ExtraTreesClassifier    Weighted F1: 100.00 ± 0.00 %
# [ 2019-04-03 00:10:16,872][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:17,060][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:17,238][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:17,424][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:17,725][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:17,912][cascade_classifier.transform] X_groups_test.shape=[(5380, 4)]
# [ 2019-04-03 00:10:17,914][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:10:17,918][cascade_classifier.transform] X_test.shape=(5380, 4)
# [ 2019-04-03 00:10:17,919][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5380, 4)
# [ 2019-04-03 00:10:18,078][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:18,238][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:18,393][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:18,564][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:18,719][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:10:18,880][cascade_classifier.transform] X_groups_test.shape=[(5377, 4)]
# [ 2019-04-03 00:10:18,881][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:10:18,882][cascade_classifier.transform] X_test.shape=(5377, 4)
# [ 2019-04-03 00:10:18,883][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5377, 4)
# [ 2019-04-03 00:10:19,043][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:10:19,208][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:10:19,403][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:10:19,579][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:10:19,752][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:10:19,908][cascade_classifier.transform] X_groups_test.shape=[(5376, 4)]
# [ 2019-04-03 00:10:19,909][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:10:19,910][cascade_classifier.transform] X_test.shape=(5376, 4)
# [ 2019-04-03 00:10:19,912][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5376, 4)
# [ 2019-04-03 00:10:20,056][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:20,225][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:20,404][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:20,564][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:20,736][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:20,913][cascade_classifier.transform] X_groups_test.shape=[(5376, 4)]
# [ 2019-04-03 00:10:20,914][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:10:20,915][cascade_classifier.transform] X_test.shape=(5376, 4)
# [ 2019-04-03 00:10:20,916][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5376, 4)
# [ 2019-04-03 00:10:21,089][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:21,249][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:21,403][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:21,561][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:10:21,731][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5376, 52)
# GCForest    Weighted F1: 99.80 ± 0.06 %

# %% [markdown]
# 2. MeanSD Acc

# %%
for model in models:
    model_name = model.__class__.__name__
    
    # Kfold
    scores = []
    skf = StratifiedKFold(n_splits=5)
    for train_index, test_index in skf.split(X_train, y_train):
        K_train_x, K_test_x = X_train[train_index], X_train[test_index]
        K_train_y, K_test_y = y_train[train_index], y_train[test_index]
        
        y_pred = model.predict(K_test_x)
        scores.append(accuracy_score(K_test_y, y_pred))
    print("%s    Acc: %0.2f ± %0.2f %%" % (model_name, np.mean(scores)*100, np.std(scores)*100))
# Out:
# LogisticRegression    Acc: 66.87 ± 0.83 %
# LinearDiscriminantAnalysis    Acc: 62.00 ± 0.21 %
# SVC    Acc: 90.10 ± 0.32 %
# DecisionTreeClassifier    Acc: 100.00 ± 0.00 %
# ExtraTreeClassifier    Acc: 100.00 ± 0.00 %
# GaussianNB    Acc: 81.78 ± 0.39 %
# [ 2019-04-03 00:11:17,345][cascade_classifier.transform] X_groups_test.shape=[(5380, 4)]
# [ 2019-04-03 00:11:17,352][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:11:17,354][cascade_classifier.transform] X_test.shape=(5380, 4)
# [ 2019-04-03 00:11:17,356][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5380, 4)
# KNeighborsClassifier    Acc: 94.40 ± 0.30 %
# RandomForestClassifier    Acc: 99.92 ± 0.03 %
# ExtraTreesClassifier    Acc: 100.00 ± 0.00 %
# [ 2019-04-03 00:11:17,561][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:17,730][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:17,896][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:18,058][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:18,288][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:18,463][cascade_classifier.transform] X_groups_test.shape=[(5380, 4)]
# [ 2019-04-03 00:11:18,464][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:11:18,465][cascade_classifier.transform] X_test.shape=(5380, 4)
# [ 2019-04-03 00:11:18,467][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5380, 4)
# [ 2019-04-03 00:11:18,636][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:18,818][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:18,971][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:19,123][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:19,274][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5380, 52)
# [ 2019-04-03 00:11:19,434][cascade_classifier.transform] X_groups_test.shape=[(5377, 4)]
# [ 2019-04-03 00:11:19,435][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:11:19,436][cascade_classifier.transform] X_test.shape=(5377, 4)
# [ 2019-04-03 00:11:19,437][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5377, 4)
# [ 2019-04-03 00:11:19,581][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:11:19,742][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:11:19,895][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:11:20,046][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:11:20,199][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5377, 52)
# [ 2019-04-03 00:11:20,394][cascade_classifier.transform] X_groups_test.shape=[(5376, 4)]
# [ 2019-04-03 00:11:20,396][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:11:20,397][cascade_classifier.transform] X_test.shape=(5376, 4)
# [ 2019-04-03 00:11:20,398][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5376, 4)
# [ 2019-04-03 00:11:20,557][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:20,717][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:20,870][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:21,024][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:21,176][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:21,328][cascade_classifier.transform] X_groups_test.shape=[(5376, 4)]
# [ 2019-04-03 00:11:21,329][cascade_classifier.transform] group_dims=[4]
# [ 2019-04-03 00:11:21,330][cascade_classifier.transform] X_test.shape=(5376, 4)
# [ 2019-04-03 00:11:21,331][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(5376, 4)
# [ 2019-04-03 00:11:21,475][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:21,632][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:21,785][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:21,935][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(5376, 52)
# [ 2019-04-03 00:11:22,086][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(5376, 52)
# GCForest    Acc: 99.80 ± 0.06 %
