# %%
import os
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.pipeline import Pipeline

from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append("..") 
from gcforest.gcforest import GCForest

import xlwt

# %% [markdown]
# # 数据及参数

# %%
random_seed = 42
cv=5
score = 'f1_weighted'
gc_cv=5

# %%
def config1():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
def config2():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config3():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config4():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config5():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config6():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config7():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config8():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config9():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config10():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config11():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config12():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config13():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
def config14():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    config["cascade"] = ca_config
    return config

# %%
def config15():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    config["cascade"] = ca_config
    return config

# %%
def config16():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "RandomForestClassifier", "random_state" : random_seed})
    config["cascade"] = ca_config
    return config

# %%
def config17():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config18():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config19():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "DecisionTreeClassifier"})
    config["cascade"] = ca_config
    return config

# %%
def config20():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
def config21():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
def config22():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    ca_config["estimators"].append({"n_folds": gc_cv, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
path = os.getcwd()+'/../data/20122018freshwater_four_feature.csv'
data = pd.read_csv(path, na_values = np.nan)

# %%
X = data.drop(['本周水质'], axis=1).values # Series
y = data['本周水质'].values.reshape(-1,1) - 1

# 1. 中位数填充缺失值，2.Z-score标准化
clean_pipeline = Pipeline([('imputer', preprocessing.Imputer(missing_values='NaN',strategy="median")),
                           ('std_scaler', preprocessing.StandardScaler())])
X = clean_pipeline.fit_transform(X)

# %%
X.shape
# Out:
# (33612, 4)

# %% [markdown]
# # k折交叉验证

# %%
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1


def kftrain(X, y, model, cv):
    model_name = model.__class__.__name__

    n_samples = X.shape[0]
    n_features = X.shape[1]
    n_class = np.unique(y).shape[0]

    Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    cv_F1_weighted = np.zeros(cv) # 5次 test data 的F1_weighted
    _cv_F1_weighted = np.zeros(cv) # 5次 train data 的F1_weighted
    cv_Acc = np.zeros(cv) # 5次test data的Acc
    _cv_Acc = np.zeros(cv) # 5次train data的Acc
    # 各类别的Support，每个类别的support由5次fold后得到的5个support求平均得到，这里support：各类别样本占总样本的比列
    # 各类别的F1，由5次fold后得到的5个F1求平均得到
    # 所以，Weighted F1 等于“5次fold得到的5个 Weighted F1 求平均得到” ——等价于—— “6个support*6个F1”得到
    Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后test data各类别的support
    _Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后train data各类别的support
    
    # 各类别的Mean，SD
    Acc_mean_class = np.zeros(6)
    _Acc_mean_class = np.zeros(6)
    Acc_SD_class = np.zeros(6)
    _Acc_SD_class = np.zeros(6)
    F1_mean_class = np.zeros(6)
    _F1_mean_class = np.zeros(6)
    F1_SD_class = np.zeros(6)
    _F1_SD_class = np.zeros(6)
    
    k = 0
    skf = StratifiedKFold(n_splits=cv) # 定义5折分层划分器
    
    for train_index, test_index in skf.split(X, y):
        K_train_x, K_test_x = X[train_index], X[test_index]
        K_train_y, K_test_y = y[train_index], y[test_index]
        if model_name == 'GCForest':
            model.fit_transform(K_train_x, K_train_y.reshape(K_train_y.shape[0]))
        else:
            model.fit(K_train_x, K_train_y)
    
        K_test_y_pred = model.predict(K_test_x)
        K_train_y_pred = model.predict(K_train_x)
        
        # 由混淆矩阵计算各类别的Acc
        test_cm = confusion_matrix(K_test_y, K_test_y_pred)
        train_cm = confusion_matrix(K_train_y, K_train_y_pred)
        test_acc_all_class = np.zeros(n_class) # 6个类别上的测试acc
        train_acc_all_class = np.zeros(n_class) # 6个类别上的训练acc
        
        i = 0
        for c in test_cm:
            test_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        Acc_matrix[:,k] = test_acc_all_class
        
        i = 0
        for c in train_cm:
            train_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        _Acc_matrix[:,k] = train_acc_all_class
        
        # 由classification_report提取各类别的F1
        cr = classification_report(K_test_y, K_test_y_pred, digits=4)
        _cr = classification_report(K_train_y, K_train_y_pred, digits=4)
        test_f1_all_class = np.zeros(n_class) # test data 6个类别上的测试f1
        train_f1_all_class = np.zeros(n_class) # train data 6个类别上的训练f1
        support_all_class = np.zeros(n_class) # test data 6个类别的support
        _support_all_class = np.zeros(n_class) # train data 6个类别的support
        
        i = 0
        for l in range(2,8):
            test_f1_all_class[i] = float(cr.splitlines()[l].split()[3])
            train_f1_all_class[i] = float(_cr.splitlines()[l].split()[3])
            support_all_class[i] = float(cr.splitlines()[l].split()[4])/(n_samples/cv)
            _support_all_class[i] = float(_cr.splitlines()[l].split()[4])/(n_samples*(1-1/cv))
            i = i + 1
        F1_matrix[:,k] = test_f1_all_class
        _F1_matrix[:,k] = train_f1_all_class
        Support_matrix[:,k] = support_all_class
        _Support_matrix[:,k] = _support_all_class
        
        # cv_F1_weighted[k] = float(cr.splitlines()[9].split()[5]) # 第k折时的Weighted F1
        cv_F1_weighted[k] = f1_score(K_test_y, K_test_y_pred, average="weighted")
        _cv_F1_weighted[k] = f1_score(K_train_y, K_train_y_pred, average="weighted")
        cv_Acc[k] = accuracy_score(K_test_y, K_test_y_pred)
        _cv_Acc[k] = accuracy_score(K_train_y, K_train_y_pred)
        
        k += 1
    
    Acc_mean = np.mean(Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    _Acc_mean = np.mean(_Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    
    F1_mean = np.mean(F1_matrix, axis=1) # 6个类别的k-fold平均F1
    _F1_mean = np.mean(_F1_matrix, axis=1) # 6个类别的k-fold平均F1
    Support_mean = np.mean(Support_matrix, axis=1) # 6个类别的k-fold平均support
    _Support_mean = np.mean(_Support_matrix, axis=1) # 6个类别的k-fold平均support
    
    Acc = np.mean(Acc_mean)
    _Acc = np.mean(_Acc_mean)
    F1_weighted = np.mean(cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    _F1_weighted = np.mean(_cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    SD_Acc = np.std(cv_Acc)
    _SD_Acc = np.std(cv_Acc)
    SD_F1 = np.std(cv_F1_weighted)
    _SD_F1 = np.std(cv_F1_weighted)
    
    Acc_mean_class = np.mean(Acc_matrix, axis=1)
    _Acc_mean_class = np.mean(_Acc_matrix, axis=1)
    Acc_SD_class = np.std(Acc_matrix, axis=1)
    _Acc_SD_class = np.std(_Acc_matrix, axis=1)
    F1_mean_class = np.mean(F1_matrix, axis=1)
    _F1_mean_class = np.mean(_F1_matrix, axis=1)
    F1_SD_class = np.std(F1_matrix, axis=1)
    _F1_SD_class = np.std(_F1_matrix, axis=1)
    
    # return Acc_mean, F1_mean, Support_mean, Acc, F1_weighted, SD_Acc, SD_F1, Acc_mean_class, Acc_SD_class, F1_mean_class, F1_SD_class
    return Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_mean, _Acc_mean, F1_mean, _F1_mean, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class

# %%
models = [
    GCForest(config1()),
    GCForest(config2()),
    GCForest(config3()),
    GCForest(config4()),
    GCForest(config5()),
    GCForest(config6()),
    GCForest(config7()),
    GCForest(config8()),
    GCForest(config9()),
    GCForest(config10()),
    GCForest(config11()),
    GCForest(config12()),
    GCForest(config13()),
    GCForest(config14()),
    GCForest(config15()),
    GCForest(config16()),
    GCForest(config17()),
    GCForest(config18()),
    GCForest(config19()),
    GCForest(config20()),
    GCForest(config21()),
    GCForest(config22())
]

# %%
workbook = xlwt.Workbook(encoding = 'utf-8')  

config_index = 1

for model in models:
    model_name = model.__class__.__name__
    print(model_name)
    Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_class, _Acc_class, F1_class, _F1_class, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class = kftrain(X, y, model, cv)
    
    worksheet = workbook.add_sheet("config" + str(config_index), cell_overwrite_ok=True)
    worksheet.write(0,0, "train_Acc_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+1, j, _Acc_matrix[i,j])

    worksheet.write(0,6, "test_Acc_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+1, j+cv+2, Acc_matrix[i,j])



    worksheet.write(11,0, "train_F1_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+12, j, _F1_matrix[i,j])

    worksheet.write(11,6, "test_F1_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+12, j+cv+2, F1_matrix[i,j])



    worksheet.write(20,0, "train_support_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+21, j, _Support_matrix[i,j])

    worksheet.write(20,6, "test_support_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+21, j+cv+2, Support_matrix[i,j])
            
    for index, val in enumerate(str(model.config).split()):
        worksheet.write(30+index, 0, val)
        
    config_index+=1
            
workbook.save("../res/gc_comparisions.xls")
# Out:
# [ 2019-05-22 00:12:51,072][cascade_classifier.fit_transform] X_groups_train.shape=[(26886, 4)],y_train.shape=(26886,),X_groups_test.shape=no_test,y_test.shape=no_test
# [ 2019-05-22 00:12:51,074][cascade_classifier.fit_transform] group_dims=[4]
# [ 2019-05-22 00:12:51,074][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-05-22 00:12:51,076][cascade_classifier.fit_transform] group_ends=[4]
# [ 2019-05-22 00:12:51,077][cascade_classifier.fit_transform] X_train.shape=(26886, 4),X_test.shape=(0, 4)
# [ 2019-05-22 00:12:51,080][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(26886, 4), X_cur_test.shape=(0, 4)
# GCForest
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# [ 2019-05-22 00:12:51,313][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-22 00:12:51,467][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_1.predict)=99.52%
# [ 2019-05-22 00:12:51,623][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_2.predict)=99.61%
# [ 2019-05-22 00:12:51,785][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_3.predict)=99.52%
# [ 2019-05-22 00:12:51,949][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-22 00:12:51,956][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_cv.predict)=99.54%
# [ 2019-05-22 00:12:52,137][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_0.predict)=99.42%
# [ 2019-05-22 00:12:52,297][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_1.predict)=99.63%
# [ 2019-05-22 00:12:52,454][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_2.predict)=99.50%
# [ 2019-05-22 00:12:52,605][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_3.predict)=99.33%
# [ 2019-05-22 00:12:52,761][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_4.predict)=99.53%
# [ 2019-05-22 00:12:52,768][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_cv.predict)=99.48%
# [ 2019-05-22 00:12:52,936][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_0.predict)=99.52%
# [ 2019-05-22 00:12:53,103][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-22 00:12:53,265][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-22 00:12:53,469][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_3.predict)=99.55%
# [ 2019-05-22 00:12:53,639][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_4.predict)=99.52%
# [ 2019-05-22 00:12:53,651][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_cv.predict)=99.52%
# [ 2019-05-22 00:12:53,834][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-22 00:12:53,994][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_1.predict)=99.31%
# [ 2019-05-22 00:12:54,161][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_2.predict)=99.53%
# [ 2019-05-22 00:12:54,321][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_3.predict)=99.46%
# [ 2019-05-22 00:12:54,488][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_4.predict)=99.65%
# [ 2019-05-22 00:12:54,495][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_cv.predict)=99.48%
# [ 2019-05-22 00:12:54,555][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_0.predict)=99.11%
# [ 2019-05-22 00:12:54,599][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_1.predict)=98.90%
# [ 2019-05-22 00:12:54,642][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_2.predict)=99.26%
# [ 2019-05-22 00:12:54,688][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_3.predict)=99.01%
# [ 2019-05-22 00:12:54,733][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_4.predict)=98.99%
# [ 2019-05-22 00:12:54,740][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_cv.predict)=99.06%
# [ 2019-05-22 00:12:54,810][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_0.predict)=99.22%
# [ 2019-05-22 00:12:54,863][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_1.predict)=99.03%
# [ 2019-05-22 00:12:54,909][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_2.predict)=99.00%
# [ 2019-05-22 00:12:54,952][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_3.predict)=99.07%
# [ 2019-05-22 00:12:54,997][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_4.predict)=99.31%
# [ 2019-05-22 00:12:55,004][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_cv.predict)=99.13%
# [ 2019-05-22 00:12:55,063][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_0.predict)=99.26%
# [ 2019-05-22 00:12:55,109][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_1.predict)=99.07%
# [ 2019-05-22 00:12:55,156][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_2.predict)=99.05%
# [ 2019-05-22 00:12:55,201][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_3.predict)=99.09%
# [ 2019-05-22 00:12:55,245][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_4.predict)=99.01%
# [ 2019-05-22 00:12:55,252][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_cv.predict)=99.10%
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [ 2019-05-22 00:12:55,526][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_0.predict)=62.35%
# [ 2019-05-22 00:12:55,651][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_1.predict)=61.95%
# [ 2019-05-22 00:12:55,795][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_2.predict)=62.63%
# [ 2019-05-22 00:12:55,917][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_3.predict)=61.34%
# [ 2019-05-22 00:12:56,031][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_4.predict)=62.38%
# [ 2019-05-22 00:12:56,037][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_cv.predict)=62.13%
# [ 2019-05-22 00:12:56,045][cascade_classifier.calc_f1] Weighted F1 (layer_0 - train.classifier_average)=99.53%
# [ 2019-05-22 00:12:56,056][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-22 00:12:56,330][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_0.predict)=99.54%
# [ 2019-05-22 00:12:56,563][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-22 00:12:56,824][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_2.predict)=99.52%
# [ 2019-05-22 00:12:57,110][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_3.predict)=99.57%
# [ 2019-05-22 00:12:57,359][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-22 00:12:57,366][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:12:57,649][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_0.predict)=99.50%
# [ 2019-05-22 00:12:57,932][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_1.predict)=99.63%
# [ 2019-05-22 00:12:58,193][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_2.predict)=99.61%
# [ 2019-05-22 00:12:58,491][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_3.predict)=99.59%
# [ 2019-05-22 00:12:58,739][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_4.predict)=99.46%
# [ 2019-05-22 00:12:58,746][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:12:59,007][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_0.predict)=99.54%
# [ 2019-05-22 00:12:59,256][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_1.predict)=99.46%
# [ 2019-05-22 00:12:59,542][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_2.predict)=99.57%
# [ 2019-05-22 00:12:59,810][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_3.predict)=99.61%
# [ 2019-05-22 00:13:00,065][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-22 00:13:00,073][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:00,338][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_0.predict)=99.70%
# [ 2019-05-22 00:13:00,571][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_1.predict)=99.40%
# [ 2019-05-22 00:13:00,818][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_2.predict)=99.68%
# [ 2019-05-22 00:13:01,058][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_3.predict)=99.44%
# [ 2019-05-22 00:13:01,341][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_4.predict)=99.52%
# [ 2019-05-22 00:13:01,350][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-22 00:13:01,635][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_0.predict)=98.90%
# [ 2019-05-22 00:13:01,891][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_1.predict)=99.31%
# [ 2019-05-22 00:13:02,150][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_2.predict)=99.16%
# [ 2019-05-22 00:13:02,410][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_3.predict)=99.14%
# [ 2019-05-22 00:13:02,670][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_4.predict)=99.07%
# [ 2019-05-22 00:13:02,677][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_cv.predict)=99.12%
# [ 2019-05-22 00:13:02,944][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_0.predict)=99.07%
# [ 2019-05-22 00:13:03,222][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_1.predict)=99.11%
# [ 2019-05-22 00:13:03,474][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_2.predict)=99.31%
# [ 2019-05-22 00:13:03,758][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_3.predict)=99.22%
# [ 2019-05-22 00:13:04,017][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_4.predict)=99.09%
# [ 2019-05-22 00:13:04,025][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_cv.predict)=99.16%
# [ 2019-05-22 00:13:04,271][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_0.predict)=99.05%
# [ 2019-05-22 00:13:04,534][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_1.predict)=99.11%
# [ 2019-05-22 00:13:04,805][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_2.predict)=99.07%
# [ 2019-05-22 00:13:05,063][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_3.predict)=99.14%
# [ 2019-05-22 00:13:05,316][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_4.predict)=99.29%
# [ 2019-05-22 00:13:05,323][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_cv.predict)=99.13%
# [ 2019-05-22 00:13:06,080][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_0.predict)=99.37%
# [ 2019-05-22 00:13:06,904][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-22 00:13:07,647][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_2.predict)=99.59%
# [ 2019-05-22 00:13:08,370][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_3.predict)=99.65%
# [ 2019-05-22 00:13:09,102][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_4.predict)=99.70%
# [ 2019-05-22 00:13:09,109][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-22 00:13:09,116][cascade_classifier.calc_f1] Weighted F1 (layer_1 - train.classifier_average)=99.56%
# [ 2019-05-22 00:13:09,123][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-22 00:13:09,364][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-22 00:13:09,593][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_1.predict)=99.61%
# [ 2019-05-22 00:13:09,829][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_2.predict)=99.65%
# [ 2019-05-22 00:13:10,066][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_3.predict)=99.57%
# [ 2019-05-22 00:13:10,292][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_4.predict)=99.55%
# [ 2019-05-22 00:13:10,299][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:10,561][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_0.predict)=99.68%
# [ 2019-05-22 00:13:10,812][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-22 00:13:11,054][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_2.predict)=99.48%
# [ 2019-05-22 00:13:11,291][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_3.predict)=99.54%
# [ 2019-05-22 00:13:11,527][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_4.predict)=99.57%
# [ 2019-05-22 00:13:11,535][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-22 00:13:11,773][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_0.predict)=99.52%
# [ 2019-05-22 00:13:12,004][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_1.predict)=99.63%
# [ 2019-05-22 00:13:12,224][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_2.predict)=99.29%
# [ 2019-05-22 00:13:12,448][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_3.predict)=99.65%
# [ 2019-05-22 00:13:12,669][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_4.predict)=99.68%
# [ 2019-05-22 00:13:12,677][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-22 00:13:12,921][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_0.predict)=99.55%
# [ 2019-05-22 00:13:13,129][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_1.predict)=99.59%
# [ 2019-05-22 00:13:13,372][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_2.predict)=99.57%
# [ 2019-05-22 00:13:13,599][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_3.predict)=99.59%
# [ 2019-05-22 00:13:13,812][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_4.predict)=99.46%
# [ 2019-05-22 00:13:13,819][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-22 00:13:14,074][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_0.predict)=99.05%
# [ 2019-05-22 00:13:14,288][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_1.predict)=99.09%
# [ 2019-05-22 00:13:14,531][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_2.predict)=99.20%
# [ 2019-05-22 00:13:14,751][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_3.predict)=99.18%
# [ 2019-05-22 00:13:14,992][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_4.predict)=99.14%
# [ 2019-05-22 00:13:15,000][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_cv.predict)=99.13%
# [ 2019-05-22 00:13:15,251][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_0.predict)=99.24%
# [ 2019-05-22 00:13:15,470][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_1.predict)=99.09%
# [ 2019-05-22 00:13:15,686][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_2.predict)=99.03%
# [ 2019-05-22 00:13:15,902][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_3.predict)=99.14%
# [ 2019-05-22 00:13:16,108][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_4.predict)=98.99%
# [ 2019-05-22 00:13:16,115][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_cv.predict)=99.10%
# [ 2019-05-22 00:13:16,357][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_0.predict)=99.33%
# [ 2019-05-22 00:13:16,560][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_1.predict)=99.18%
# [ 2019-05-22 00:13:16,767][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_2.predict)=99.26%
# [ 2019-05-22 00:13:16,988][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_3.predict)=99.20%
# [ 2019-05-22 00:13:17,197][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_4.predict)=99.00%
# [ 2019-05-22 00:13:17,204][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_cv.predict)=99.19%
# [ 2019-05-22 00:13:17,948][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_0.predict)=99.59%
# [ 2019-05-22 00:13:18,655][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_1.predict)=99.57%
# [ 2019-05-22 00:13:19,317][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_2.predict)=99.53%
# [ 2019-05-22 00:13:19,998][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_3.predict)=99.50%
# [ 2019-05-22 00:13:20,740][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_4.predict)=99.55%
# [ 2019-05-22 00:13:20,747][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-22 00:13:20,754][cascade_classifier.calc_f1] Weighted F1 (layer_2 - train.classifier_average)=99.57%
# [ 2019-05-22 00:13:20,762][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-22 00:13:21,013][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-22 00:13:21,246][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_1.predict)=99.48%
# [ 2019-05-22 00:13:21,487][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_2.predict)=99.52%
# [ 2019-05-22 00:13:21,728][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_3.predict)=99.70%
# [ 2019-05-22 00:13:21,961][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-22 00:13:21,968][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-22 00:13:22,212][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_0.predict)=99.54%
# [ 2019-05-22 00:13:22,433][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_1.predict)=99.67%
# [ 2019-05-22 00:13:22,668][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_2.predict)=99.53%
# [ 2019-05-22 00:13:22,898][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_3.predict)=99.50%
# [ 2019-05-22 00:13:23,166][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-22 00:13:23,175][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-22 00:13:23,450][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_0.predict)=99.59%
# [ 2019-05-22 00:13:23,688][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_1.predict)=99.52%
# [ 2019-05-22 00:13:23,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_2.predict)=99.54%
# [ 2019-05-22 00:13:24,111][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_3.predict)=99.40%
# [ 2019-05-22 00:13:24,350][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_4.predict)=99.74%
# [ 2019-05-22 00:13:24,357][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:24,649][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_0.predict)=99.37%
# [ 2019-05-22 00:13:24,864][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_1.predict)=99.39%
# [ 2019-05-22 00:13:25,087][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_2.predict)=99.67%
# [ 2019-05-22 00:13:25,310][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_3.predict)=99.68%
# [ 2019-05-22 00:13:25,542][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_4.predict)=99.65%
# [ 2019-05-22 00:13:25,549][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_cv.predict)=99.55%
# [ 2019-05-22 00:13:25,800][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_0.predict)=99.27%
# [ 2019-05-22 00:13:26,025][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_1.predict)=99.20%
# [ 2019-05-22 00:13:26,238][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_2.predict)=98.94%
# [ 2019-05-22 00:13:26,461][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_3.predict)=98.77%
# [ 2019-05-22 00:13:26,705][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_4.predict)=99.03%
# [ 2019-05-22 00:13:26,714][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_cv.predict)=99.04%
# [ 2019-05-22 00:13:26,983][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_0.predict)=99.26%
# [ 2019-05-22 00:13:27,211][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_1.predict)=99.22%
# [ 2019-05-22 00:13:27,424][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_2.predict)=99.16%
# [ 2019-05-22 00:13:27,655][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_3.predict)=99.24%
# [ 2019-05-22 00:13:27,890][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_4.predict)=98.98%
# [ 2019-05-22 00:13:27,897][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_cv.predict)=99.17%
# [ 2019-05-22 00:13:28,158][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_0.predict)=99.16%
# [ 2019-05-22 00:13:28,390][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_1.predict)=99.05%
# [ 2019-05-22 00:13:28,617][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_2.predict)=99.13%
# [ 2019-05-22 00:13:28,844][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_3.predict)=99.22%
# [ 2019-05-22 00:13:29,049][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_4.predict)=99.05%
# [ 2019-05-22 00:13:29,055][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_cv.predict)=99.12%
# [ 2019-05-22 00:13:29,782][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-22 00:13:30,451][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_1.predict)=99.52%
# [ 2019-05-22 00:13:31,117][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_2.predict)=99.80%
# [ 2019-05-22 00:13:31,774][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_3.predict)=99.52%
# [ 2019-05-22 00:13:32,433][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_4.predict)=99.55%
# [ 2019-05-22 00:13:32,440][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-22 00:13:32,447][cascade_classifier.calc_f1] Weighted F1 (layer_3 - train.classifier_average)=99.55%
# [ 2019-05-22 00:13:32,454][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-22 00:13:32,678][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_0.predict)=99.55%
# [ 2019-05-22 00:13:32,886][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_1.predict)=99.63%
# [ 2019-05-22 00:13:33,100][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_2.predict)=99.44%
# [ 2019-05-22 00:13:33,311][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_3.predict)=99.46%
# [ 2019-05-22 00:13:33,519][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_4.predict)=99.70%
# [ 2019-05-22 00:13:33,526][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:33,760][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_0.predict)=99.61%
# [ 2019-05-22 00:13:33,972][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-22 00:13:34,185][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_2.predict)=99.61%
# [ 2019-05-22 00:13:34,406][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_3.predict)=99.59%
# [ 2019-05-22 00:13:34,617][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_4.predict)=99.48%
# [ 2019-05-22 00:13:34,624][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-22 00:13:34,865][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_0.predict)=99.65%
# [ 2019-05-22 00:13:35,079][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_1.predict)=99.44%
# [ 2019-05-22 00:13:35,292][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_2.predict)=99.57%
# [ 2019-05-22 00:13:35,512][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_3.predict)=99.52%
# [ 2019-05-22 00:13:35,722][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_4.predict)=99.65%
# [ 2019-05-22 00:13:35,728][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:35,973][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_0.predict)=99.59%
# [ 2019-05-22 00:13:36,185][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_1.predict)=99.50%
# [ 2019-05-22 00:13:36,423][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_2.predict)=99.57%
# [ 2019-05-22 00:13:36,654][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_3.predict)=99.54%
# [ 2019-05-22 00:13:36,881][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_4.predict)=99.59%
# [ 2019-05-22 00:13:36,887][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:37,141][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_0.predict)=99.18%
# [ 2019-05-22 00:13:37,362][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_1.predict)=98.96%
# [ 2019-05-22 00:13:37,597][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_2.predict)=99.20%
# [ 2019-05-22 00:13:37,842][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_3.predict)=99.27%
# [ 2019-05-22 00:13:38,078][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_4.predict)=99.07%
# [ 2019-05-22 00:13:38,085][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_cv.predict)=99.14%
# [ 2019-05-22 00:13:38,352][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_0.predict)=99.11%
# [ 2019-05-22 00:13:38,588][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_1.predict)=99.22%
# [ 2019-05-22 00:13:38,825][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_2.predict)=99.13%
# [ 2019-05-22 00:13:39,045][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_3.predict)=99.07%
# [ 2019-05-22 00:13:39,261][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_4.predict)=99.09%
# [ 2019-05-22 00:13:39,267][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_cv.predict)=99.12%
# [ 2019-05-22 00:13:39,513][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_0.predict)=98.77%
# [ 2019-05-22 00:13:39,743][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_1.predict)=98.98%
# [ 2019-05-22 00:13:39,972][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_2.predict)=99.05%
# [ 2019-05-22 00:13:40,212][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_3.predict)=99.09%
# [ 2019-05-22 00:13:40,454][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_4.predict)=99.11%
# [ 2019-05-22 00:13:40,461][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_cv.predict)=99.00%
# [ 2019-05-22 00:13:41,108][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_0.predict)=99.52%
# [ 2019-05-22 00:13:41,739][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-22 00:13:42,434][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_2.predict)=99.67%
# [ 2019-05-22 00:13:43,075][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_3.predict)=99.57%
# [ 2019-05-22 00:13:43,712][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_4.predict)=99.53%
# [ 2019-05-22 00:13:43,719][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-22 00:13:43,726][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=99.56%
# [ 2019-05-22 00:13:43,733][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(26886, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-22 00:13:43,953][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=99.50%
# [ 2019-05-22 00:13:44,162][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=99.61%
# [ 2019-05-22 00:13:44,372][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=99.61%
# [ 2019-05-22 00:13:44,581][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=99.68%
# [ 2019-05-22 00:13:44,791][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-22 00:13:44,797][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:45,039][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=99.59%
# [ 2019-05-22 00:13:45,266][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=99.52%
# [ 2019-05-22 00:13:45,485][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=99.55%
# [ 2019-05-22 00:13:45,702][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=99.52%
# [ 2019-05-22 00:13:45,943][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-22 00:13:45,950][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:46,187][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_0.predict)=99.63%
# [ 2019-05-22 00:13:46,402][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_1.predict)=99.63%
# [ 2019-05-22 00:13:46,624][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_2.predict)=99.63%
# [ 2019-05-22 00:13:46,828][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_3.predict)=99.44%
# [ 2019-05-22 00:13:47,047][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_4.predict)=99.46%
# [ 2019-05-22 00:13:47,054][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:47,281][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_0.predict)=99.50%
# [ 2019-05-22 00:13:47,492][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_1.predict)=99.48%
# [ 2019-05-22 00:13:47,706][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_2.predict)=99.65%
# [ 2019-05-22 00:13:47,935][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_3.predict)=99.57%
# [ 2019-05-22 00:13:48,154][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_4.predict)=99.63%
# [ 2019-05-22 00:13:48,160][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_cv.predict)=99.56%
# [ 2019-05-22 00:13:48,407][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_0.predict)=99.11%
# [ 2019-05-22 00:13:48,630][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_1.predict)=99.11%
# [ 2019-05-22 00:13:48,864][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_2.predict)=99.14%
# [ 2019-05-22 00:13:49,096][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_3.predict)=99.20%
# [ 2019-05-22 00:13:49,317][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_4.predict)=99.35%
# [ 2019-05-22 00:13:49,325][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_cv.predict)=99.18%
# [ 2019-05-22 00:13:49,551][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_0.predict)=98.94%
# [ 2019-05-22 00:13:49,786][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_1.predict)=99.22%
# [ 2019-05-22 00:13:50,021][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_2.predict)=99.13%
# [ 2019-05-22 00:13:50,240][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_3.predict)=99.22%
# [ 2019-05-22 00:13:50,456][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_4.predict)=99.20%
# [ 2019-05-22 00:13:50,463][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_cv.predict)=99.14%
# [ 2019-05-22 00:13:50,700][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_0.predict)=99.13%
# [ 2019-05-22 00:13:50,918][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_1.predict)=98.89%
# [ 2019-05-22 00:13:51,135][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=99.05%
# [ 2019-05-22 00:13:51,376][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=99.20%
# [ 2019-05-22 00:13:51,622][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=99.20%
# [ 2019-05-22 00:13:51,628][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=99.09%
# [ 2019-05-22 00:13:52,299][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.67%
# [ 2019-05-22 00:13:52,947][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.48%
# [ 2019-05-22 00:13:53,585][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.48%
# [ 2019-05-22 00:13:54,208][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.61%
# [ 2019-05-22 00:13:54,845][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.61%
# [ 2019-05-22 00:13:54,852][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.57%
# [ 2019-05-22 00:13:54,859][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.56%
# [ 2019-05-22 00:13:54,860][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=3, weighted_f1_train=99.57%, weighted_f1_test=0.00%
# [ 2019-05-22 00:13:54,865][cascade_classifier.transform] X_groups_test.shape=[(6726, 4)]
# [ 2019-05-22 00:13:54,866][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-22 00:13:54,867][cascade_classifier.transform] X_test.shape=(6726, 4)
# [ 2019-05-22 00:13:54,868][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6726, 4)
# [ 2019-05-22 00:13:55,018][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6726, 52)
# [ 2019-05-22 00:13:55,182][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(6726, 52)
# [ 2019-05-22 00:13:55,341][cascade_classifier.transform] X_groups_test.shape=[(26886, 4)]
# [ 2019-05-22 00:13:55,342][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-22 00:13:55,343][cascade_classifier.transform] X_test.shape=(26886, 4)
# [ 2019-05-22 00:13:55,345][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(26886, 4)
# [ 2019-05-22 00:13:55,837][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(26886, 52)
# [ 2019-05-22 00:13:56,415][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(26886, 52)
# [ 2019-05-22 00:13:57,018][cascade_classifier.fit_transform] X_groups_train.shape=[(26887, 4)],y_train.shape=(26887,),X_groups_test.shape=no_test,y_test.shape=no_test
# [ 2019-05-22 00:13:57,019][cascade_classifier.fit_transform] group_dims=[4]
# [ 2019-05-22 00:13:57,020][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-05-22 00:13:57,021][cascade_classifier.fit_transform] group_ends=[4]
# [ 2019-05-22 00:13:57,023][cascade_classifier.fit_transform] X_train.shape=(26887, 4),X_test.shape=(0, 4)
# [ 2019-05-22 00:13:57,025][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(26887, 4), X_cur_test.shape=(0, 4)
# [ 2019-05-22 00:13:57,200][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-22 00:13:57,363][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_1.predict)=99.50%
# [ 2019-05-22 00:13:57,521][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_2.predict)=99.59%
# [ 2019-05-22 00:13:57,678][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_3.predict)=99.33%
# [ 2019-05-22 00:13:57,841][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_4.predict)=99.44%
# [ 2019-05-22 00:13:57,847][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_cv.predict)=99.46%
# [ 2019-05-22 00:13:58,020][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_0.predict)=99.24%
# [ 2019-05-22 00:13:58,183][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-22 00:13:58,343][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_2.predict)=99.50%
# [ 2019-05-22 00:13:58,500][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_3.predict)=99.29%
# [ 2019-05-22 00:13:58,662][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_4.predict)=99.52%
# [ 2019-05-22 00:13:58,668][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_cv.predict)=99.42%
# [ 2019-05-22 00:13:58,844][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_0.predict)=99.48%
# [ 2019-05-22 00:13:59,004][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_1.predict)=99.42%
# [ 2019-05-22 00:13:59,168][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_2.predict)=99.48%
# [ 2019-05-22 00:13:59,328][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_3.predict)=99.40%
# [ 2019-05-22 00:13:59,490][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-22 00:13:59,496][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_cv.predict)=99.44%
# [ 2019-05-22 00:13:59,669][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_0.predict)=99.57%
# [ 2019-05-22 00:13:59,829][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_1.predict)=99.50%
# [ 2019-05-22 00:13:59,990][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-22 00:14:00,149][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_3.predict)=99.37%
# [ 2019-05-22 00:14:00,308][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_4.predict)=99.48%
# [ 2019-05-22 00:14:00,314][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_cv.predict)=99.48%
# [ 2019-05-22 00:14:00,373][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_0.predict)=98.90%
# [ 2019-05-22 00:14:00,416][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_1.predict)=98.94%
# [ 2019-05-22 00:14:00,460][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_2.predict)=99.03%
# [ 2019-05-22 00:14:00,505][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_3.predict)=98.77%
# [ 2019-05-22 00:14:00,547][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_4.predict)=98.79%
# [ 2019-05-22 00:14:00,553][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_cv.predict)=98.89%
# [ 2019-05-22 00:14:00,611][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_0.predict)=98.79%
# [ 2019-05-22 00:14:00,655][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_1.predict)=98.76%
# [ 2019-05-22 00:14:00,698][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_2.predict)=98.94%
# [ 2019-05-22 00:14:00,739][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_3.predict)=98.85%
# [ 2019-05-22 00:14:00,785][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_4.predict)=99.14%
# [ 2019-05-22 00:14:00,791][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_cv.predict)=98.90%
# [ 2019-05-22 00:14:00,848][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_0.predict)=98.83%
# [ 2019-05-22 00:14:00,891][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_1.predict)=99.01%
# [ 2019-05-22 00:14:00,936][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_2.predict)=98.72%
# [ 2019-05-22 00:14:00,980][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_3.predict)=99.07%
# [ 2019-05-22 00:14:01,023][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_4.predict)=98.83%
# [ 2019-05-22 00:14:01,029][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_cv.predict)=98.89%
# [ 2019-05-22 00:14:01,142][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_0.predict)=61.05%
# [ 2019-05-22 00:14:01,244][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_1.predict)=60.77%
# [ 2019-05-22 00:14:01,343][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_2.predict)=61.32%
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [ 2019-05-22 00:14:01,445][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_3.predict)=60.56%
# [ 2019-05-22 00:14:01,552][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_4.predict)=61.07%
# [ 2019-05-22 00:14:01,559][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_cv.predict)=60.96%
# [ 2019-05-22 00:14:01,567][cascade_classifier.calc_f1] Weighted F1 (layer_0 - train.classifier_average)=99.46%
# ...
# [ 2019-05-22 01:05:55,339][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_2.predict)=75.30%
# [ 2019-05-22 01:05:56,095][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_3.predict)=74.03%
# [ 2019-05-22 01:05:56,873][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_4.predict)=74.62%
# [ 2019-05-22 01:05:56,879][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_cv.predict)=74.96%
# [ 2019-05-22 01:05:57,675][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_0.predict)=75.26%
# [ 2019-05-22 01:05:58,477][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_1.predict)=74.85%
# [ 2019-05-22 01:05:59,246][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_2.predict)=75.43%
# [ 2019-05-22 01:06:00,046][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_3.predict)=73.89%
# [ 2019-05-22 01:06:00,872][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_4.predict)=75.57%
# [ 2019-05-22 01:06:00,878][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_cv.predict)=75.00%
# [ 2019-05-22 01:06:00,885][cascade_classifier.calc_f1] Weighted F1 (layer_1 - train.classifier_average)=74.97%
# [ 2019-05-22 01:06:00,888][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(26892, 16), X_cur_test.shape=(0, 16)
# [ 2019-05-22 01:06:01,713][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_0.predict)=75.32%
# [ 2019-05-22 01:06:02,525][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_1.predict)=74.84%
# [ 2019-05-22 01:06:03,336][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_2.predict)=75.27%
# [ 2019-05-22 01:06:04,102][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_3.predict)=75.69%
# [ 2019-05-22 01:06:04,930][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_4.predict)=75.08%
# [ 2019-05-22 01:06:04,937][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_cv.predict)=75.25%
# [ 2019-05-22 01:06:05,762][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_0.predict)=76.01%
# [ 2019-05-22 01:06:06,513][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_1.predict)=74.56%
# [ 2019-05-22 01:06:07,343][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_2.predict)=74.78%
# [ 2019-05-22 01:06:08,175][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_3.predict)=75.07%
# [ 2019-05-22 01:06:08,986][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_4.predict)=76.04%
# [ 2019-05-22 01:06:08,994][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_cv.predict)=75.29%
# [ 2019-05-22 01:06:09,001][cascade_classifier.calc_f1] Weighted F1 (layer_2 - train.classifier_average)=75.29%
# [ 2019-05-22 01:06:09,004][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(26892, 16), X_cur_test.shape=(0, 16)
# [ 2019-05-22 01:06:09,812][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_0.predict)=75.06%
# [ 2019-05-22 01:06:10,613][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_1.predict)=76.27%
# [ 2019-05-22 01:06:11,412][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_2.predict)=74.77%
# [ 2019-05-22 01:06:12,217][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_3.predict)=75.19%
# [ 2019-05-22 01:06:13,036][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_4.predict)=75.23%
# [ 2019-05-22 01:06:13,043][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_cv.predict)=75.31%
# [ 2019-05-22 01:06:13,875][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_0.predict)=75.57%
# [ 2019-05-22 01:06:14,696][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_1.predict)=75.37%
# [ 2019-05-22 01:06:15,506][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_2.predict)=75.35%
# [ 2019-05-22 01:06:16,292][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_3.predict)=74.59%
# [ 2019-05-22 01:06:17,089][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_4.predict)=75.68%
# [ 2019-05-22 01:06:17,096][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_cv.predict)=75.31%
# [ 2019-05-22 01:06:17,103][cascade_classifier.calc_f1] Weighted F1 (layer_3 - train.classifier_average)=75.32%
# [ 2019-05-22 01:06:17,106][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(26892, 16), X_cur_test.shape=(0, 16)
# [ 2019-05-22 01:06:17,908][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_0.predict)=74.77%
# [ 2019-05-22 01:06:18,696][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_1.predict)=75.86%
# [ 2019-05-22 01:06:19,507][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_2.predict)=74.45%
# [ 2019-05-22 01:06:20,248][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_3.predict)=75.77%
# [ 2019-05-22 01:06:21,044][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_4.predict)=75.74%
# [ 2019-05-22 01:06:21,050][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_cv.predict)=75.32%
# [ 2019-05-22 01:06:21,870][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_0.predict)=75.83%
# [ 2019-05-22 01:06:22,664][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_1.predict)=74.59%
# [ 2019-05-22 01:06:23,437][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_2.predict)=76.44%
# [ 2019-05-22 01:06:24,251][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_3.predict)=74.67%
# [ 2019-05-22 01:06:25,044][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_4.predict)=75.04%
# [ 2019-05-22 01:06:25,050][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_cv.predict)=75.32%
# [ 2019-05-22 01:06:25,058][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=75.31%
# [ 2019-05-22 01:06:25,061][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(26892, 16), X_cur_test.shape=(0, 16)
# [ 2019-05-22 01:06:25,852][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=75.23%
# [ 2019-05-22 01:06:26,612][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=75.29%
# [ 2019-05-22 01:06:27,384][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=74.99%
# [ 2019-05-22 01:06:28,185][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=75.17%
# [ 2019-05-22 01:06:28,938][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=75.86%
# [ 2019-05-22 01:06:28,944][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=75.31%
# [ 2019-05-22 01:06:29,722][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=74.65%
# [ 2019-05-22 01:06:30,460][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=76.05%
# [ 2019-05-22 01:06:31,204][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=75.92%
# [ 2019-05-22 01:06:31,959][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=74.25%
# [ 2019-05-22 01:06:32,757][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=75.67%
# [ 2019-05-22 01:06:32,763][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=75.31%
# [ 2019-05-22 01:06:32,771][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=75.33%
# [ 2019-05-22 01:06:32,773][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(26892, 16), X_cur_test.shape=(0, 16)
# [ 2019-05-22 01:06:33,583][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_0.predict)=74.85%
# [ 2019-05-22 01:06:34,362][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_1.predict)=75.57%
# [ 2019-05-22 01:06:35,151][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_2.predict)=74.86%
# [ 2019-05-22 01:06:35,909][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_3.predict)=74.86%
# [ 2019-05-22 01:06:36,695][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_4.predict)=76.43%
# [ 2019-05-22 01:06:36,702][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_cv.predict)=75.31%
# [ 2019-05-22 01:06:37,472][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_0.predict)=75.92%
# [ 2019-05-22 01:06:38,258][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_1.predict)=75.16%
# [ 2019-05-22 01:06:39,079][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_2.predict)=74.97%
# [ 2019-05-22 01:06:39,890][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_3.predict)=74.59%
# [ 2019-05-22 01:06:40,688][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_4.predict)=75.73%
# [ 2019-05-22 01:06:40,695][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_cv.predict)=75.27%
# [ 2019-05-22 01:06:40,703][cascade_classifier.calc_f1] Weighted F1 (layer_6 - train.classifier_average)=75.28%
# [ 2019-05-22 01:06:40,705][cascade_classifier.fit_transform] [layer=7] look_indexs=[0], X_cur_train.shape=(26892, 16), X_cur_test.shape=(0, 16)
# [ 2019-05-22 01:06:41,481][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_0.predict)=75.50%
# [ 2019-05-22 01:06:42,269][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_1.predict)=75.22%
# [ 2019-05-22 01:06:43,024][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_2.predict)=74.79%
# [ 2019-05-22 01:06:43,783][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_3.predict)=75.00%
# [ 2019-05-22 01:06:44,591][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_4.predict)=75.84%
# [ 2019-05-22 01:06:44,598][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_0 - 5_folds.train_cv.predict)=75.27%
# [ 2019-05-22 01:06:45,348][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_0.predict)=75.58%
# [ 2019-05-22 01:06:46,162][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_1.predict)=74.39%
# [ 2019-05-22 01:06:46,913][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_2.predict)=75.82%
# [ 2019-05-22 01:06:47,704][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_3.predict)=74.99%
# [ 2019-05-22 01:06:48,483][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_4.predict)=75.51%
# [ 2019-05-22 01:06:48,490][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_7 - estimator_1 - 5_folds.train_cv.predict)=75.26%
# [ 2019-05-22 01:06:48,497][cascade_classifier.calc_f1] Weighted F1 (layer_7 - train.classifier_average)=75.27%
# [ 2019-05-22 01:06:48,500][cascade_classifier.fit_transform] [layer=8] look_indexs=[0], X_cur_train.shape=(26892, 16), X_cur_test.shape=(0, 16)
# [ 2019-05-22 01:06:49,298][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_0 - 5_folds.train_0.predict)=75.38%
# [ 2019-05-22 01:06:50,080][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_0 - 5_folds.train_1.predict)=75.52%
# [ 2019-05-22 01:06:50,833][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_0 - 5_folds.train_2.predict)=75.23%
# [ 2019-05-22 01:06:51,613][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_0 - 5_folds.train_3.predict)=75.59%
# [ 2019-05-22 01:06:52,400][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_0 - 5_folds.train_4.predict)=74.75%
# [ 2019-05-22 01:06:52,407][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_0 - 5_folds.train_cv.predict)=75.30%
# [ 2019-05-22 01:06:53,189][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_1 - 5_folds.train_0.predict)=75.15%
# [ 2019-05-22 01:06:54,000][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_1 - 5_folds.train_1.predict)=75.79%
# [ 2019-05-22 01:06:54,783][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_1 - 5_folds.train_2.predict)=74.97%
# [ 2019-05-22 01:06:55,548][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_1 - 5_folds.train_3.predict)=75.37%
# [ 2019-05-22 01:06:56,282][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_1 - 5_folds.train_4.predict)=75.01%
# [ 2019-05-22 01:06:56,289][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_8 - estimator_1 - 5_folds.train_cv.predict)=75.27%
# [ 2019-05-22 01:06:56,296][cascade_classifier.calc_f1] Weighted F1 (layer_8 - train.classifier_average)=75.29%
# [ 2019-05-22 01:06:56,297][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=6, weighted_f1_train=75.33%, weighted_f1_test=0.00%
# [ 2019-05-22 01:06:56,299][cascade_classifier.transform] X_groups_test.shape=[(6720, 4)]
# [ 2019-05-22 01:06:56,301][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-22 01:06:56,302][cascade_classifier.transform] X_test.shape=(6720, 4)
# [ 2019-05-22 01:06:56,303][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6720, 4)
# [ 2019-05-22 01:06:56,314][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6720, 16)
# [ 2019-05-22 01:06:56,326][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(6720, 16)
# [ 2019-05-22 01:06:56,338][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(6720, 16)
# [ 2019-05-22 01:06:56,348][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(6720, 16)
# [ 2019-05-22 01:06:56,360][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(6720, 16)
# [ 2019-05-22 01:06:56,373][cascade_classifier.transform] X_groups_test.shape=[(26892, 4)]
# [ 2019-05-22 01:06:56,374][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-22 01:06:56,375][cascade_classifier.transform] X_test.shape=(26892, 4)
# [ 2019-05-22 01:06:56,376][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(26892, 4)
# [ 2019-05-22 01:06:56,414][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(26892, 16)
# [ 2019-05-22 01:06:56,449][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(26892, 16)
# [ 2019-05-22 01:06:56,485][cascade_classifier.transform] [layer=3] look_indexs=[0], X_cur_test.shape=(26892, 16)
# [ 2019-05-22 01:06:56,522][cascade_classifier.transform] [layer=4] look_indexs=[0], X_cur_test.shape=(26892, 16)
# [ 2019-05-22 01:06:56,558][cascade_classifier.transform] [layer=5] look_indexs=[0], X_cur_test.shape=(26892, 16)
