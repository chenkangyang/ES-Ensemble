# %%
import os
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import StratifiedKFold

from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append("..") 
from gcforest.gcforest import GCForest

import xlwt
# Out:
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# # 数据及参数

# %%
random_seed = 42
cv=3
score = 'f1_weighted'

# %%
def get_toy_config():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 10
    ca_config["early_stopping_rounds"] = 3
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
path = os.getcwd()+'/../data/20122018freshwater_four_feature.csv'
data = pd.read_csv(path, na_values = np.nan)

# %%
X = data.drop(['本周水质'], axis=1).values # Series
y = data['本周水质'].values.reshape(-1,1) - 1

# 1. 中位数填充缺失值，2.Z-score标准化
clean_pipeline = Pipeline([('imputer', preprocessing.Imputer(missing_values='NaN',strategy="median")),
                           ('std_scaler', preprocessing.StandardScaler())])
X = clean_pipeline.fit_transform(X)

# %%
X.shape
# Out:
# (33612, 4)

# %% [markdown]
# # k折交叉验证

# %%
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1
# function：使用5折交叉验证统计各类别5次平均后的Acc，5次平均后的F1，和模型的总Acc以及总Weighted F1

# Input: 
#     X: 总样本
#     y: 总样本
#     model: function
#     cv: cross_validation的次数
# Output:
#     Acc_mean, 各类别的Acc
#     F1_mean, 各类别F1
#     Support_mean, 各类别预测样本占总样本的比重
#     Acc, 总Acc
#     F1_weighted 总Weighted F1


def kftrain(X, y, model, cv):
    model_name = model.__class__.__name__

    n_samples = X.shape[0]
    n_features = X.shape[1]
    n_class = np.unique(y).shape[0]

    Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _Acc_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组test data的cv个acc
    _F1_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 第i行：类别i的在cv组train data的cv个acc
    cv_F1_weighted = np.zeros(cv) # 5次 test data 的F1_weighted
    _cv_F1_weighted = np.zeros(cv) # 5次 train data 的F1_weighted
    cv_Acc = np.zeros(cv) # 5次test data的Acc
    _cv_Acc = np.zeros(cv) # 5次train data的Acc
    # 各类别的Support，每个类别的support由5次fold后得到的5个support求平均得到，这里support：各类别样本占总样本的比列
    # 各类别的F1，由5次fold后得到的5个F1求平均得到
    # 所以，Weighted F1 等于“5次fold得到的5个 Weighted F1 求平均得到” ——等价于—— “6个support*6个F1”得到
    Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后test data各类别的support
    _Support_matrix = np.zeros((n_class, cv)) # 矩阵(6,5) 5次fold后train data各类别的support
    
    # 各类别的Mean，SD
    Acc_mean_class = np.zeros(6)
    _Acc_mean_class = np.zeros(6)
    Acc_SD_class = np.zeros(6)
    _Acc_SD_class = np.zeros(6)
    F1_mean_class = np.zeros(6)
    _F1_mean_class = np.zeros(6)
    F1_SD_class = np.zeros(6)
    _F1_SD_class = np.zeros(6)
    
    k = 0
    skf = StratifiedKFold(n_splits=cv) # 定义5折分层划分器
    
    for train_index, test_index in skf.split(X, y):
        K_train_x, K_test_x = X[train_index], X[test_index]
        K_train_y, K_test_y = y[train_index], y[test_index]
        if model_name == 'GCForest':
            model.fit_transform(K_train_x, K_train_y.reshape(K_train_y.shape[0]))
        else:
            model.fit(K_train_x, K_train_y)
    
        K_test_y_pred = model.predict(K_test_x)
        K_train_y_pred = model.predict(K_train_x)
        
        # 由混淆矩阵计算各类别的Acc
        test_cm = confusion_matrix(K_test_y, K_test_y_pred)
        train_cm = confusion_matrix(K_train_y, K_train_y_pred)
        test_acc_all_class = np.zeros(n_class) # 6个类别上的测试acc
        train_acc_all_class = np.zeros(n_class) # 6个类别上的训练acc
        
        i = 0
        for c in test_cm:
            test_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        Acc_matrix[:,k] = test_acc_all_class
        
        i = 0
        for c in train_cm:
            train_acc_all_class[i] = c[i]/np.sum(c)
            i += 1
        _Acc_matrix[:,k] = train_acc_all_class
        
        # 由classification_report提取各类别的F1
        cr = classification_report(K_test_y, K_test_y_pred, digits=4)
        _cr = classification_report(K_train_y, K_train_y_pred, digits=4)
        test_f1_all_class = np.zeros(n_class) # test data 6个类别上的测试f1
        train_f1_all_class = np.zeros(n_class) # train data 6个类别上的训练f1
        support_all_class = np.zeros(n_class) # test data 6个类别的support
        _support_all_class = np.zeros(n_class) # train data 6个类别的support
        
        i = 0
        for l in range(2,8): 
            test_f1_all_class[i] = float(cr.splitlines()[l].split()[3])
            train_f1_all_class[i] = float(_cr.splitlines()[l].split()[3])
            support_all_class[i] = float(cr.splitlines()[l].split()[4])/(n_samples/cv)
            _support_all_class[i] = float(_cr.splitlines()[l].split()[4])/(n_samples*(1-1/cv))
            i = i + 1
        F1_matrix[:,k] = test_f1_all_class
        _F1_matrix[:,k] = train_f1_all_class
        Support_matrix[:,k] = support_all_class
        _Support_matrix[:,k] = _support_all_class
        
        # cv_F1_weighted[k] = float(cr.splitlines()[9].split()[5]) # 第k折时的Weighted F1
        cv_F1_weighted[k] = f1_score(K_test_y, K_test_y_pred, average="weighted")
        _cv_F1_weighted[k] = f1_score(K_train_y, K_train_y_pred, average="weighted")
        cv_Acc[k] = accuracy_score(K_test_y, K_test_y_pred)
        _cv_Acc[k] = accuracy_score(K_train_y, K_train_y_pred)
        
        k += 1
    
    Acc_mean = np.mean(Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    _Acc_mean = np.mean(_Acc_matrix, axis=1) # 6个类别的k-fold平均acc
    
    F1_mean = np.mean(F1_matrix, axis=1) # 6个类别的k-fold平均F1
    _F1_mean = np.mean(_F1_matrix, axis=1) # 6个类别的k-fold平均F1
    Support_mean = np.mean(Support_matrix, axis=1) # 6个类别的k-fold平均support
    _Support_mean = np.mean(_Support_matrix, axis=1) # 6个类别的k-fold平均support
    
    Acc = np.mean(Acc_mean)
    _Acc = np.mean(_Acc_mean)
    F1_weighted = np.mean(cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    _F1_weighted = np.mean(_cv_F1_weighted) # 5个Weighted F1 求平均，并可以证明其等价于 np.sum(F1_mean*Support_mean)
    SD_Acc = np.std(cv_Acc)
    _SD_Acc = np.std(cv_Acc)
    SD_F1 = np.std(cv_F1_weighted)
    _SD_F1 = np.std(cv_F1_weighted)
    
    Acc_mean_class = np.mean(Acc_matrix, axis=1)
    _Acc_mean_class = np.mean(_Acc_matrix, axis=1)
    Acc_SD_class = np.std(Acc_matrix, axis=1)
    _Acc_SD_class = np.std(_Acc_matrix, axis=1)
    F1_mean_class = np.mean(F1_matrix, axis=1)
    _F1_mean_class = np.mean(_F1_matrix, axis=1)
    F1_SD_class = np.std(F1_matrix, axis=1)
    _F1_SD_class = np.std(_F1_matrix, axis=1)
    
    # return Acc_mean, F1_mean, Support_mean, Acc, F1_weighted, SD_Acc, SD_F1, Acc_mean_class, Acc_SD_class, F1_mean_class, F1_SD_class
    return Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_mean, _Acc_mean, F1_mean, _F1_mean, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class

# %%
config = get_toy_config()

models = [
    LogisticRegression(),
    LinearDiscriminantAnalysis(),
    SVC(probability=True),
    DecisionTreeClassifier(),
    ExtraTreeClassifier(),
    GaussianNB(),
    KNeighborsClassifier(),
    RandomForestClassifier(random_state=random_seed),
    ExtraTreesClassifier(random_state=random_seed),
    GCForest(config)
]

workbook = xlwt.Workbook(encoding = 'utf-8')  

for model in models:
    model_name = model.__class__.__name__
    print(model_name)
    # Acc_class, F1_class, Support_class, Acc, F1_weighted, SD_Acc, SD_F1, Acc_mean_class, Acc_SD_class, F1_mean_class, F1_SD_class = kftrain(X, y, model, 5)
    Acc_matrix, F1_matrix, Support_matrix, _Acc_matrix, _F1_matrix, _Support_matrix, Acc_class, _Acc_class, F1_class, _F1_class, Acc, _Acc, F1_weighted, _F1_weighted, SD_Acc, _SD_Acc, SD_F1, _SD_F1, Acc_mean_class, _Acc_mean_class, Acc_SD_class, _Acc_SD_class, F1_mean_class, _F1_mean_class, F1_SD_class, _F1_SD_class = kftrain(X, y, model, cv)

    worksheet = workbook.add_sheet(model_name, cell_overwrite_ok=True)
    worksheet.write(0,0, "train_Acc_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+1, j, _Acc_matrix[i,j])

    worksheet.write(0,6, "test_Acc_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+1, j+cv+2, Acc_matrix[i,j])



    worksheet.write(11,0, "train_F1_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+12, j, _F1_matrix[i,j])

    worksheet.write(11,6, "test_F1_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+12, j+cv+2, F1_matrix[i,j])



    worksheet.write(20,0, "train_support_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+21, j, _Support_matrix[i,j])

    worksheet.write(20,6, "test_support_matrix")
    for i in range(6):
        for j in range(cv):
            worksheet.write(i+21, j+cv+2, Support_matrix[i,j])
            
workbook.save("../res/basemodels_10flod.xls")
# Out:
# LogisticRegression
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# LinearDiscriminantAnalysis
# SVC
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:442: UserWarning: The priors do not sum to 1. Renormalizing
#   UserWarning)
# DecisionTreeClassifier
# ExtraTreeClassifier
# GaussianNB
# KNeighborsClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# RandomForestClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ExtraTreesClassifier
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/ipykernel/__main__.py:69: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# [ 2019-05-21 16:32:07,818][cascade_classifier.fit_transform] X_groups_train.shape=[(22406, 4)],y_train.shape=(22406,),X_groups_test.shape=no_test,y_test.shape=no_test
# [ 2019-05-21 16:32:07,819][cascade_classifier.fit_transform] group_dims=[4]
# [ 2019-05-21 16:32:07,821][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-05-21 16:32:07,824][cascade_classifier.fit_transform] group_ends=[4]
# [ 2019-05-21 16:32:07,825][cascade_classifier.fit_transform] X_train.shape=(22406, 4),X_test.shape=(0, 4)
# [ 2019-05-21 16:32:07,828][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(22406, 4), X_cur_test.shape=(0, 4)
# [ 2019-05-21 16:32:07,978][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_0.predict)=99.75%
# GCForest
# [ 2019-05-21 16:32:08,104][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_1.predict)=99.46%
# [ 2019-05-21 16:32:08,241][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_2.predict)=99.58%
# [ 2019-05-21 16:32:08,369][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_3.predict)=99.58%
# [ 2019-05-21 16:32:08,500][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_4.predict)=99.64%
# [ 2019-05-21 16:32:08,506][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_cv.predict)=99.60%
# [ 2019-05-21 16:32:08,655][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_0.predict)=99.69%
# [ 2019-05-21 16:32:08,790][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_1.predict)=99.64%
# [ 2019-05-21 16:32:08,932][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_2.predict)=99.58%
# [ 2019-05-21 16:32:09,065][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_3.predict)=99.42%
# [ 2019-05-21 16:32:09,208][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_4.predict)=99.62%
# [ 2019-05-21 16:32:09,214][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_cv.predict)=99.59%
# [ 2019-05-21 16:32:09,363][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_0.predict)=99.73%
# [ 2019-05-21 16:32:09,494][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_1.predict)=99.62%
# [ 2019-05-21 16:32:09,620][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_2.predict)=99.60%
# [ 2019-05-21 16:32:09,777][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_3.predict)=99.69%
# [ 2019-05-21 16:32:09,915][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_4.predict)=99.64%
# [ 2019-05-21 16:32:09,921][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_cv.predict)=99.66%
# [ 2019-05-21 16:32:10,063][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-21 16:32:10,200][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_1.predict)=99.73%
# [ 2019-05-21 16:32:10,333][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-21 16:32:10,463][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_3.predict)=99.62%
# [ 2019-05-21 16:32:10,614][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_4.predict)=99.80%
# [ 2019-05-21 16:32:10,620][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_cv.predict)=99.62%
# [ 2019-05-21 16:32:10,664][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_0.predict)=99.33%
# [ 2019-05-21 16:32:10,698][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_1.predict)=99.38%
# [ 2019-05-21 16:32:10,730][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_2.predict)=99.11%
# [ 2019-05-21 16:32:10,763][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_3.predict)=99.51%
# [ 2019-05-21 16:32:10,795][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_4.predict)=99.58%
# [ 2019-05-21 16:32:10,801][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_cv.predict)=99.38%
# [ 2019-05-21 16:32:10,843][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_0.predict)=99.37%
# [ 2019-05-21 16:32:10,874][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_1.predict)=99.33%
# [ 2019-05-21 16:32:10,909][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_2.predict)=99.15%
# [ 2019-05-21 16:32:10,939][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_3.predict)=99.26%
# [ 2019-05-21 16:32:10,970][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-21 16:32:10,976][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_cv.predict)=99.30%
# [ 2019-05-21 16:32:11,018][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_0.predict)=99.42%
# [ 2019-05-21 16:32:11,048][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_1.predict)=99.15%
# [ 2019-05-21 16:32:11,081][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_2.predict)=99.35%
# [ 2019-05-21 16:32:11,113][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-21 16:32:11,153][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-21 16:32:11,159][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_cv.predict)=99.34%
# [ 2019-05-21 16:32:11,269][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_0.predict)=61.75%
# [ 2019-05-21 16:32:11,365][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_1.predict)=61.53%
# [ 2019-05-21 16:32:11,477][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_2.predict)=61.90%
# [ 2019-05-21 16:32:11,569][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_3.predict)=61.93%
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [ 2019-05-21 16:32:11,671][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_4.predict)=61.42%
# [ 2019-05-21 16:32:11,679][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_cv.predict)=61.69%
# [ 2019-05-21 16:32:11,686][cascade_classifier.calc_f1] Weighted F1 (layer_0 - train.classifier_average)=99.64%
# [ 2019-05-21 16:32:11,695][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(22406, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:32:11,883][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_0.predict)=99.53%
# [ 2019-05-21 16:32:12,050][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_1.predict)=99.64%
# [ 2019-05-21 16:32:12,252][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_2.predict)=99.62%
# [ 2019-05-21 16:32:12,473][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_3.predict)=99.75%
# [ 2019-05-21 16:32:12,689][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_4.predict)=99.75%
# [ 2019-05-21 16:32:12,697][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_cv.predict)=99.66%
# [ 2019-05-21 16:32:12,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_0.predict)=99.53%
# [ 2019-05-21 16:32:13,092][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_1.predict)=99.60%
# [ 2019-05-21 16:32:13,296][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_2.predict)=99.89%
# [ 2019-05-21 16:32:13,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_3.predict)=99.75%
# [ 2019-05-21 16:32:13,674][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_4.predict)=99.55%
# [ 2019-05-21 16:32:13,681][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_cv.predict)=99.67%
# [ 2019-05-21 16:32:13,890][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_0.predict)=99.62%
# [ 2019-05-21 16:32:14,077][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_1.predict)=99.67%
# [ 2019-05-21 16:32:14,280][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_2.predict)=99.75%
# [ 2019-05-21 16:32:14,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_3.predict)=99.69%
# [ 2019-05-21 16:32:14,653][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_4.predict)=99.64%
# [ 2019-05-21 16:32:14,660][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_cv.predict)=99.67%
# [ 2019-05-21 16:32:14,855][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_0.predict)=99.64%
# [ 2019-05-21 16:32:15,030][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_1.predict)=99.71%
# [ 2019-05-21 16:32:15,225][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_2.predict)=99.75%
# [ 2019-05-21 16:32:15,416][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_3.predict)=99.58%
# [ 2019-05-21 16:32:15,600][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:32:15,606][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_cv.predict)=99.67%
# [ 2019-05-21 16:32:15,788][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_0.predict)=99.31%
# [ 2019-05-21 16:32:15,962][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_1.predict)=99.26%
# [ 2019-05-21 16:32:16,138][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_2.predict)=99.64%
# [ 2019-05-21 16:32:16,304][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:32:16,490][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_4.predict)=99.37%
# [ 2019-05-21 16:32:16,497][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_cv.predict)=99.38%
# [ 2019-05-21 16:32:16,691][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_0.predict)=99.42%
# [ 2019-05-21 16:32:16,846][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-21 16:32:17,019][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_2.predict)=99.33%
# [ 2019-05-21 16:32:17,202][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_3.predict)=99.29%
# [ 2019-05-21 16:32:17,433][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-21 16:32:17,441][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-21 16:32:17,680][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_0.predict)=99.31%
# [ 2019-05-21 16:32:17,849][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_1.predict)=99.37%
# [ 2019-05-21 16:32:18,033][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_2.predict)=99.33%
# [ 2019-05-21 16:32:18,213][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-21 16:32:18,399][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_4.predict)=99.28%
# [ 2019-05-21 16:32:18,406][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_cv.predict)=99.33%
# [ 2019-05-21 16:32:19,091][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_0.predict)=99.69%
# [ 2019-05-21 16:32:19,731][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_1.predict)=99.75%
# [ 2019-05-21 16:32:20,352][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_2.predict)=99.62%
# [ 2019-05-21 16:32:21,003][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_3.predict)=99.66%
# [ 2019-05-21 16:32:21,606][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_4.predict)=99.67%
# [ 2019-05-21 16:32:21,614][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:21,622][cascade_classifier.calc_f1] Weighted F1 (layer_1 - train.classifier_average)=99.68%
# [ 2019-05-21 16:32:21,628][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(22406, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:32:21,852][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_0.predict)=99.78%
# [ 2019-05-21 16:32:22,019][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_1.predict)=99.73%
# [ 2019-05-21 16:32:22,179][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_2.predict)=99.58%
# [ 2019-05-21 16:32:22,351][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_3.predict)=99.67%
# [ 2019-05-21 16:32:22,540][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_4.predict)=99.58%
# [ 2019-05-21 16:32:22,547][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_cv.predict)=99.67%
# [ 2019-05-21 16:32:22,728][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_0.predict)=99.73%
# [ 2019-05-21 16:32:22,875][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_1.predict)=99.62%
# [ 2019-05-21 16:32:23,037][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_2.predict)=99.64%
# [ 2019-05-21 16:32:23,257][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_3.predict)=99.60%
# [ 2019-05-21 16:32:23,469][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_4.predict)=99.75%
# [ 2019-05-21 16:32:23,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_cv.predict)=99.67%
# [ 2019-05-21 16:32:23,665][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_0.predict)=99.69%
# [ 2019-05-21 16:32:23,837][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-21 16:32:23,996][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_2.predict)=99.71%
# [ 2019-05-21 16:32:24,154][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_3.predict)=99.64%
# [ 2019-05-21 16:32:24,333][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_4.predict)=99.78%
# [ 2019-05-21 16:32:24,340][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_cv.predict)=99.67%
# [ 2019-05-21 16:32:24,521][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_0.predict)=99.67%
# [ 2019-05-21 16:32:24,685][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_1.predict)=99.67%
# [ 2019-05-21 16:32:24,853][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_2.predict)=99.75%
# [ 2019-05-21 16:32:25,014][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_3.predict)=99.64%
# [ 2019-05-21 16:32:25,199][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_4.predict)=99.73%
# [ 2019-05-21 16:32:25,205][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:32:25,377][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_0.predict)=99.53%
# [ 2019-05-21 16:32:25,531][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-21 16:32:25,691][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_2.predict)=99.55%
# [ 2019-05-21 16:32:25,853][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_3.predict)=99.42%
# [ 2019-05-21 16:32:25,985][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-21 16:32:25,992][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_cv.predict)=99.45%
# [ 2019-05-21 16:32:26,142][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_0.predict)=99.24%
# [ 2019-05-21 16:32:26,287][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_1.predict)=99.51%
# [ 2019-05-21 16:32:26,431][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_2.predict)=99.42%
# [ 2019-05-21 16:32:26,588][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_3.predict)=99.37%
# [ 2019-05-21 16:32:26,737][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_4.predict)=99.35%
# [ 2019-05-21 16:32:26,744][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_cv.predict)=99.38%
# [ 2019-05-21 16:32:26,916][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_0.predict)=99.42%
# [ 2019-05-21 16:32:27,069][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_1.predict)=99.33%
# [ 2019-05-21 16:32:27,207][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_2.predict)=99.24%
# [ 2019-05-21 16:32:27,382][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_3.predict)=99.42%
# [ 2019-05-21 16:32:27,527][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_4.predict)=99.26%
# [ 2019-05-21 16:32:27,534][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_cv.predict)=99.34%
# [ 2019-05-21 16:32:28,106][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_0.predict)=99.69%
# [ 2019-05-21 16:32:28,655][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_1.predict)=99.73%
# [ 2019-05-21 16:32:29,235][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_2.predict)=99.71%
# [ 2019-05-21 16:32:29,814][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_3.predict)=99.69%
# [ 2019-05-21 16:32:30,360][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_4.predict)=99.60%
# [ 2019-05-21 16:32:30,367][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:30,374][cascade_classifier.calc_f1] Weighted F1 (layer_2 - train.classifier_average)=99.69%
# [ 2019-05-21 16:32:30,380][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(22406, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:32:30,579][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_0.predict)=99.62%
# [ 2019-05-21 16:32:30,749][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_1.predict)=99.75%
# [ 2019-05-21 16:32:30,924][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_2.predict)=99.71%
# [ 2019-05-21 16:32:31,106][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_3.predict)=99.58%
# [ 2019-05-21 16:32:31,282][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_4.predict)=99.80%
# [ 2019-05-21 16:32:31,289][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:32:31,472][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_0.predict)=99.60%
# [ 2019-05-21 16:32:31,654][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_1.predict)=99.84%
# [ 2019-05-21 16:32:31,846][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_2.predict)=99.62%
# [ 2019-05-21 16:32:32,008][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_3.predict)=99.62%
# [ 2019-05-21 16:32:32,182][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_4.predict)=99.69%
# [ 2019-05-21 16:32:32,188][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_cv.predict)=99.67%
# [ 2019-05-21 16:32:32,402][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_0.predict)=99.71%
# [ 2019-05-21 16:32:32,580][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_1.predict)=99.71%
# [ 2019-05-21 16:32:32,761][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_2.predict)=99.62%
# [ 2019-05-21 16:32:32,949][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_3.predict)=99.58%
# [ 2019-05-21 16:32:33,131][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_4.predict)=99.78%
# [ 2019-05-21 16:32:33,139][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:33,351][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_0.predict)=99.58%
# [ 2019-05-21 16:32:33,511][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_1.predict)=99.62%
# [ 2019-05-21 16:32:33,696][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_2.predict)=99.71%
# [ 2019-05-21 16:32:33,875][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_3.predict)=99.80%
# [ 2019-05-21 16:32:34,057][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:32:34,064][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_cv.predict)=99.67%
# [ 2019-05-21 16:32:34,235][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_0.predict)=99.22%
# [ 2019-05-21 16:32:34,410][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_1.predict)=99.31%
# [ 2019-05-21 16:32:34,578][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_2.predict)=99.42%
# [ 2019-05-21 16:32:34,790][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_3.predict)=99.51%
# [ 2019-05-21 16:32:34,993][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_4.predict)=99.37%
# [ 2019-05-21 16:32:35,001][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:32:35,194][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_0.predict)=99.51%
# [ 2019-05-21 16:32:35,363][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_1.predict)=99.53%
# [ 2019-05-21 16:32:35,531][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_2.predict)=99.29%
# [ 2019-05-21 16:32:35,699][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_3.predict)=99.26%
# [ 2019-05-21 16:32:35,851][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_4.predict)=99.42%
# [ 2019-05-21 16:32:35,858][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_cv.predict)=99.40%
# [ 2019-05-21 16:32:36,019][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-21 16:32:36,181][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_1.predict)=99.46%
# [ 2019-05-21 16:32:36,340][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_2.predict)=99.29%
# [ 2019-05-21 16:32:36,501][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_3.predict)=99.17%
# [ 2019-05-21 16:32:36,681][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_4.predict)=99.22%
# [ 2019-05-21 16:32:36,688][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_cv.predict)=99.32%
# [ 2019-05-21 16:32:37,251][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_0.predict)=99.71%
# [ 2019-05-21 16:32:37,784][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_1.predict)=99.62%
# [ 2019-05-21 16:32:38,345][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_2.predict)=99.69%
# [ 2019-05-21 16:32:38,896][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_3.predict)=99.75%
# [ 2019-05-21 16:32:39,446][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_4.predict)=99.62%
# [ 2019-05-21 16:32:39,452][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:39,460][cascade_classifier.calc_f1] Weighted F1 (layer_3 - train.classifier_average)=99.70%
# [ 2019-05-21 16:32:39,466][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(22406, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:32:39,664][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_0.predict)=99.69%
# [ 2019-05-21 16:32:39,834][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_1.predict)=99.78%
# [ 2019-05-21 16:32:39,998][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_2.predict)=99.60%
# [ 2019-05-21 16:32:40,161][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_3.predict)=99.75%
# [ 2019-05-21 16:32:40,322][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_4.predict)=99.60%
# [ 2019-05-21 16:32:40,328][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:40,510][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_0.predict)=99.73%
# [ 2019-05-21 16:32:40,694][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-21 16:32:40,858][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_2.predict)=99.75%
# [ 2019-05-21 16:32:41,021][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_3.predict)=99.62%
# [ 2019-05-21 16:32:41,191][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_4.predict)=99.73%
# [ 2019-05-21 16:32:41,197][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:41,366][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_0.predict)=99.58%
# [ 2019-05-21 16:32:41,524][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_1.predict)=99.69%
# [ 2019-05-21 16:32:41,696][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_2.predict)=99.69%
# [ 2019-05-21 16:32:41,860][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_3.predict)=99.75%
# [ 2019-05-21 16:32:42,022][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_4.predict)=99.69%
# [ 2019-05-21 16:32:42,028][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:42,195][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_0.predict)=99.69%
# [ 2019-05-21 16:32:42,361][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_1.predict)=99.64%
# [ 2019-05-21 16:32:42,519][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_2.predict)=99.78%
# [ 2019-05-21 16:32:42,697][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_3.predict)=99.71%
# [ 2019-05-21 16:32:42,866][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_4.predict)=99.60%
# [ 2019-05-21 16:32:42,872][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:43,047][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_0.predict)=99.35%
# [ 2019-05-21 16:32:43,205][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_1.predict)=99.24%
# [ 2019-05-21 16:32:43,376][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-21 16:32:43,575][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_3.predict)=99.49%
# [ 2019-05-21 16:32:43,711][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_4.predict)=99.22%
# [ 2019-05-21 16:32:43,718][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_cv.predict)=99.35%
# [ 2019-05-21 16:32:43,884][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_0.predict)=99.42%
# [ 2019-05-21 16:32:44,057][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_1.predict)=99.31%
# [ 2019-05-21 16:32:44,257][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_2.predict)=99.22%
# [ 2019-05-21 16:32:44,428][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_3.predict)=99.33%
# [ 2019-05-21 16:32:44,607][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_4.predict)=99.37%
# [ 2019-05-21 16:32:44,615][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_cv.predict)=99.33%
# [ 2019-05-21 16:32:44,802][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_0.predict)=99.31%
# [ 2019-05-21 16:32:44,980][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_1.predict)=99.33%
# [ 2019-05-21 16:32:45,147][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_2.predict)=99.35%
# [ 2019-05-21 16:32:45,324][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_3.predict)=99.38%
# [ 2019-05-21 16:32:45,489][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_4.predict)=99.26%
# [ 2019-05-21 16:32:45,495][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_cv.predict)=99.33%
# [ 2019-05-21 16:32:46,066][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_0.predict)=99.73%
# [ 2019-05-21 16:32:46,629][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_1.predict)=99.60%
# [ 2019-05-21 16:32:47,221][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_2.predict)=99.71%
# [ 2019-05-21 16:32:47,777][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_3.predict)=99.75%
# [ 2019-05-21 16:32:48,340][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_4.predict)=99.69%
# [ 2019-05-21 16:32:48,347][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_cv.predict)=99.70%
# [ 2019-05-21 16:32:48,356][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=99.68%
# [ 2019-05-21 16:32:48,362][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(22406, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:32:48,549][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=99.75%
# [ 2019-05-21 16:32:48,708][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=99.71%
# [ 2019-05-21 16:32:48,873][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=99.71%
# [ 2019-05-21 16:32:49,038][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=99.60%
# [ 2019-05-21 16:32:49,193][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=99.66%
# [ 2019-05-21 16:32:49,199][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:32:49,367][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=99.73%
# [ 2019-05-21 16:32:49,516][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=99.69%
# [ 2019-05-21 16:32:49,669][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=99.64%
# [ 2019-05-21 16:32:49,850][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=99.64%
# [ 2019-05-21 16:32:50,010][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=99.73%
# [ 2019-05-21 16:32:50,017][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:32:50,186][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_0.predict)=99.62%
# [ 2019-05-21 16:32:50,349][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_1.predict)=99.80%
# [ 2019-05-21 16:32:50,513][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_2.predict)=99.73%
# [ 2019-05-21 16:32:50,665][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_3.predict)=99.58%
# [ 2019-05-21 16:32:50,845][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_4.predict)=99.71%
# [ 2019-05-21 16:32:50,851][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:32:51,026][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_0.predict)=99.71%
# [ 2019-05-21 16:32:51,199][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_1.predict)=99.75%
# [ 2019-05-21 16:32:51,359][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-21 16:32:51,533][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_3.predict)=99.73%
# [ 2019-05-21 16:32:51,697][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_4.predict)=99.73%
# [ 2019-05-21 16:32:51,703][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:51,875][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_0.predict)=99.40%
# [ 2019-05-21 16:32:52,028][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-21 16:32:52,192][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_2.predict)=99.55%
# [ 2019-05-21 16:32:52,329][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_3.predict)=99.15%
# [ 2019-05-21 16:32:52,470][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-21 16:32:52,476][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:32:52,641][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_0.predict)=99.15%
# [ 2019-05-21 16:32:52,799][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-21 16:32:52,960][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_2.predict)=99.33%
# [ 2019-05-21 16:32:53,116][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:32:53,282][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_4.predict)=99.26%
# [ 2019-05-21 16:32:53,289][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_cv.predict)=99.28%
# [ 2019-05-21 16:32:53,458][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_0.predict)=99.42%
# [ 2019-05-21 16:32:53,619][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_1.predict)=99.44%
# [ 2019-05-21 16:32:53,780][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=99.42%
# [ 2019-05-21 16:32:53,951][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-21 16:32:54,107][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=99.35%
# [ 2019-05-21 16:32:54,114][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=99.40%
# [ 2019-05-21 16:32:54,692][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.64%
# [ 2019-05-21 16:32:55,237][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.55%
# [ 2019-05-21 16:32:55,778][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.71%
# [ 2019-05-21 16:32:56,359][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.80%
# [ 2019-05-21 16:32:56,912][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.73%
# [ 2019-05-21 16:32:56,919][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.69%
# [ 2019-05-21 16:32:56,926][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.69%
# [ 2019-05-21 16:32:56,933][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(22406, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:32:57,131][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_0.predict)=99.78%
# [ 2019-05-21 16:32:57,291][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_1.predict)=99.75%
# [ 2019-05-21 16:32:57,462][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_2.predict)=99.69%
# [ 2019-05-21 16:32:57,624][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_3.predict)=99.53%
# [ 2019-05-21 16:32:57,780][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_4.predict)=99.64%
# [ 2019-05-21 16:32:57,787][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:57,964][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_0.predict)=99.73%
# [ 2019-05-21 16:32:58,128][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_1.predict)=99.60%
# [ 2019-05-21 16:32:58,298][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_2.predict)=99.75%
# [ 2019-05-21 16:32:58,459][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_3.predict)=99.58%
# [ 2019-05-21 16:32:58,619][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_4.predict)=99.75%
# [ 2019-05-21 16:32:58,625][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:58,810][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_0.predict)=99.71%
# [ 2019-05-21 16:32:58,977][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_1.predict)=99.71%
# [ 2019-05-21 16:32:59,146][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_2.predict)=99.67%
# [ 2019-05-21 16:32:59,312][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_3.predict)=99.71%
# [ 2019-05-21 16:32:59,477][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_4.predict)=99.62%
# [ 2019-05-21 16:32:59,484][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:32:59,666][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_0.predict)=99.69%
# [ 2019-05-21 16:32:59,843][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_1.predict)=99.64%
# [ 2019-05-21 16:33:00,032][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_2.predict)=99.64%
# [ 2019-05-21 16:33:00,205][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_3.predict)=99.71%
# [ 2019-05-21 16:33:00,372][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_4.predict)=99.71%
# [ 2019-05-21 16:33:00,377][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_cv.predict)=99.68%
# [ 2019-05-21 16:33:00,552][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_0.predict)=99.38%
# [ 2019-05-21 16:33:00,702][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_1.predict)=99.13%
# [ 2019-05-21 16:33:00,855][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_2.predict)=99.26%
# [ 2019-05-21 16:33:01,014][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_3.predict)=99.33%
# [ 2019-05-21 16:33:01,164][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_4.predict)=99.49%
# [ 2019-05-21 16:33:01,171][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_cv.predict)=99.32%
# [ 2019-05-21 16:33:01,341][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_0.predict)=99.40%
# [ 2019-05-21 16:33:01,492][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_1.predict)=99.31%
# [ 2019-05-21 16:33:01,661][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_2.predict)=99.04%
# [ 2019-05-21 16:33:01,810][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_3.predict)=99.22%
# [ 2019-05-21 16:33:01,970][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_4.predict)=99.24%
# [ 2019-05-21 16:33:01,977][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_cv.predict)=99.24%
# [ 2019-05-21 16:33:02,154][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_0.predict)=99.33%
# [ 2019-05-21 16:33:02,298][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_1.predict)=99.20%
# [ 2019-05-21 16:33:02,458][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_2.predict)=99.49%
# [ 2019-05-21 16:33:02,634][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:33:02,781][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_4.predict)=99.33%
# [ 2019-05-21 16:33:02,788][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_cv.predict)=99.33%
# [ 2019-05-21 16:33:03,347][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_0.predict)=99.71%
# [ 2019-05-21 16:33:03,882][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_1.predict)=99.58%
# [ 2019-05-21 16:33:04,461][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_2.predict)=99.75%
# ...
# [ 2019-05-21 16:34:48,566][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_cv.predict)=98.65%
# [ 2019-05-21 16:34:48,782][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_0.predict)=98.91%
# [ 2019-05-21 16:34:49,000][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_1.predict)=98.62%
# [ 2019-05-21 16:34:49,220][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_2.predict)=98.71%
# [ 2019-05-21 16:34:49,432][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_3.predict)=98.68%
# [ 2019-05-21 16:34:49,655][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_4.predict)=98.66%
# [ 2019-05-21 16:34:49,662][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_cv.predict)=98.71%
# [ 2019-05-21 16:34:50,255][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_0.predict)=99.31%
# [ 2019-05-21 16:34:50,854][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_1.predict)=99.17%
# [ 2019-05-21 16:34:51,462][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_2.predict)=99.24%
# [ 2019-05-21 16:34:52,049][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_3.predict)=99.69%
# [ 2019-05-21 16:34:52,703][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_4.predict)=99.49%
# [ 2019-05-21 16:34:52,710][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_cv.predict)=99.38%
# [ 2019-05-21 16:34:52,718][cascade_classifier.calc_f1] Weighted F1 (layer_3 - train.classifier_average)=99.36%
# [ 2019-05-21 16:34:52,724][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(22410, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:34:52,947][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_0.predict)=99.44%
# [ 2019-05-21 16:34:53,143][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_1.predict)=99.33%
# [ 2019-05-21 16:34:53,339][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_2.predict)=99.31%
# [ 2019-05-21 16:34:53,539][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_3.predict)=99.38%
# [ 2019-05-21 16:34:53,736][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_4.predict)=99.20%
# [ 2019-05-21 16:34:53,743][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_cv.predict)=99.33%
# [ 2019-05-21 16:34:53,961][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_0.predict)=99.46%
# [ 2019-05-21 16:34:54,154][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_1.predict)=99.38%
# [ 2019-05-21 16:34:54,343][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_2.predict)=99.35%
# [ 2019-05-21 16:34:54,542][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-21 16:34:54,744][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_4.predict)=99.24%
# [ 2019-05-21 16:34:54,754][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-21 16:34:55,051][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_0.predict)=99.31%
# [ 2019-05-21 16:34:55,294][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_1.predict)=99.42%
# [ 2019-05-21 16:34:55,494][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_2.predict)=99.42%
# [ 2019-05-21 16:34:55,697][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:34:55,896][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_4.predict)=99.38%
# [ 2019-05-21 16:34:55,902][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:34:56,099][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_0.predict)=99.38%
# [ 2019-05-21 16:34:56,291][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_1.predict)=99.26%
# [ 2019-05-21 16:34:56,508][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_2.predict)=99.33%
# [ 2019-05-21 16:34:56,712][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_3.predict)=99.44%
# [ 2019-05-21 16:34:56,940][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_4.predict)=99.44%
# [ 2019-05-21 16:34:56,947][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:34:57,171][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_0.predict)=98.73%
# [ 2019-05-21 16:34:57,373][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_1.predict)=98.70%
# [ 2019-05-21 16:34:57,645][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_2.predict)=98.75%
# [ 2019-05-21 16:34:57,898][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_3.predict)=98.82%
# [ 2019-05-21 16:34:58,101][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_4.predict)=98.66%
# [ 2019-05-21 16:34:58,108][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_cv.predict)=98.73%
# [ 2019-05-21 16:34:58,371][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_0.predict)=98.93%
# [ 2019-05-21 16:34:58,566][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_1.predict)=98.59%
# [ 2019-05-21 16:34:58,795][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_2.predict)=98.62%
# [ 2019-05-21 16:34:59,017][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_3.predict)=98.62%
# [ 2019-05-21 16:34:59,249][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_4.predict)=98.89%
# [ 2019-05-21 16:34:59,256][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_cv.predict)=98.73%
# [ 2019-05-21 16:34:59,481][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_0.predict)=98.66%
# [ 2019-05-21 16:34:59,681][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_1.predict)=98.64%
# [ 2019-05-21 16:34:59,894][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_2.predict)=98.59%
# [ 2019-05-21 16:35:00,089][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_3.predict)=98.91%
# [ 2019-05-21 16:35:00,295][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_4.predict)=98.62%
# [ 2019-05-21 16:35:00,304][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_cv.predict)=98.68%
# [ 2019-05-21 16:35:00,962][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_0.predict)=99.60%
# [ 2019-05-21 16:35:01,568][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_1.predict)=99.44%
# [ 2019-05-21 16:35:02,216][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_2.predict)=99.49%
# [ 2019-05-21 16:35:02,877][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_3.predict)=99.22%
# [ 2019-05-21 16:35:03,503][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_4.predict)=99.11%
# [ 2019-05-21 16:35:03,511][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_cv.predict)=99.37%
# [ 2019-05-21 16:35:03,520][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=99.35%
# [ 2019-05-21 16:35:03,528][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(22410, 52), X_cur_test.shape=(0, 52)
# [ 2019-05-21 16:35:03,782][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=99.20%
# [ 2019-05-21 16:35:04,002][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=99.44%
# [ 2019-05-21 16:35:04,199][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=99.35%
# [ 2019-05-21 16:35:04,402][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=99.29%
# [ 2019-05-21 16:35:04,598][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=99.40%
# [ 2019-05-21 16:35:04,605][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=99.34%
# [ 2019-05-21 16:35:04,817][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=99.29%
# [ 2019-05-21 16:35:05,019][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-21 16:35:05,216][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=99.44%
# [ 2019-05-21 16:35:05,415][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=99.35%
# [ 2019-05-21 16:35:05,616][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=99.31%
# [ 2019-05-21 16:35:05,631][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=99.35%
# [ 2019-05-21 16:35:05,842][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_0.predict)=99.40%
# [ 2019-05-21 16:35:06,041][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_1.predict)=99.20%
# [ 2019-05-21 16:35:06,241][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_2.predict)=99.47%
# [ 2019-05-21 16:35:06,438][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_3.predict)=99.31%
# [ 2019-05-21 16:35:06,626][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_4.predict)=99.37%
# [ 2019-05-21 16:35:06,632][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_cv.predict)=99.35%
# [ 2019-05-21 16:35:06,848][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_0.predict)=99.22%
# [ 2019-05-21 16:35:07,071][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_1.predict)=99.35%
# [ 2019-05-21 16:35:07,288][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_2.predict)=99.51%
# [ 2019-05-21 16:35:07,511][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_3.predict)=99.38%
# [ 2019-05-21 16:35:07,733][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_4.predict)=99.35%
# [ 2019-05-21 16:35:07,739][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-21 16:35:07,943][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_0.predict)=98.66%
# [ 2019-05-21 16:35:08,146][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_1.predict)=98.75%
# [ 2019-05-21 16:35:08,339][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_2.predict)=98.55%
# [ 2019-05-21 16:35:08,564][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_3.predict)=98.55%
# [ 2019-05-21 16:35:08,796][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_4.predict)=98.86%
# [ 2019-05-21 16:35:08,803][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_cv.predict)=98.67%
# [ 2019-05-21 16:35:09,024][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_0.predict)=98.62%
# [ 2019-05-21 16:35:09,240][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_1.predict)=98.93%
# [ 2019-05-21 16:35:09,448][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_2.predict)=98.50%
# [ 2019-05-21 16:35:09,647][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_3.predict)=98.70%
# [ 2019-05-21 16:35:09,883][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_4.predict)=98.68%
# [ 2019-05-21 16:35:09,890][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_cv.predict)=98.69%
# [ 2019-05-21 16:35:10,176][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_0.predict)=98.73%
# [ 2019-05-21 16:35:10,425][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_1.predict)=98.55%
# [ 2019-05-21 16:35:10,644][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=98.48%
# [ 2019-05-21 16:35:10,875][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=98.75%
# [ 2019-05-21 16:35:11,114][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=98.44%
# [ 2019-05-21 16:35:11,121][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=98.59%
# [ 2019-05-21 16:35:11,791][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.31%
# [ 2019-05-21 16:35:12,464][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.29%
# [ 2019-05-21 16:35:13,069][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.46%
# [ 2019-05-21 16:35:13,707][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.49%
# [ 2019-05-21 16:35:14,305][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.26%
# [ 2019-05-21 16:35:14,312][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.36%
# [ 2019-05-21 16:35:14,320][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.36%
# [ 2019-05-21 16:35:14,321][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=3, weighted_f1_train=99.38%, weighted_f1_test=0.00%
# [ 2019-05-21 16:35:14,328][cascade_classifier.transform] X_groups_test.shape=[(11202, 4)]
# [ 2019-05-21 16:35:14,329][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-21 16:35:14,330][cascade_classifier.transform] X_test.shape=(11202, 4)
# [ 2019-05-21 16:35:14,332][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(11202, 4)
# [ 2019-05-21 16:35:14,578][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(11202, 52)
# [ 2019-05-21 16:35:14,857][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(11202, 52)
# [ 2019-05-21 16:35:15,157][cascade_classifier.transform] X_groups_test.shape=[(22410, 4)]
# [ 2019-05-21 16:35:15,158][cascade_classifier.transform] group_dims=[4]
# [ 2019-05-21 16:35:15,159][cascade_classifier.transform] X_test.shape=(22410, 4)
# [ 2019-05-21 16:35:15,161][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(22410, 4)
# [ 2019-05-21 16:35:15,641][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(22410, 52)
# [ 2019-05-21 16:35:16,190][cascade_classifier.transform] [layer=2] look_indexs=[0], X_cur_test.shape=(22410, 52)
