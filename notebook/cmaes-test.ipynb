# %%
import os
import numpy as np
import pandas as pd

from sklearn import preprocessing
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import train_test_split

from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append("..") 
from gcforest.gcforest import GCForest
import cmaes as cma
# Out:
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# # 数据以及参数

# %%
random_seed = 42

# %% [markdown]
# 其余基本模型的参数都是sklearn默认的
#
# 设置深度森林参数：最大层数20，连续5层没有效果（WF1）提升则停止，每一层：4个随机森林，3个决策树，1个逻辑回归

# %%
def get_toy_config():
    config = {}
    ca_config = {}
    ca_config["random_state"] = random_seed
    ca_config["max_layers"] = 20
    ca_config["early_stopping_rounds"] = 5
    ca_config["n_classes"] = 6
    ca_config["estimators"] = []
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "RandomForestClassifier", "random_state" : random_seed})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "DecisionTreeClassifier"})
    ca_config["estimators"].append({"n_folds": 5, "type": "LogisticRegression"})
    config["cascade"] = ca_config
    return config

# %%
path = os.getcwd()+'/../data/20122018freshwater_four_feature.csv'
data = pd.read_csv(path, na_values = np.nan)

# %%
# training/valid/test: 0.6/0.2/0.2, 各数据集划分的时候要注意
X = data.drop(['本周水质'], axis=1).values # Series
y = data['本周水质'].values-1
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, 
                                       stratify = y, random_state = random_seed)
# Z-score
clean_pipeline = Pipeline([('imputer', preprocessing.Imputer(missing_values='NaN',strategy="median")),
                           ('std_scaler', preprocessing.StandardScaler()),])
X_train = clean_pipeline.fit_transform(X_train)
X_test = clean_pipeline.fit_transform(X_test)
X_train2, X_valid, y_train2, y_valid = train_test_split(X_train, y_train, test_size=0.25, 
                                       stratify = y_train, random_state = random_seed)

# %% [markdown]
# # 训练

# %%
config = get_toy_config()

models = [
    LogisticRegression(),
    LinearDiscriminantAnalysis(),
    SVC(probability=True),
    DecisionTreeClassifier(),
    ExtraTreeClassifier(),
    GaussianNB(),
    KNeighborsClassifier(),
    RandomForestClassifier(random_state=random_seed),
    ExtraTreesClassifier(random_state=random_seed),
    GCForest(config)
]

y_pred_proba_all = []

for model in models:
    model_name = model.__class__.__name__
    if model_name == 'GCForest':
        model.fit_transform(X_train2, y_train2, X_test, y_test)
    else:
        model.fit(X_train2, y_train2)
    y_pred_proba = model.predict_proba(X_valid)
    # y_pred = model.predict(X_valid)
    # print("%s, validation set: weighted F1 score:%f, Accuracy:%f" %(model_name, f1_score(y_valid, y_pred, average="weighted"), accuracy_score(y_valid, y_pred)))
    y_pred_proba_all.append(y_pred_proba)
# Out:
# [ 2019-02-25 20:31:31,532][cascade_classifier.fit_transform] X_groups_train.shape=[(20166, 4)],y_train.shape=(20166,),X_groups_test.shape=[(6723, 4)],y_test.shape=(6723,)
# [ 2019-02-25 20:31:31,534][cascade_classifier.fit_transform] group_dims=[4]
# [ 2019-02-25 20:31:31,535][cascade_classifier.fit_transform] group_starts=[0]
# [ 2019-02-25 20:31:31,536][cascade_classifier.fit_transform] group_ends=[4]
# [ 2019-02-25 20:31:31,537][cascade_classifier.fit_transform] X_train.shape=(20166, 4),X_test.shape=(6723, 4)
# [ 2019-02-25 20:31:31,539][cascade_classifier.fit_transform] [layer=0] look_indexs=[0], X_cur_train.shape=(20166, 4), X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:31:31,668][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_0.predict)=99.28%
# [ 2019-02-25 20:31:31,800][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_1.predict)=99.43%
# [ 2019-02-25 20:31:31,930][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_2.predict)=99.48%
# [ 2019-02-25 20:31:32,066][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_3.predict)=99.43%
# [ 2019-02-25 20:31:32,206][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_4.predict)=99.28%
# [ 2019-02-25 20:31:32,219][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.train_cv.predict)=99.38%
# [ 2019-02-25 20:31:32,222][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_0 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:32,355][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_0.predict)=99.30%
# [ 2019-02-25 20:31:32,497][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_1.predict)=99.55%
# [ 2019-02-25 20:31:32,732][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_2.predict)=99.28%
# [ 2019-02-25 20:31:32,932][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_3.predict)=99.23%
# [ 2019-02-25 20:31:33,073][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_4.predict)=99.53%
# [ 2019-02-25 20:31:33,087][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.train_cv.predict)=99.38%
# [ 2019-02-25 20:31:33,089][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_1 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:33,264][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_0.predict)=99.33%
# [ 2019-02-25 20:31:33,422][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_1.predict)=99.38%
# [ 2019-02-25 20:31:33,562][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_2.predict)=99.21%
# [ 2019-02-25 20:31:33,743][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_3.predict)=99.38%
# [ 2019-02-25 20:31:33,888][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_4.predict)=99.43%
# [ 2019-02-25 20:31:33,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.train_cv.predict)=99.35%
# [ 2019-02-25 20:31:33,904][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_2 - 5_folds.test.predict)=97.62%
# [ 2019-02-25 20:31:34,148][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_0.predict)=99.38%
# [ 2019-02-25 20:31:34,293][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_1.predict)=99.53%
# [ 2019-02-25 20:31:34,452][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_2.predict)=99.33%
# [ 2019-02-25 20:31:34,675][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_3.predict)=99.38%
# [ 2019-02-25 20:31:34,853][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_4.predict)=99.11%
# [ 2019-02-25 20:31:34,868][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.train_cv.predict)=99.35%
# [ 2019-02-25 20:31:34,873][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_3 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:34,972][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_0.predict)=98.83%
# [ 2019-02-25 20:31:35,071][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_1.predict)=98.91%
# [ 2019-02-25 20:31:35,130][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_2.predict)=98.81%
# [ 2019-02-25 20:31:35,174][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_3.predict)=98.68%
# [ 2019-02-25 20:31:35,251][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_4.predict)=99.03%
# [ 2019-02-25 20:31:35,262][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.train_cv.predict)=98.85%
# [ 2019-02-25 20:31:35,266][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_4 - 5_folds.test.predict)=97.32%
# [ 2019-02-25 20:31:35,342][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_0.predict)=99.06%
# [ 2019-02-25 20:31:35,410][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_1.predict)=98.69%
# [ 2019-02-25 20:31:35,449][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_2.predict)=98.71%
# [ 2019-02-25 20:31:35,508][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_3.predict)=98.79%
# [ 2019-02-25 20:31:35,558][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_4.predict)=98.96%
# [ 2019-02-25 20:31:35,571][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.train_cv.predict)=98.84%
# [ 2019-02-25 20:31:35,574][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_5 - 5_folds.test.predict)=97.34%
# [ 2019-02-25 20:31:35,659][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_0.predict)=98.76%
# [ 2019-02-25 20:31:35,719][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_1.predict)=98.94%
# [ 2019-02-25 20:31:35,779][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_2.predict)=98.86%
# [ 2019-02-25 20:31:35,842][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_3.predict)=98.98%
# [ 2019-02-25 20:31:35,882][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_4.predict)=98.61%
# [ 2019-02-25 20:31:35,889][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.train_cv.predict)=98.83%
# [ 2019-02-25 20:31:35,891][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_6 - 5_folds.test.predict)=97.39%
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# [ 2019-02-25 20:31:36,008][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_0.predict)=61.33%
# [ 2019-02-25 20:31:36,091][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_1.predict)=61.04%
# [ 2019-02-25 20:31:36,172][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_2.predict)=61.26%
# [ 2019-02-25 20:31:36,249][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_3.predict)=61.02%
# [ 2019-02-25 20:31:36,333][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_4.predict)=61.18%
# [ 2019-02-25 20:31:36,339][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.train_cv.predict)=61.17%
# [ 2019-02-25 20:31:36,342][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_0 - estimator_7 - 5_folds.test.predict)=61.80%
# [ 2019-02-25 20:31:36,347][cascade_classifier.calc_f1] Weighted F1 (layer_0 - train.classifier_average)=99.44%
# [ 2019-02-25 20:31:36,350][cascade_classifier.calc_f1] Weighted F1 (layer_0 - test.classifier_average)=97.60%
# [ 2019-02-25 20:31:36,360][cascade_classifier.fit_transform] [layer=1] look_indexs=[0], X_cur_train.shape=(20166, 52), X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:31:36,625][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_0.predict)=99.40%
# [ 2019-02-25 20:31:36,814][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_1.predict)=99.48%
# [ 2019-02-25 20:31:36,995][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_2.predict)=99.53%
# [ 2019-02-25 20:31:37,190][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_3.predict)=99.58%
# [ 2019-02-25 20:31:37,380][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_4.predict)=99.33%
# [ 2019-02-25 20:31:37,393][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:31:37,396][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_0 - 5_folds.test.predict)=97.66%
# [ 2019-02-25 20:31:37,607][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_0.predict)=99.58%
# [ 2019-02-25 20:31:37,805][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_1.predict)=99.41%
# [ 2019-02-25 20:31:38,009][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_2.predict)=99.65%
# [ 2019-02-25 20:31:38,206][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_3.predict)=99.38%
# [ 2019-02-25 20:31:38,388][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_4.predict)=99.25%
# [ 2019-02-25 20:31:38,401][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.train_cv.predict)=99.45%
# [ 2019-02-25 20:31:38,404][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_1 - 5_folds.test.predict)=97.66%
# [ 2019-02-25 20:31:38,604][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_0.predict)=99.38%
# [ 2019-02-25 20:31:38,809][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_1.predict)=99.53%
# [ 2019-02-25 20:31:39,004][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_2.predict)=99.36%
# [ 2019-02-25 20:31:39,205][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_3.predict)=99.50%
# [ 2019-02-25 20:31:39,403][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_4.predict)=99.55%
# [ 2019-02-25 20:31:39,416][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:31:39,418][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_2 - 5_folds.test.predict)=97.66%
# [ 2019-02-25 20:31:39,616][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_0.predict)=99.60%
# [ 2019-02-25 20:31:39,797][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_1.predict)=99.28%
# [ 2019-02-25 20:31:39,987][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_2.predict)=99.55%
# [ 2019-02-25 20:31:40,178][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_3.predict)=99.38%
# [ 2019-02-25 20:31:40,381][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_4.predict)=99.38%
# [ 2019-02-25 20:31:40,397][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.train_cv.predict)=99.44%
# [ 2019-02-25 20:31:40,402][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_3 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:40,641][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_0.predict)=98.81%
# [ 2019-02-25 20:31:40,896][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_1.predict)=98.79%
# [ 2019-02-25 20:31:41,117][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_2.predict)=98.96%
# [ 2019-02-25 20:31:41,419][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_3.predict)=98.76%
# [ 2019-02-25 20:31:41,656][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_4.predict)=98.98%
# [ 2019-02-25 20:31:41,666][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.train_cv.predict)=98.86%
# [ 2019-02-25 20:31:41,669][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_4 - 5_folds.test.predict)=97.44%
# [ 2019-02-25 20:31:42,061][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_0.predict)=98.89%
# [ 2019-02-25 20:31:42,548][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_1.predict)=98.69%
# [ 2019-02-25 20:31:42,931][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_2.predict)=98.93%
# [ 2019-02-25 20:31:43,172][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_3.predict)=98.83%
# [ 2019-02-25 20:31:43,407][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_4.predict)=98.79%
# [ 2019-02-25 20:31:43,414][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.train_cv.predict)=98.82%
# [ 2019-02-25 20:31:43,417][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_5 - 5_folds.test.predict)=97.46%
# [ 2019-02-25 20:31:43,648][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_0.predict)=98.98%
# [ 2019-02-25 20:31:43,844][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_1.predict)=98.79%
# [ 2019-02-25 20:31:44,042][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_2.predict)=98.69%
# [ 2019-02-25 20:31:44,255][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_3.predict)=98.68%
# [ 2019-02-25 20:31:44,468][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_4.predict)=99.06%
# [ 2019-02-25 20:31:44,474][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.train_cv.predict)=98.84%
# [ 2019-02-25 20:31:44,481][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_6 - 5_folds.test.predict)=97.49%
# [ 2019-02-25 20:31:45,036][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_0.predict)=99.23%
# [ 2019-02-25 20:31:45,534][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_1.predict)=99.58%
# [ 2019-02-25 20:31:46,056][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_2.predict)=99.40%
# [ 2019-02-25 20:31:46,547][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_3.predict)=99.43%
# [ 2019-02-25 20:31:47,028][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_4.predict)=99.65%
# [ 2019-02-25 20:31:47,035][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:31:47,037][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_1 - estimator_7 - 5_folds.test.predict)=97.66%
# [ 2019-02-25 20:31:47,044][cascade_classifier.calc_f1] Weighted F1 (layer_1 - train.classifier_average)=99.48%
# [ 2019-02-25 20:31:47,046][cascade_classifier.calc_f1] Weighted F1 (layer_1 - test.classifier_average)=97.63%
# [ 2019-02-25 20:31:47,051][cascade_classifier.fit_transform] [layer=2] look_indexs=[0], X_cur_train.shape=(20166, 52), X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:31:47,229][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_0.predict)=99.60%
# [ 2019-02-25 20:31:47,402][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_1.predict)=99.36%
# [ 2019-02-25 20:31:47,585][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_2.predict)=99.53%
# [ 2019-02-25 20:31:47,760][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_3.predict)=99.43%
# [ 2019-02-25 20:31:47,936][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_4.predict)=99.38%
# [ 2019-02-25 20:31:47,949][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:31:47,951][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_0 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:48,117][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_0.predict)=99.40%
# [ 2019-02-25 20:31:48,327][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_1.predict)=99.53%
# [ 2019-02-25 20:31:48,523][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_2.predict)=99.36%
# [ 2019-02-25 20:31:48,697][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_3.predict)=99.48%
# [ 2019-02-25 20:31:48,908][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_4.predict)=99.43%
# [ 2019-02-25 20:31:48,923][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.train_cv.predict)=99.44%
# [ 2019-02-25 20:31:48,926][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_1 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:49,105][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_0.predict)=99.41%
# [ 2019-02-25 20:31:49,288][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_1.predict)=99.53%
# [ 2019-02-25 20:31:49,478][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_2.predict)=99.38%
# [ 2019-02-25 20:31:49,651][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_3.predict)=99.33%
# [ 2019-02-25 20:31:49,844][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_4.predict)=99.68%
# [ 2019-02-25 20:31:49,857][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:31:49,860][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_2 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:50,134][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_0.predict)=99.58%
# [ 2019-02-25 20:31:50,309][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_1.predict)=99.38%
# [ 2019-02-25 20:31:50,474][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_2.predict)=99.41%
# [ 2019-02-25 20:31:50,649][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_3.predict)=99.55%
# [ 2019-02-25 20:31:50,820][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_4.predict)=99.43%
# [ 2019-02-25 20:31:50,833][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.train_cv.predict)=99.47%
# [ 2019-02-25 20:31:50,836][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_3 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:51,017][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_0.predict)=99.03%
# [ 2019-02-25 20:31:51,183][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_1.predict)=98.84%
# [ 2019-02-25 20:31:51,349][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_2.predict)=98.76%
# [ 2019-02-25 20:31:51,527][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_3.predict)=98.83%
# [ 2019-02-25 20:31:51,695][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_4.predict)=98.63%
# [ 2019-02-25 20:31:51,701][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.train_cv.predict)=98.82%
# [ 2019-02-25 20:31:51,704][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_4 - 5_folds.test.predict)=97.57%
# [ 2019-02-25 20:31:51,896][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_0.predict)=98.91%
# [ 2019-02-25 20:31:52,055][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_1.predict)=98.64%
# [ 2019-02-25 20:31:52,234][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_2.predict)=98.91%
# [ 2019-02-25 20:31:52,410][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_3.predict)=98.78%
# [ 2019-02-25 20:31:52,601][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_4.predict)=98.81%
# [ 2019-02-25 20:31:52,608][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.train_cv.predict)=98.81%
# [ 2019-02-25 20:31:52,611][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_5 - 5_folds.test.predict)=97.62%
# [ 2019-02-25 20:31:52,800][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_0.predict)=98.81%
# [ 2019-02-25 20:31:52,993][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_1.predict)=98.67%
# [ 2019-02-25 20:31:53,160][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_2.predict)=98.88%
# [ 2019-02-25 20:31:53,358][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_3.predict)=98.76%
# [ 2019-02-25 20:31:53,536][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_4.predict)=98.98%
# [ 2019-02-25 20:31:53,543][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.train_cv.predict)=98.82%
# [ 2019-02-25 20:31:53,547][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_6 - 5_folds.test.predict)=97.62%
# [ 2019-02-25 20:31:54,050][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_0.predict)=99.53%
# [ 2019-02-25 20:31:54,519][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_1.predict)=99.45%
# [ 2019-02-25 20:31:54,972][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_2.predict)=99.53%
# [ 2019-02-25 20:31:55,428][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_3.predict)=99.50%
# [ 2019-02-25 20:31:55,894][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_4.predict)=99.33%
# [ 2019-02-25 20:31:55,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.train_cv.predict)=99.47%
# [ 2019-02-25 20:31:55,904][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_2 - estimator_7 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:55,910][cascade_classifier.calc_f1] Weighted F1 (layer_2 - train.classifier_average)=99.46%
# [ 2019-02-25 20:31:55,914][cascade_classifier.calc_f1] Weighted F1 (layer_2 - test.classifier_average)=97.65%
# [ 2019-02-25 20:31:55,923][cascade_classifier.fit_transform] [layer=3] look_indexs=[0], X_cur_train.shape=(20166, 52), X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:31:56,109][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_0.predict)=99.41%
# [ 2019-02-25 20:31:56,281][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_1.predict)=99.41%
# [ 2019-02-25 20:31:56,457][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_2.predict)=99.43%
# [ 2019-02-25 20:31:56,640][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_3.predict)=99.58%
# [ 2019-02-25 20:31:56,819][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_4.predict)=99.50%
# [ 2019-02-25 20:31:56,832][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:31:56,834][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_0 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:57,009][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_0.predict)=99.41%
# [ 2019-02-25 20:31:57,188][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_1.predict)=99.55%
# [ 2019-02-25 20:31:57,362][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_2.predict)=99.55%
# [ 2019-02-25 20:31:57,533][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_3.predict)=99.38%
# [ 2019-02-25 20:31:57,736][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_4.predict)=99.43%
# [ 2019-02-25 20:31:57,750][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:31:57,753][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_1 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:57,962][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_0.predict)=99.58%
# [ 2019-02-25 20:31:58,149][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_1.predict)=99.53%
# [ 2019-02-25 20:31:58,367][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_2.predict)=99.43%
# [ 2019-02-25 20:31:58,543][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_3.predict)=99.26%
# [ 2019-02-25 20:31:58,740][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_4.predict)=99.63%
# [ 2019-02-25 20:31:58,754][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.train_cv.predict)=99.48%
# [ 2019-02-25 20:31:58,756][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_2 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:58,970][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_0.predict)=99.35%
# [ 2019-02-25 20:31:59,138][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_1.predict)=99.28%
# [ 2019-02-25 20:31:59,378][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_2.predict)=99.63%
# [ 2019-02-25 20:31:59,595][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_3.predict)=99.50%
# [ 2019-02-25 20:31:59,779][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_4.predict)=99.58%
# [ 2019-02-25 20:31:59,792][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.train_cv.predict)=99.47%
# [ 2019-02-25 20:31:59,796][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_3 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:31:59,988][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_0.predict)=98.71%
# [ 2019-02-25 20:32:00,175][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_1.predict)=98.84%
# [ 2019-02-25 20:32:00,344][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_2.predict)=99.06%
# [ 2019-02-25 20:32:00,535][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_3.predict)=98.76%
# [ 2019-02-25 20:32:00,731][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_4.predict)=98.78%
# [ 2019-02-25 20:32:00,740][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.train_cv.predict)=98.83%
# [ 2019-02-25 20:32:00,743][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_4 - 5_folds.test.predict)=97.56%
# [ 2019-02-25 20:32:00,924][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_0.predict)=98.64%
# [ 2019-02-25 20:32:01,119][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_1.predict)=99.06%
# [ 2019-02-25 20:32:01,292][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_2.predict)=98.69%
# [ 2019-02-25 20:32:01,468][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_3.predict)=98.71%
# [ 2019-02-25 20:32:01,644][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_4.predict)=98.88%
# [ 2019-02-25 20:32:01,651][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.train_cv.predict)=98.79%
# [ 2019-02-25 20:32:01,654][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_5 - 5_folds.test.predict)=97.54%
# [ 2019-02-25 20:32:01,841][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_0.predict)=98.81%
# [ 2019-02-25 20:32:02,013][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_1.predict)=98.63%
# [ 2019-02-25 20:32:02,198][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_2.predict)=98.81%
# [ 2019-02-25 20:32:02,396][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_3.predict)=98.91%
# [ 2019-02-25 20:32:02,575][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_4.predict)=98.98%
# [ 2019-02-25 20:32:02,582][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.train_cv.predict)=98.83%
# [ 2019-02-25 20:32:02,585][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_6 - 5_folds.test.predict)=97.57%
# [ 2019-02-25 20:32:03,075][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_0.predict)=99.28%
# [ 2019-02-25 20:32:03,493][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_1.predict)=99.63%
# [ 2019-02-25 20:32:04,008][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_2.predict)=99.63%
# [ 2019-02-25 20:32:04,486][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_3.predict)=99.38%
# [ 2019-02-25 20:32:04,990][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_4.predict)=99.43%
# [ 2019-02-25 20:32:04,997][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.train_cv.predict)=99.47%
# [ 2019-02-25 20:32:05,000][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_3 - estimator_7 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:05,006][cascade_classifier.calc_f1] Weighted F1 (layer_3 - train.classifier_average)=99.46%
# [ 2019-02-25 20:32:05,010][cascade_classifier.calc_f1] Weighted F1 (layer_3 - test.classifier_average)=97.63%
# [ 2019-02-25 20:32:05,018][cascade_classifier.fit_transform] [layer=4] look_indexs=[0], X_cur_train.shape=(20166, 52), X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:32:05,211][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_0.predict)=99.68%
# [ 2019-02-25 20:32:05,392][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_1.predict)=99.43%
# [ 2019-02-25 20:32:05,580][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_2.predict)=99.26%
# [ 2019-02-25 20:32:05,757][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_3.predict)=99.43%
# [ 2019-02-25 20:32:05,955][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_4.predict)=99.48%
# [ 2019-02-25 20:32:05,971][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.train_cv.predict)=99.45%
# [ 2019-02-25 20:32:05,976][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_0 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:06,149][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_0.predict)=99.45%
# [ 2019-02-25 20:32:06,322][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_1.predict)=99.46%
# [ 2019-02-25 20:32:06,488][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_2.predict)=99.31%
# [ 2019-02-25 20:32:06,670][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_3.predict)=99.65%
# [ 2019-02-25 20:32:06,859][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_4.predict)=99.45%
# [ 2019-02-25 20:32:06,875][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:06,879][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_1 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:07,092][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_0.predict)=99.50%
# [ 2019-02-25 20:32:07,282][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_1.predict)=99.36%
# [ 2019-02-25 20:32:07,466][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_2.predict)=99.45%
# [ 2019-02-25 20:32:07,629][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_3.predict)=99.20%
# [ 2019-02-25 20:32:07,815][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_4.predict)=99.78%
# [ 2019-02-25 20:32:07,827][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:07,831][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_2 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:08,016][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_0.predict)=99.50%
# [ 2019-02-25 20:32:08,190][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_1.predict)=99.43%
# [ 2019-02-25 20:32:08,376][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_2.predict)=99.45%
# [ 2019-02-25 20:32:08,551][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_3.predict)=99.50%
# [ 2019-02-25 20:32:08,738][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_4.predict)=99.45%
# [ 2019-02-25 20:32:08,751][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.train_cv.predict)=99.47%
# [ 2019-02-25 20:32:08,754][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_3 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:08,919][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_0.predict)=98.89%
# [ 2019-02-25 20:32:09,082][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_1.predict)=98.59%
# [ 2019-02-25 20:32:09,248][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_2.predict)=98.96%
# [ 2019-02-25 20:32:09,432][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_3.predict)=98.98%
# [ 2019-02-25 20:32:09,597][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_4.predict)=98.78%
# [ 2019-02-25 20:32:09,603][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.train_cv.predict)=98.84%
# [ 2019-02-25 20:32:09,606][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_4 - 5_folds.test.predict)=97.50%
# [ 2019-02-25 20:32:09,765][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_0.predict)=98.71%
# [ 2019-02-25 20:32:09,947][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_1.predict)=98.64%
# [ 2019-02-25 20:32:10,137][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_2.predict)=99.11%
# [ 2019-02-25 20:32:10,309][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_3.predict)=98.98%
# [ 2019-02-25 20:32:10,484][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_4.predict)=98.91%
# [ 2019-02-25 20:32:10,491][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.train_cv.predict)=98.87%
# [ 2019-02-25 20:32:10,494][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_5 - 5_folds.test.predict)=97.44%
# [ 2019-02-25 20:32:10,654][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_0.predict)=98.69%
# [ 2019-02-25 20:32:10,841][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_1.predict)=98.91%
# [ 2019-02-25 20:32:11,019][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_2.predict)=98.76%
# [ 2019-02-25 20:32:11,187][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_3.predict)=98.96%
# [ 2019-02-25 20:32:11,340][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_4.predict)=98.93%
# [ 2019-02-25 20:32:11,347][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.train_cv.predict)=98.85%
# [ 2019-02-25 20:32:11,349][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_6 - 5_folds.test.predict)=97.50%
# [ 2019-02-25 20:32:11,828][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_0.predict)=99.55%
# [ 2019-02-25 20:32:12,283][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_1.predict)=99.53%
# [ 2019-02-25 20:32:12,711][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_2.predict)=99.43%
# [ 2019-02-25 20:32:13,175][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_3.predict)=99.50%
# [ 2019-02-25 20:32:13,608][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_4.predict)=99.33%
# [ 2019-02-25 20:32:13,615][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.train_cv.predict)=99.47%
# [ 2019-02-25 20:32:13,617][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_4 - estimator_7 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:13,623][cascade_classifier.calc_f1] Weighted F1 (layer_4 - train.classifier_average)=99.45%
# [ 2019-02-25 20:32:13,626][cascade_classifier.calc_f1] Weighted F1 (layer_4 - test.classifier_average)=97.65%
# [ 2019-02-25 20:32:13,630][cascade_classifier.fit_transform] [layer=5] look_indexs=[0], X_cur_train.shape=(20166, 52), X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:32:13,808][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_0.predict)=99.48%
# [ 2019-02-25 20:32:13,983][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_1.predict)=99.65%
# [ 2019-02-25 20:32:14,148][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_2.predict)=99.48%
# [ 2019-02-25 20:32:14,312][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_3.predict)=99.35%
# [ 2019-02-25 20:32:14,476][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_4.predict)=99.40%
# [ 2019-02-25 20:32:14,488][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.train_cv.predict)=99.47%
# [ 2019-02-25 20:32:14,491][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_0 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:14,670][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_0.predict)=99.65%
# [ 2019-02-25 20:32:14,839][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_1.predict)=99.58%
# [ 2019-02-25 20:32:15,013][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_2.predict)=99.35%
# [ 2019-02-25 20:32:15,195][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_3.predict)=99.53%
# [ 2019-02-25 20:32:15,370][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_4.predict)=99.21%
# [ 2019-02-25 20:32:15,382][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:15,385][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_1 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:15,554][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_0.predict)=99.53%
# [ 2019-02-25 20:32:15,734][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_1.predict)=99.48%
# [ 2019-02-25 20:32:15,898][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_2.predict)=99.35%
# [ 2019-02-25 20:32:16,068][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_3.predict)=99.43%
# [ 2019-02-25 20:32:16,243][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_4.predict)=99.53%
# [ 2019-02-25 20:32:16,255][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:16,258][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_2 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:16,440][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_0.predict)=99.41%
# [ 2019-02-25 20:32:16,610][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_1.predict)=99.38%
# [ 2019-02-25 20:32:16,774][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_2.predict)=99.53%
# [ 2019-02-25 20:32:16,935][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_3.predict)=99.53%
# [ 2019-02-25 20:32:17,100][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_4.predict)=99.45%
# [ 2019-02-25 20:32:17,113][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:17,116][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_3 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:17,282][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_0.predict)=98.84%
# [ 2019-02-25 20:32:17,449][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_1.predict)=99.11%
# [ 2019-02-25 20:32:17,602][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_2.predict)=98.91%
# [ 2019-02-25 20:32:17,762][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_3.predict)=98.71%
# [ 2019-02-25 20:32:17,916][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_4.predict)=98.83%
# [ 2019-02-25 20:32:17,922][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.train_cv.predict)=98.88%
# [ 2019-02-25 20:32:17,925][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_4 - 5_folds.test.predict)=97.53%
# [ 2019-02-25 20:32:18,099][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_0.predict)=99.08%
# [ 2019-02-25 20:32:18,251][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_1.predict)=98.81%
# [ 2019-02-25 20:32:18,415][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_2.predict)=98.56%
# [ 2019-02-25 20:32:18,574][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_3.predict)=98.88%
# [ 2019-02-25 20:32:18,730][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_4.predict)=98.93%
# [ 2019-02-25 20:32:18,736][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.train_cv.predict)=98.85%
# [ 2019-02-25 20:32:18,739][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_5 - 5_folds.test.predict)=97.63%
# [ 2019-02-25 20:32:18,904][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_0.predict)=98.71%
# [ 2019-02-25 20:32:19,073][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_1.predict)=98.93%
# [ 2019-02-25 20:32:19,218][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_2.predict)=98.81%
# [ 2019-02-25 20:32:19,387][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_3.predict)=98.83%
# [ 2019-02-25 20:32:19,553][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_4.predict)=98.74%
# [ 2019-02-25 20:32:19,559][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.train_cv.predict)=98.81%
# [ 2019-02-25 20:32:19,562][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_6 - 5_folds.test.predict)=97.63%
# [ 2019-02-25 20:32:20,034][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_0.predict)=99.45%
# [ 2019-02-25 20:32:20,458][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_1.predict)=99.38%
# [ 2019-02-25 20:32:20,898][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_2.predict)=99.58%
# [ 2019-02-25 20:32:21,464][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_3.predict)=99.58%
# [ 2019-02-25 20:32:21,939][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_4.predict)=99.33%
# [ 2019-02-25 20:32:21,947][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:21,949][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_5 - estimator_7 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:21,955][cascade_classifier.calc_f1] Weighted F1 (layer_5 - train.classifier_average)=99.47%
# [ 2019-02-25 20:32:21,958][cascade_classifier.calc_f1] Weighted F1 (layer_5 - test.classifier_average)=97.65%
# [ 2019-02-25 20:32:21,963][cascade_classifier.fit_transform] [layer=6] look_indexs=[0], X_cur_train.shape=(20166, 52), X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:32:22,153][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_0.predict)=99.50%
# [ 2019-02-25 20:32:22,325][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_1.predict)=99.53%
# [ 2019-02-25 20:32:22,511][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_2.predict)=99.23%
# [ 2019-02-25 20:32:22,692][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_3.predict)=99.43%
# [ 2019-02-25 20:32:22,871][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_4.predict)=99.55%
# [ 2019-02-25 20:32:22,891][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.train_cv.predict)=99.45%
# [ 2019-02-25 20:32:22,894][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_0 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:23,080][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_0.predict)=99.36%
# [ 2019-02-25 20:32:23,264][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_1.predict)=99.36%
# [ 2019-02-25 20:32:23,444][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_2.predict)=99.65%
# [ 2019-02-25 20:32:23,629][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_3.predict)=99.48%
# [ 2019-02-25 20:32:23,805][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_4.predict)=99.45%
# [ 2019-02-25 20:32:23,817][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:23,820][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_1 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:24,007][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_0.predict)=99.48%
# [ 2019-02-25 20:32:24,189][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_1.predict)=99.50%
# [ 2019-02-25 20:32:24,361][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_2.predict)=99.31%
# [ 2019-02-25 20:32:24,543][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_3.predict)=99.53%
# [ 2019-02-25 20:32:24,725][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_4.predict)=99.53%
# [ 2019-02-25 20:32:24,739][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.train_cv.predict)=99.47%
# [ 2019-02-25 20:32:24,742][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_2 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:24,915][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_0.predict)=99.60%
# [ 2019-02-25 20:32:25,080][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_1.predict)=99.28%
# [ 2019-02-25 20:32:25,259][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_2.predict)=99.36%
# [ 2019-02-25 20:32:25,439][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_3.predict)=99.58%
# [ 2019-02-25 20:32:25,614][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_4.predict)=99.48%
# [ 2019-02-25 20:32:25,627][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:25,630][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_3 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:25,816][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_0.predict)=98.71%
# [ 2019-02-25 20:32:25,987][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_1.predict)=99.03%
# [ 2019-02-25 20:32:26,150][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_2.predict)=98.79%
# [ 2019-02-25 20:32:26,324][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_3.predict)=98.96%
# [ 2019-02-25 20:32:26,488][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_4.predict)=98.78%
# [ 2019-02-25 20:32:26,495][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.train_cv.predict)=98.85%
# [ 2019-02-25 20:32:26,498][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_4 - 5_folds.test.predict)=97.54%
# [ 2019-02-25 20:32:26,668][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_0.predict)=98.61%
# [ 2019-02-25 20:32:26,845][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_1.predict)=98.91%
# [ 2019-02-25 20:32:27,016][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_2.predict)=98.93%
# [ 2019-02-25 20:32:27,199][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_3.predict)=98.93%
# [ 2019-02-25 20:32:27,391][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_4.predict)=98.81%
# [ 2019-02-25 20:32:27,398][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.train_cv.predict)=98.84%
# [ 2019-02-25 20:32:27,401][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_5 - 5_folds.test.predict)=97.59%
# [ 2019-02-25 20:32:27,589][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_0.predict)=98.91%
# [ 2019-02-25 20:32:27,786][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_1.predict)=98.37%
# [ 2019-02-25 20:32:27,965][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_2.predict)=98.66%
# [ 2019-02-25 20:32:28,123][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_3.predict)=98.32%
# [ 2019-02-25 20:32:28,306][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_4.predict)=98.51%
# [ 2019-02-25 20:32:28,313][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.train_cv.predict)=98.55%
# [ 2019-02-25 20:32:28,316][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_6 - 5_folds.test.predict)=97.56%
# [ 2019-02-25 20:32:28,873][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_0.predict)=99.48%
# [ 2019-02-25 20:32:29,347][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_1.predict)=99.45%
# [ 2019-02-25 20:32:29,803][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_2.predict)=99.28%
# [ 2019-02-25 20:32:30,352][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_3.predict)=99.53%
# [ 2019-02-25 20:32:30,890][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_4.predict)=99.58%
# [ 2019-02-25 20:32:30,897][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.train_cv.predict)=99.46%
# [ 2019-02-25 20:32:30,901][kfold_wrapper.log_eval_metrics] Weighted F1 (layer_6 - estimator_7 - 5_folds.test.predict)=97.65%
# [ 2019-02-25 20:32:30,907][cascade_classifier.calc_f1] Weighted F1 (layer_6 - train.classifier_average)=99.46%
# [ 2019-02-25 20:32:30,910][cascade_classifier.calc_f1] Weighted F1 (layer_6 - test.classifier_average)=97.65%
# [ 2019-02-25 20:32:30,911][cascade_classifier.fit_transform] [Result][Optimal Level Detected] opt_layer_num=2, weighted_f1_train=99.48%, weighted_f1_test=97.63%
# [ 2019-02-25 20:32:30,925][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:32:30,927][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:32:30,929][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:32:30,930][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:32:31,093][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)

# %% [markdown]
# 深度森林训练结果：4层不再有效果提升
#
# opt_layer_num=4, weighted_f1_train=99.45%, weighted_f1_test=97.66%
#
# 60%训练集，20%的测试集仅用做展示

# %% [markdown]
# # 验证

# %%
y_pred_proba_all = np.asarray(y_pred_proba_all)
# np.save("../npy/y_pred_proba_all.npy", y_pred_proba_all)

# %%
# 直接载入各个模型在验证集的概率向量，仅在懒得pre train的时候使用
# y_pred_proba_all = np.load("../npy/y_pred_proba_all.npy")

# %%
es = cma.CMAEvolutionStrategy(10 * [0], 0.5)
# Out:
# (5_w,10)-aCMA-ES (mu_w=3.2,w_1=45%) in dimension 10 (seed=149041, Mon Feb 25 20:32:31 2019)

# %%
# help(cma)
# help(es)

# %%
# score = "f1_weighted"
score = "accuracy"
while not es.stop():
    solutions = es.ask()
    es.tell(solutions, [cma.ff.water_ensemble(x, y_pred_proba_all, y_valid, metric=score) for x in solutions])
    es.logger.add()  # write data to disc to be plotted
    es.disp()
# Out:
# Iterat #Fevals   function value  axis ratio  sigma  min&max std  t[m:s]
#     1     10 -9.921166146065744e-01 1.0e+00 4.48e-01  4e-01  5e-01 0:00.0
#     2     20 -9.933065595716198e-01 1.2e+00 4.32e-01  4e-01  4e-01 0:00.1
#     3     30 -9.937527889335118e-01 1.2e+00 4.54e-01  4e-01  5e-01 0:00.1
# WARNING (iteration=10):  flat fitness (f=-0.994348, sigma=7.39e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=10):  flat fitness (f=-0.994348, sigma=7.39e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=11):  flat fitness (f=-0.994348, sigma=7.01e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=11):  flat fitness (f=-0.994348, sigma=7.01e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=12):  flat fitness (f=-0.994348, sigma=6.77e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=12):  flat fitness (f=-0.994348, sigma=6.77e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=13):  flat fitness (f=-0.994348, sigma=6.46e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=13):  flat fitness (f=-0.994348, sigma=6.46e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=14):  flat fitness (f=-0.994348, sigma=6.02e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=14):  flat fitness (f=-0.994348, sigma=6.02e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=15):  flat fitness (f=-0.994348, sigma=5.87e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=15):  flat fitness (f=-0.994348, sigma=5.87e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=16):  flat fitness (f=-0.994348, sigma=5.91e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=16):  flat fitness (f=-0.994348, sigma=5.91e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=17):  flat fitness (f=-0.994348, sigma=5.89e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=17):  flat fitness (f=-0.994348, sigma=5.89e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=18):  flat fitness (f=-0.994348, sigma=6.02e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=18):  flat fitness (f=-0.994348, sigma=6.02e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=19):  flat fitness (f=-0.994348, sigma=5.60e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=19):  flat fitness (f=-0.994348, sigma=5.60e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=20):  flat fitness (f=-0.994348, sigma=5.78e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=20):  flat fitness (f=-0.994348, sigma=5.78e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=21):  flat fitness (f=-0.994348, sigma=5.80e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=21):  flat fitness (f=-0.994348, sigma=5.80e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=22):  flat fitness (f=-0.994348, sigma=5.99e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=22):  flat fitness (f=-0.994348, sigma=5.99e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=23):  flat fitness (f=-0.994348, sigma=5.86e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=23):  flat fitness (f=-0.994348, sigma=5.86e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=24):  flat fitness (f=-0.994348, sigma=6.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=24):  flat fitness (f=-0.994348, sigma=6.28e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=25):  flat fitness (f=-0.994348, sigma=6.72e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=25):  flat fitness (f=-0.994348, sigma=6.72e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=26):  flat fitness (f=-0.994348, sigma=7.55e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=26):  flat fitness (f=-0.994348, sigma=7.55e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=33):  flat fitness (f=-0.994348, sigma=9.00e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=33):  flat fitness (f=-0.994348, sigma=9.00e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=38):  flat fitness (f=-0.994348, sigma=1.01e+00).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=38):  flat fitness (f=-0.994348, sigma=1.01e+00).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=39):  flat fitness (f=-0.994348, sigma=9.52e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=39):  flat fitness (f=-0.994348, sigma=9.52e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=40):  flat fitness (f=-0.994348, sigma=8.77e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=40):  flat fitness (f=-0.994348, sigma=8.77e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=41):  flat fitness (f=-0.994348, sigma=8.47e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=41):  flat fitness (f=-0.994348, sigma=8.47e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=42):  flat fitness (f=-0.994348, sigma=7.94e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=42):  flat fitness (f=-0.994348, sigma=7.94e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=43):  flat fitness (f=-0.994348, sigma=7.11e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=43):  flat fitness (f=-0.994348, sigma=7.11e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=44):  flat fitness (f=-0.994348, sigma=6.60e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=44):  flat fitness (f=-0.994348, sigma=6.60e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=45):  flat fitness (f=-0.994348, sigma=6.02e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=45):  flat fitness (f=-0.994348, sigma=6.02e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# WARNING (iteration=46):  flat fitness (f=-0.994348, sigma=5.47e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
#    46    460 -9.943477614160345e-01 3.1e+00 5.47e-01  4e-01  6e-01 0:01.7
# WARNING (iteration=46):  flat fitness (f=-0.994348, sigma=5.47e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.

# %%
es.result_pretty()  # pretty print result
cma.plot()
# Out:
# WARNING (iteration=46):  flat fitness (f=-0.994348, sigma=5.47e-01).
#                     For small sigma, this could indicate numerical convergence.
#                     Otherwise, please (re)consider how to compute the fitness more elaborately.
# termination on tolfun=1e-11
# termination on tolfunhist=1e-12
# termination on flat fitness=please (re)consider how to compute the fitness more elaborately if sigma=5.47e-01 is large
# final/bestever f-value = -9.943478e-01 -9.943478e-01
# incumbent solution: [ 0.22842961  0.12925116 -0.24130466  2.25937237  0.18667401  0.12343035
#  -1.59306814  0.08957381 ...]
# std deviations: [0.38362726 0.51429093 0.54625353 0.58062604 0.51069583 0.47945131
#  0.55132484 0.52154448 ...]

# %% [markdown]
# ## 得到10个基模型的权重

# %%
weights = np.exp(es.result.xbest)/np.sum(np.exp(es.result.xbest))
# weights = np.load("../npy/cmaes_weights.npy")  # 载入保存的权重，直接载入仅在懒得训练CMAES时使用或者想得到固定的结果

# weights of each base models
print("CMAES weights", weights)
# np.save("../npy/cmaes_weights.npy", weights) # 保存结果
# Out:
# CMAES weights [0.01097652 0.0270836  0.01180409 0.10165539 0.01333095 0.09007401
#  0.03286971 0.07746972 0.06164148 0.57309454]

# %% [markdown]
# # 测试

# %% [markdown]
# 代入权重，在3个集合上计算ACC和F1
#
# - 训练集（总样本数量的60%）X_train2
# - 验证集（总样本数量的20%，调参数，用CMAES得到权重）X_valid
# - 测试集（总样本数的20%）X_test
# - 各模型稳定性基于交叉验证，在除测试集外的80%上做5折 X_train

# %% [markdown]
# ### ACC

# %%
# 取训练好的模型
for model in models:
    model_name = model.__class__.__name__
    train_pred = model.predict(X_train2)
    valid_pred = model.predict(X_valid)
    test_pred = model.predict(X_test)
    print("=================" + model_name + "=================")
    train_cm = confusion_matrix(y_train2, train_pred)
    valid_cm = confusion_matrix(y_valid, valid_pred)
    test_cm = confusion_matrix(y_test, test_pred)
    i=0
    train_acc_all = np.zeros(6)
    for c in train_cm:
        train_acc_all[i] = c[i]/np.sum(c)
        print("%d train_acc: %.2f" %(i+1, 100*train_acc_all[i]))
        i=i+1
    print("average: %.2f" % (100*np.mean(train_acc_all)))
    i=0
    valid_acc_all = np.zeros(6)
    for c in valid_cm:
        valid_acc_all[i] = c[i]/np.sum(c)
        print("%d valid_acc: %.2f" %(i+1, 100*valid_acc_all[i]))
        i=i+1
    print("average: %.2f" % (100*np.mean(valid_acc_all)))
    i=0
    test_acc_all = np.zeros(6)
    for c in test_cm:
        test_acc_all[i] = c[i]/np.sum(c)
        print("%d test_acc: %.2f" %(i+1, 100*test_acc_all[i]))
        i=i+1
    print("average: %.2f" % (100*np.mean(test_acc_all)))


# - 计算CE（1-10）

population_best_weight = weights

classifier_num = 10

# 所有学习器都输出概率向量，最后投票
y_train_pred_proba_all = []
y_valid_pred_proba_all = []
y_test_pred_proba_all = []

# 取训练好的模型，计算各模型”验证集“上输出概率向量
for model in models:
    train_pred_proba = model.predict_proba(X_train2)
    valid_pred_proba = model.predict_proba(X_valid)
    test_pred_proba = model.predict_proba(X_test)
    y_train_pred_proba_all.append(train_pred_proba)
    y_valid_pred_proba_all.append(valid_pred_proba)
    y_test_pred_proba_all.append(test_pred_proba)
    
y_train_pred_ensemble_proba = np.zeros((len(y_train2), 6)) # 初始化集成器概率向量
y_valid_pred_ensemble_proba = np.zeros((len(y_valid), 6)) # 初始化集成器概率向量
y_test_pred_ensemble_proba = np.zeros((len(y_test), 6)) # 初始化集成器概率向量

# 为每一个基学习器乘上权重
for k in range(classifier_num):
    y_train_pred_ensemble_proba += y_train_pred_proba_all[k] * population_best_weight[k]
    y_valid_pred_ensemble_proba += y_valid_pred_proba_all[k] * population_best_weight[k]
    y_test_pred_ensemble_proba += y_test_pred_proba_all[k] * population_best_weight[k]
y_train_pred_ensemble = np.argmax(y_train_pred_ensemble_proba, axis=1)
y_valid_pred_ensemble = np.argmax(y_valid_pred_ensemble_proba, axis=1)
y_test_pred_ensemble = np.argmax(y_test_pred_ensemble_proba, axis=1)

# 计算各水质等级的得分
print("=================CMAES=================")
train_cm = confusion_matrix(y_train2, y_train_pred_ensemble)
valid_cm = confusion_matrix(y_valid, y_valid_pred_ensemble)
test_cm = confusion_matrix(y_test, y_test_pred_ensemble)
i=0
train_acc_all = np.zeros(6)
for c in train_cm:
    train_acc_all[i] = c[i]/np.sum(c)
    print("%d train_acc: %.2f" %(i+1, 100*train_acc_all[i]))
    i=i+1
print("average: %.2f" % (100*np.mean(train_acc_all)))
i=0
valid_acc_all = np.zeros(6)
for c in valid_cm:
    valid_acc_all[i] = c[i]/np.sum(c)
    print("%d valid_acc: %.2f" %(i+1, 100*valid_acc_all[i]))
    i=i+1
print("average: %.2f" % (100*np.mean(valid_acc_all)))
i=0
test_acc_all = np.zeros(6)
for c in test_cm:
    test_acc_all[i] = c[i]/np.sum(c)
    print("%d test_acc: %.2f" %(i+1, 100*test_acc_all[i]))
    i=i+1
print("average: %.2f" % (100*np.mean(test_acc_all)))
# Out:
# =================LogisticRegression=================
# 1 train_acc: 3.08
# 2 train_acc: 99.21
# 3 train_acc: 57.22
# 4 train_acc: 45.05
# 5 train_acc: 0.00
# 6 train_acc: 77.02
# average: 46.93
# 1 valid_acc: 3.07
# 2 valid_acc: 99.13
# 3 valid_acc: 58.50
# 4 valid_acc: 45.21
# 5 valid_acc: 0.00
# 6 valid_acc: 78.79
# average: 47.45
# 1 test_acc: 5.74
# 2 test_acc: 99.51
# 3 test_acc: 55.17
# 4 test_acc: 48.08
# 5 test_acc: 0.00
# 6 test_acc: 80.19
# average: 48.11
# =================LinearDiscriminantAnalysis=================
# 1 train_acc: 0.00
# 2 train_acc: 99.90
# 3 train_acc: 38.08
# 4 train_acc: 50.62
# 5 train_acc: 28.33
# 6 train_acc: 44.57
# average: 43.58
# 1 valid_acc: 0.00
# 2 valid_acc: 99.85
# 3 valid_acc: 38.49
# 4 valid_acc: 51.42
# 5 valid_acc: 26.94
# 6 valid_acc: 45.45
# average: 43.69
# 1 test_acc: 0.00
# 2 test_acc: 99.92
# 3 test_acc: 38.58
# 4 test_acc: 52.83
# 5 test_acc: 29.97
# 6 test_acc: 47.32
# average: 44.77
# =================SVC=================
# 1 train_acc: 64.64
# 2 train_acc: 93.62
# 3 train_acc: 89.20
# 4 train_acc: 90.07
# 5 train_acc: 87.35
# 6 train_acc: 95.73
# average: 86.77
# 1 valid_acc: 64.34
# 2 valid_acc: 93.22
# 3 valid_acc: 88.74
# 4 valid_acc: 89.77
# 5 valid_acc: 78.45
# 6 valid_acc: 94.87
# average: 84.90
# 1 test_acc: 65.16
# 2 test_acc: 93.33
# 3 test_acc: 87.61
# 4 test_acc: 91.77
# 5 test_acc: 87.54
# 6 test_acc: 98.14
# average: 87.26
# =================DecisionTreeClassifier=================
# 1 train_acc: 100.00
# 2 train_acc: 100.00
# 3 train_acc: 100.00
# 4 train_acc: 100.00
# 5 train_acc: 100.00
# 6 train_acc: 100.00
# average: 100.00
# 1 valid_acc: 98.98
# 2 valid_acc: 98.98
# 3 valid_acc: 98.52
# 4 valid_acc: 98.45
# 5 valid_acc: 98.65
# 6 valid_acc: 99.07
# average: 98.77
# 1 test_acc: 98.98
# 2 test_acc: 97.14
# 3 test_acc: 97.22
# 4 test_acc: 96.71
# 5 test_acc: 91.92
# 6 test_acc: 98.83
# average: 96.80
# =================ExtraTreeClassifier=================
# 1 train_acc: 100.00
# 2 train_acc: 100.00
# 3 train_acc: 100.00
# 4 train_acc: 100.00
# 5 train_acc: 100.00
# 6 train_acc: 100.00
# average: 100.00
# 1 valid_acc: 90.78
# 2 valid_acc: 94.69
# 3 valid_acc: 92.27
# 4 valid_acc: 88.58
# 5 valid_acc: 65.32
# 6 valid_acc: 86.71
# average: 86.39
# 1 test_acc: 89.96
# 2 test_acc: 93.41
# 3 test_acc: 91.02
# 4 test_acc: 86.56
# 5 test_acc: 73.06
# 6 test_acc: 88.11
# average: 87.02
# =================GaussianNB=================
# 1 train_acc: 78.32
# 2 train_acc: 90.94
# 3 train_acc: 82.30
# 4 train_acc: 69.57
# 5 train_acc: 60.13
# 6 train_acc: 67.70
# average: 74.83
# 1 valid_acc: 80.53
# 2 valid_acc: 90.47
# 3 valid_acc: 81.92
# 4 valid_acc: 70.05
# 5 valid_acc: 56.23
# 6 valid_acc: 71.33
# average: 75.09
# 1 test_acc: 79.51
# 2 test_acc: 90.81
# 3 test_acc: 84.03
# 4 test_acc: 71.30
# 5 test_acc: 55.22
# 6 test_acc: 74.13
# average: 75.83
# [ 2019-02-25 20:32:41,766][cascade_classifier.transform] X_groups_test.shape=[(20166, 4)]
# [ 2019-02-25 20:32:41,768][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:32:41,769][cascade_classifier.transform] X_test.shape=(20166, 4)
# [ 2019-02-25 20:32:41,771][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(20166, 4)
# =================KNeighborsClassifier=================
# 1 train_acc: 84.06
# 2 train_acc: 96.51
# 3 train_acc: 93.43
# 4 train_acc: 94.21
# 5 train_acc: 85.89
# 6 train_acc: 94.88
# average: 91.50
# 1 valid_acc: 77.46
# 2 valid_acc: 93.48
# 3 valid_acc: 89.31
# 4 valid_acc: 88.68
# 5 valid_acc: 70.03
# 6 valid_acc: 90.44
# average: 84.90
# 1 test_acc: 76.84
# 2 test_acc: 93.15
# 3 test_acc: 88.75
# 4 test_acc: 89.58
# 5 test_acc: 81.82
# 6 test_acc: 93.94
# average: 87.35
# =================RandomForestClassifier=================
# 1 train_acc: 99.66
# 2 train_acc: 99.97
# 3 train_acc: 99.94
# 4 train_acc: 99.85
# 5 train_acc: 99.66
# 6 train_acc: 99.92
# average: 99.84
# 1 valid_acc: 99.18
# 2 valid_acc: 99.51
# 3 valid_acc: 99.55
# 4 valid_acc: 99.27
# 5 valid_acc: 98.65
# 6 valid_acc: 99.30
# average: 99.24
# 1 test_acc: 99.39
# 2 test_acc: 97.55
# 3 test_acc: 98.01
# 4 test_acc: 96.98
# 5 test_acc: 93.27
# 6 test_acc: 98.83
# average: 97.34
# =================ExtraTreesClassifier=================
# 1 train_acc: 100.00
# 2 train_acc: 100.00
# 3 train_acc: 100.00
# 4 train_acc: 100.00
# 5 train_acc: 100.00
# 6 train_acc: 100.00
# average: 100.00
# 1 valid_acc: 98.36
# 2 valid_acc: 98.64
# 3 valid_acc: 97.56
# 4 valid_acc: 96.35
# 5 valid_acc: 87.88
# 6 valid_acc: 96.27
# average: 95.84
# 1 test_acc: 98.36
# 2 test_acc: 97.21
# 3 test_acc: 95.28
# 4 test_acc: 94.97
# 5 test_acc: 91.58
# 6 test_acc: 98.37
# average: 95.96
# [ 2019-02-25 20:32:42,244][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(20166, 52)
# [ 2019-02-25 20:32:42,714][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:32:42,715][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:32:42,716][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:32:42,717][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:32:42,875][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:32:43,047][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:32:43,048][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:32:43,049][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:32:43,050][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:32:43,208][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# =================GCForest=================
# 1 train_acc: 99.52
# 2 train_acc: 99.90
# 3 train_acc: 99.89
# 4 train_acc: 100.00
# 5 train_acc: 99.66
# 6 train_acc: 99.77
# average: 99.79
# 1 valid_acc: 99.39
# 2 valid_acc: 99.51
# 3 valid_acc: 99.55
# 4 valid_acc: 99.27
# 5 valid_acc: 99.33
# 6 valid_acc: 99.07
# average: 99.35
# 1 test_acc: 99.39
# 2 test_acc: 97.59
# 3 test_acc: 97.95
# 4 test_acc: 96.98
# 5 test_acc: 93.27
# 6 test_acc: 99.07
# average: 97.37
# [ 2019-02-25 20:32:48,946][cascade_classifier.transform] X_groups_test.shape=[(20166, 4)]
# [ 2019-02-25 20:32:48,947][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:32:48,948][cascade_classifier.transform] X_test.shape=(20166, 4)
# [ 2019-02-25 20:32:48,949][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(20166, 4)
# [ 2019-02-25 20:32:49,357][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(20166, 52)
# [ 2019-02-25 20:32:49,813][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:32:49,814][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:32:49,815][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:32:49,816][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:32:49,977][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:32:50,151][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:32:50,152][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:32:50,153][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:32:50,154][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:32:50,309][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# =================CMAES=================
# 1 train_acc: 99.66
# 2 train_acc: 99.99
# 3 train_acc: 99.96
# 4 train_acc: 100.00
# 5 train_acc: 99.89
# 6 train_acc: 100.00
# average: 99.92
# 1 valid_acc: 99.39
# 2 valid_acc: 99.51
# 3 valid_acc: 99.55
# 4 valid_acc: 99.27
# 5 valid_acc: 99.33
# 6 valid_acc: 99.07
# average: 99.35
# 1 test_acc: 99.39
# 2 test_acc: 97.59
# 3 test_acc: 97.95
# 4 test_acc: 96.98
# 5 test_acc: 93.27
# 6 test_acc: 99.07
# average: 97.37

# %% [markdown]
# ### F1

# %%
# 所有学习器都输出概率向量，最后投票
y_train_pred_proba_all = []
y_valid_pred_proba_all = []
y_test_pred_proba_all = []

# 取训练好的模型，计算各模型”验证集“上输出概率向量
for model in models:
    model_name = model.__class__.__name__
    train_pred_proba = model.predict_proba(X_train2)
    valid_pred_proba = model.predict_proba(X_valid)
    test_pred_proba = model.predict_proba(X_test)
    train_pred = model.predict(X_train2)
    valid_pred = model.predict(X_valid)
    test_pred = model.predict(X_test)
    print("=================" + model_name + "=================")
    print(classification_report(y_train2, train_pred, digits=4))
    print(classification_report(y_valid, valid_pred, digits=4))
    print(classification_report(y_test, test_pred, digits=4))

    y_train_pred_proba_all.append(train_pred_proba)
    y_valid_pred_proba_all.append(valid_pred_proba)
    y_test_pred_proba_all.append(test_pred_proba)

    
y_train_pred_ensemble_proba = np.zeros((len(y_train2), 6)) # 初始化集成器概率向量
y_valid_pred_ensemble_proba = np.zeros((len(y_valid), 6)) # 初始化集成器概率向量
y_test_pred_ensemble_proba = np.zeros((len(y_test), 6)) # 初始化集成器概率向量

# 为每一个基学习器乘上权重
for k in range(classifier_num):
    y_train_pred_ensemble_proba += y_train_pred_proba_all[k] * population_best_weight[k]
    y_valid_pred_ensemble_proba += y_valid_pred_proba_all[k] * population_best_weight[k]
    y_test_pred_ensemble_proba += y_test_pred_proba_all[k] * population_best_weight[k]
y_train_pred_ensemble = np.argmax(y_train_pred_ensemble_proba, axis=1)
y_valid_pred_ensemble = np.argmax(y_valid_pred_ensemble_proba, axis=1)
y_test_pred_ensemble = np.argmax(y_test_pred_ensemble_proba, axis=1)

# 计算各水质等级的得分
print("=================CMAES=================")

print(classification_report(y_train2, y_train_pred_ensemble, digits=4))
print(classification_report(y_valid, y_valid_pred_ensemble, digits=4))
print(classification_report(y_test, y_test_pred_ensemble, digits=4))
# Out:
# =================LogisticRegression=================
#              precision    recall  f1-score   support
#
#           0     0.8654    0.0308    0.0594      1462
#           1     0.6703    0.9921    0.8000      7962
#           2     0.6432    0.5722    0.6056      5278
#           3     0.6217    0.4505    0.5224      3283
#           4     0.0000    0.0000    0.0000       893
#           5     0.7904    0.7702    0.7802      1288
#
# avg / total     0.6474    0.6662    0.6136     20166
#
#              precision    recall  f1-score   support
#
#           0     0.9375    0.0307    0.0595       488
#           1     0.6764    0.9913    0.8042      2655
#           2     0.6439    0.5850    0.6130      1759
#           3     0.6338    0.4521    0.5277      1095
#           4     0.0000    0.0000    0.0000       297
#           5     0.7735    0.7879    0.7806       429
#
# avg / total     0.6562    0.6707    0.6181      6723
#
#              precision    recall  f1-score   support
#
#           0     0.9333    0.0574    0.1081       488
#           1     0.6672    0.9951    0.7988      2655
#           2     0.6628    0.5517    0.6022      1760
#           3     0.6360    0.4808    0.5476      1094
#           4     0.0000    0.0000    0.0000       297
#           5     0.7818    0.8019    0.7917       429
#
# avg / total     0.6581    0.6710    0.6206      6723
#
# =================LinearDiscriminantAnalysis=================
#              precision    recall  f1-score   support
#
#           0     0.0000    0.0000    0.0000      1462
#           1     0.5995    0.9990    0.7494      7962
#           2     0.5908    0.3808    0.4631      5278
#           3     0.6896    0.5062    0.5839      3283
#           4     0.5030    0.2833    0.3625       893
#           5     0.9863    0.4457    0.6139      1288
#
# avg / total     0.5889    0.6175    0.5674     20166
#
#              precision    recall  f1-score   support
#
#           0     0.0000    0.0000    0.0000       488
#           1     0.6000    0.9985    0.7496      2655
#           2     0.5918    0.3849    0.4664      1759
#           3     0.7011    0.5142    0.5933      1095
#           4     0.5031    0.2694    0.3509       297
#           5     0.9848    0.4545    0.6220       429
#
# avg / total     0.5911    0.6197    0.5699      6723
#
#              precision    recall  f1-score   support
#
#           0     0.0000    0.0000    0.0000       488
#           1     0.6016    0.9992    0.7510      2655
#           2     0.6036    0.3858    0.4707      1760
#           3     0.7075    0.5283    0.6049      1094
#           4     0.5361    0.2997    0.3844       297
#           5     0.9902    0.4732    0.6404       429
#
# avg / total     0.5976    0.6250    0.5761      6723
# /Users/alex/anaconda/envs/gc/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# =================SVC=================
#              precision    recall  f1-score   support
#
#           0     0.8607    0.6464    0.7383      1462
#           1     0.8850    0.9362    0.9099      7962
#           2     0.8812    0.8920    0.8865      5278
#           3     0.9375    0.9007    0.9188      3283
#           4     0.8914    0.8735    0.8824       893
#           5     0.9686    0.9573    0.9629      1288
#
# avg / total     0.8964    0.8964    0.8949     20166
#
#              precision    recall  f1-score   support
#
#           0     0.8509    0.6434    0.7328       488
#           1     0.8802    0.9322    0.9054      2655
#           2     0.8760    0.8874    0.8817      1759
#           3     0.9239    0.8977    0.9106      1095
#           4     0.8826    0.7845    0.8307       297
#           5     0.9421    0.9487    0.9454       429
#
# avg / total     0.8881    0.8884    0.8868      6723
#
#              precision    recall  f1-score   support
#
#           0     0.7970    0.6516    0.7170       488
#           1     0.8790    0.9333    0.9054      2655
#           2     0.9012    0.8761    0.8885      1760
#           3     0.9366    0.9177    0.9271      1094
#           4     0.9253    0.8754    0.8997       297
#           5     0.9546    0.9814    0.9678       429
#
# avg / total     0.8951    0.8959    0.8945      6723
#
# =================DecisionTreeClassifier=================
#              precision    recall  f1-score   support
#
#           0     1.0000    1.0000    1.0000      1462
#           1     1.0000    1.0000    1.0000      7962
#           2     1.0000    1.0000    1.0000      5278
#           3     1.0000    1.0000    1.0000      3283
#           4     1.0000    1.0000    1.0000       893
#           5     1.0000    1.0000    1.0000      1288
#
# avg / total     1.0000    1.0000    1.0000     20166
#
#              precision    recall  f1-score   support
#
#           0     0.9817    0.9898    0.9857       488
#           1     0.9898    0.9898    0.9898      2655
#           2     0.9858    0.9852    0.9855      1759
#           3     0.9926    0.9845    0.9885      1095
#           4     0.9702    0.9865    0.9783       297
#           5     0.9884    0.9907    0.9895       429
#
# avg / total     0.9877    0.9877    0.9877      6723
#
#              precision    recall  f1-score   support
#
#           0     0.8961    0.9898    0.9406       488
#           1     0.9874    0.9714    0.9793      2655
#           2     0.9800    0.9722    0.9760      1760
#           3     0.9742    0.9671    0.9706      1094
#           4     0.9254    0.9192    0.9223       297
#           5     0.9528    0.9883    0.9703       429
#
# avg / total     0.9717    0.9710    0.9711      6723
#
# =================ExtraTreeClassifier=================
#              precision    recall  f1-score   support
#
#           0     1.0000    1.0000    1.0000      1462
#           1     1.0000    1.0000    1.0000      7962
#           2     1.0000    1.0000    1.0000      5278
#           3     1.0000    1.0000    1.0000      3283
#           4     1.0000    1.0000    1.0000       893
#           5     1.0000    1.0000    1.0000      1288
#
# avg / total     1.0000    1.0000    1.0000     20166
#
#              precision    recall  f1-score   support
#
#           0     0.8569    0.9078    0.8816       488
#           1     0.9603    0.9469    0.9535      2655
#           2     0.9164    0.9227    0.9195      1759
#           3     0.8661    0.8858    0.8758      1095
#           4     0.7055    0.6532    0.6783       297
#           5     0.8815    0.8671    0.8743       429
#
# avg / total     0.9097    0.9097    0.9096      6723
#
#              precision    recall  f1-score   support
#
#           0     0.8085    0.8996    0.8516       488
#           1     0.9549    0.9341    0.9444      2655
#           2     0.9118    0.9102    0.9110      1760
#           3     0.8532    0.8656    0.8593      1094
#           4     0.7115    0.7306    0.7209       297
#           5     0.9197    0.8811    0.9000       429
#
# avg / total     0.9034    0.9018    0.9024      6723
#
# =================GaussianNB=================
#              precision    recall  f1-score   support
#
#           0     0.8407    0.7832    0.8109      1462
#           1     0.8573    0.9094    0.8826      7962
#           2     0.7624    0.8230    0.7915      5278
#           3     0.7706    0.6957    0.7312      3283
#           4     0.6671    0.6013    0.6325       893
#           5     0.9787    0.6770    0.8004      1288
#
# avg / total     0.8165    0.8144    0.8126     20166
#
#              precision    recall  f1-score   support
#
#           0     0.8256    0.8053    0.8154       488
#           1     0.8606    0.9047    0.8821      2655
#           2     0.7600    0.8192    0.7885      1759
#           3     0.7755    0.7005    0.7361      1095
#           4     0.6448    0.5623    0.6007       297
#           5     0.9808    0.7133    0.8259       429
#
# avg / total     0.8160    0.8145    0.8130      6723
#
#              precision    recall  f1-score   support
#
#           0     0.7886    0.7951    0.7918       488
#           1     0.8657    0.9081    0.8864      2655
#           2     0.7909    0.8403    0.8149      1760
#           3     0.7816    0.7130    0.7457      1094
#           4     0.6560    0.5522    0.5996       297
#           5     0.9695    0.7413    0.8402       429
#
# avg / total     0.8242    0.8240    0.8223      6723
#
# =================KNeighborsClassifier=================
#              precision    recall  f1-score   support
#
#           0     0.8741    0.8406    0.8570      1462
#           1     0.9355    0.9651    0.9500      7962
#           2     0.9457    0.9343    0.9400      5278
#           3     0.9520    0.9421    0.9470      3283
#           4     0.9208    0.8589    0.8888       893
#           5     0.9776    0.9488    0.9630      1288
#
# avg / total     0.9384    0.9385    0.9383     20166
#
#              precision    recall  f1-score   support
#
#           0     0.7908    0.7746    0.7826       488
#           1     0.8996    0.9348    0.9169      2655
#           2     0.9013    0.8931    0.8972      1759
#           3     0.9092    0.8868    0.8978      1095
#           4     0.7879    0.7003    0.7415       297
#           5     0.9440    0.9044    0.9238       429
#
# avg / total     0.8916    0.8922    0.8916      6723
#
#              precision    recall  f1-score   support
#
#           0     0.7530    0.7684    0.7606       488
#           1     0.9016    0.9315    0.9163      2655
#           2     0.9135    0.8875    0.9003      1760
#           3     0.9245    0.8958    0.9099      1094
#           4     0.8467    0.8182    0.8322       297
#           5     0.9482    0.9394    0.9438       429
#
# avg / total     0.8982    0.8978    0.8978      6723
#
# =================RandomForestClassifier=================
#              precision    recall  f1-score   support
#
#           0     0.9993    0.9966    0.9979      1462
#           1     0.9990    0.9997    0.9994      7962
#           2     0.9989    0.9994    0.9991      5278
#           3     0.9997    0.9985    0.9991      3283
#           4     0.9989    0.9966    0.9978       893
#           5     0.9984    0.9992    0.9988      1288
#
# avg / total     0.9991    0.9991    0.9991     20166
#
#              precision    recall  f1-score   support
#
#           0     0.9898    0.9918    0.9908       488
#           1     0.9966    0.9951    0.9959      2655
#           2     0.9938    0.9955    0.9946      1759
#           3     0.9945    0.9927    0.9936      1095
#           4     0.9865    0.9865    0.9865       297
#           5     0.9884    0.9930    0.9907       429
#
# avg / total     0.9941    0.9941    0.9941      6723
#
#              precision    recall  f1-score   support
#
#           0     0.9065    0.9939    0.9482       488
#           1     0.9927    0.9755    0.9840      2655
#           2     0.9835    0.9801    0.9818      1760
#           3     0.9779    0.9698    0.9738      1094
#           4     0.9295    0.9327    0.9311       297
#           5     0.9593    0.9883    0.9736       429
#
# avg / total     0.9767    0.9761    0.9762      6723
# [ 2019-02-25 20:33:02,139][cascade_classifier.transform] X_groups_test.shape=[(20166, 4)]
# [ 2019-02-25 20:33:02,142][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:33:02,143][cascade_classifier.transform] X_test.shape=(20166, 4)
# [ 2019-02-25 20:33:02,146][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(20166, 4)
# =================ExtraTreesClassifier=================
#              precision    recall  f1-score   support
#
#           0     1.0000    1.0000    1.0000      1462
#           1     1.0000    1.0000    1.0000      7962
#           2     1.0000    1.0000    1.0000      5278
#           3     1.0000    1.0000    1.0000      3283
#           4     1.0000    1.0000    1.0000       893
#           5     1.0000    1.0000    1.0000      1288
#
# avg / total     1.0000    1.0000    1.0000     20166
#
#              precision    recall  f1-score   support
#
#           0     0.9619    0.9836    0.9726       488
#           1     0.9835    0.9864    0.9850      2655
#           2     0.9717    0.9756    0.9736      1759
#           3     0.9697    0.9635    0.9666      1095
#           4     0.9321    0.8788    0.9047       297
#           5     0.9672    0.9627    0.9650       429
#
# avg / total     0.9733    0.9734    0.9733      6723
#
#              precision    recall  f1-score   support
#
#           0     0.8905    0.9836    0.9348       488
#           1     0.9803    0.9721    0.9762      2655
#           2     0.9710    0.9528    0.9619      1760
#           3     0.9506    0.9497    0.9502      1094
#           4     0.9189    0.9158    0.9174       297
#           5     0.9701    0.9837    0.9769       429
#
# avg / total     0.9631    0.9625    0.9626      6723
# [ 2019-02-25 20:33:02,607][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(20166, 52)
# [ 2019-02-25 20:33:03,323][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:33:03,324][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:33:03,325][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:33:03,326][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:33:03,491][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:33:03,671][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:33:03,672][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:33:03,673][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:33:03,674][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:33:03,832][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:33:04,006][cascade_classifier.transform] X_groups_test.shape=[(20166, 4)]
# [ 2019-02-25 20:33:04,007][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:33:04,008][cascade_classifier.transform] X_test.shape=(20166, 4)
# [ 2019-02-25 20:33:04,010][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(20166, 4)
# [ 2019-02-25 20:33:04,410][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(20166, 52)
# [ 2019-02-25 20:33:04,882][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:33:04,883][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:33:04,884][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:33:04,885][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:33:05,036][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# [ 2019-02-25 20:33:05,308][cascade_classifier.transform] X_groups_test.shape=[(6723, 4)]
# [ 2019-02-25 20:33:05,310][cascade_classifier.transform] group_dims=[4]
# [ 2019-02-25 20:33:05,310][cascade_classifier.transform] X_test.shape=(6723, 4)
# [ 2019-02-25 20:33:05,312][cascade_classifier.transform] [layer=0] look_indexs=[0], X_cur_test.shape=(6723, 4)
# [ 2019-02-25 20:33:05,494][cascade_classifier.transform] [layer=1] look_indexs=[0], X_cur_test.shape=(6723, 52)
# =================GCForest=================
#              precision    recall  f1-score   support
#
#           0     0.9979    0.9952    0.9966      1462
#           1     0.9987    0.9990    0.9989      7962
#           2     0.9991    0.9989    0.9990      5278
#           3     0.9982    1.0000    0.9991      3283
#           4     0.9978    0.9966    0.9972       893
#           5     0.9992    0.9977    0.9984      1288
#
# avg / total     0.9987    0.9987    0.9987     20166
#
#              precision    recall  f1-score   support
#
#           0     0.9898    0.9939    0.9918       488
#           1     0.9970    0.9951    0.9960      2655
#           2     0.9938    0.9955    0.9946      1759
#           3     0.9945    0.9927    0.9936      1095
#           4     0.9833    0.9933    0.9883       297
#           5     0.9930    0.9907    0.9918       429
#
# avg / total     0.9944    0.9943    0.9943      6723
#
#              precision    recall  f1-score   support
#
#           0     0.9082    0.9939    0.9491       488
#           1     0.9923    0.9759    0.9840      2655
#           2     0.9835    0.9795    0.9815      1760
#           3     0.9779    0.9698    0.9738      1094
#           4     0.9327    0.9327    0.9327       297
#           5     0.9594    0.9907    0.9748       429
#
# avg / total     0.9768    0.9762    0.9763      6723
#
# =================CMAES=================
#              precision    recall  f1-score   support
#
#           0     1.0000    0.9966    0.9983      1462
#           1     0.9992    0.9999    0.9996      7962
#           2     0.9998    0.9996    0.9997      5278
#           3     0.9994    1.0000    0.9997      3283
#           4     1.0000    0.9989    0.9994       893
#           5     1.0000    1.0000    1.0000      1288
#
# avg / total     0.9996    0.9996    0.9996     20166
#
#              precision    recall  f1-score   support
#
#           0     0.9898    0.9939    0.9918       488
#           1     0.9970    0.9951    0.9960      2655
#           2     0.9938    0.9955    0.9946      1759
#           3     0.9945    0.9927    0.9936      1095
#           4     0.9833    0.9933    0.9883       297
#           5     0.9930    0.9907    0.9918       429
#
# avg / total     0.9944    0.9943    0.9943      6723
#
#              precision    recall  f1-score   support
#
#           0     0.9082    0.9939    0.9491       488
#           1     0.9923    0.9759    0.9840      2655
#           2     0.9835    0.9795    0.9815      1760
#           3     0.9779    0.9698    0.9738      1094
#           4     0.9327    0.9327    0.9327       297
#           5     0.9594    0.9907    0.9748       429
#
# avg / total     0.9768    0.9762    0.9763      6723

# %% [markdown]
# 人为设定了10个参数的初值x0=10*[0]，sigma0=0.5, 算法包中对sigma0的描述为：
#
# http://cma.gforge.inria.fr/apidocs-pycma/cma.evolution_strategy.CMAEvolutionStrategy.html
#
# > initial standard deviation. The problem variables should have been scaled, such that a single standard deviation on all variables is useful and the optimum is expected to lie within about x0 +- 3*sigma0. See also options scaling_of_variables. Often one wants to check for solutions close to the initial point. This allows, for example, for an easier check of consistency of the objective function and its interfacing with the optimizer. In this case, a much smaller sigma0 is advisable.
#
# CMAES 知乎算法专栏
# https://zhuanlan.zhihu.com/p/31193293

# %%
# 算法默认参数

cma.CMAOptions.defaults()
# Out:
# {'AdaptSigma': 'True  # or False or any CMAAdaptSigmaBase class e.g. CMAAdaptSigmaTPA, CMAAdaptSigmaCSA',
#  'BoundaryHandler': 'BoundTransform  # or BoundPenalty, unused when ``bounds in (None, [None, None])``',
#  'CMA_active': 'True  # negative update, conducted after the original update',
#  'CMA_cmean': '1  # learning rate for the mean value',
#  'CMA_const_trace': 'False  # normalize trace, 1, True, "arithm", "geom", "aeig", "geig" are valid',
#  'CMA_dampsvec_fac': 'np.Inf  # tentative and subject to changes, 0.5 would be a "default" damping for sigma vector update',
#  'CMA_dampsvec_fade': '0.1  # tentative fading out parameter for sigma vector update',
#  'CMA_diagonal': '0*100*N/popsize**0.5  # nb of iterations with diagonal covariance matrix, True for always',
#  'CMA_eigenmethod': 'np.linalg.eigh  # or cma.utils.eig or pygsl.eigen.eigenvectors',
#  'CMA_elitist': 'False  #v or "initial" or True, elitism likely impairs global search performance',
#  'CMA_mirrormethod': '2  # 0=unconditional, 1=selective, 2=selective with delay',
#  'CMA_mirrors': 'popsize < 6  # values <0.5 are interpreted as fraction, values >1 as numbers (rounded), otherwise about 0.16 is used',
#  'CMA_mu': 'None  # parents selection parameter, default is popsize // 2',
#  'CMA_on': '1  # multiplier for all covariance matrix updates',
#  'CMA_rankmu': '1.0  # multiplier for rank-mu update learning rate of covariance matrix',
#  'CMA_rankone': '1.0  # multiplier for rank-one update learning rate of covariance matrix',
#  'CMA_recombination_weights': 'None  # a list, see class RecombinationWeights, overwrites CMA_mu and popsize options',
#  'CMA_sampler': 'None  # a class or instance that implements the interface of `cma.interfaces.StatisticalModelSamplerWithZeroMeanBaseClass`',
#  'CMA_sampler_options': '{}  # options passed to `CMA_sampler` class init as keyword arguments',
#  'CMA_stds': 'None  # multipliers for sigma0 in each coordinate, not represented in C, makes scaling_of_variables obsolete',
#  'CMA_teststds': 'None  # factors for non-isotropic initial distr. of C, mainly for test purpose, see CMA_stds for production',
#  'CSA_clip_length_value': 'None  #v poorly tested, [0, 0] means const length N**0.5, [-1, 1] allows a variation of +- N/(N+2), etc.',
#  'CSA_damp_mueff_exponent': '0.5  # zero would mean no dependency of damping on mueff, useful with CSA_disregard_length option',
#  'CSA_dampfac': '1  #v positive multiplier for step-size damping, 0.3 is close to optimal on the sphere',
#  'CSA_disregard_length': 'False  #v True is untested, also changes respective parameters',
#  'CSA_squared': 'False  #v use squared length for sigma-adaptation ',
#  'bounds': '[None, None]  # lower (=bounds[0]) and upper domain boundaries, each a scalar or a list/vector',
#  'conditioncov_alleviate': '[1e8, 1e12]  # when to alleviate the condition in the coordinates and in main axes',
#  'fixed_variables': 'None  # dictionary with index-value pairs like {0:1.1, 2:0.1} that are not optimized',
#  'ftarget': '-inf  #v target function value, minimization',
#  'integer_variables': '[]  # index list, invokes basic integer handling: prevent std dev to become too small in the given variables',
#  'is_feasible': 'is_feasible  #v a function that computes feasibility, by default lambda x, f: f not in (None, np.NaN)',
#  'maxfevals': 'inf  #v maximum number of function evaluations',
#  'maxiter': '100 + 150 * (N+3)**2 // popsize**0.5  #v maximum number of iterations',
#  'maxstd': 'inf  #v maximal std in any coordinate direction',
#  'mean_shift_line_samples': 'False #v sample two new solutions colinear to previous mean shift',
#  'mindx': '0  #v minimal std in any arbitrary direction, cave interference with tol*',
#  'minstd': '0  #v minimal std (scalar or vector) in any coordinate direction, cave interference with tol*',
#  'pc_line_samples': 'False #v one line sample along the evolution path pc',
#  'popsize': '4+int(3*np.log(N))  # population size, AKA lambda, number of new solution per iteration',
#  'randn': 'np.random.randn  #v randn(lam, N) must return an np.array of shape (lam, N), see also cma.utilities.math.randhss',
#  'scaling_of_variables': 'None  # depreciated, rather use fitness_transformations.ScaleCoordinates instead (or possibly CMA_stds).\n            Scale for each variable in that effective_sigma0 = sigma0*scaling. Internally the variables are divided by scaling_of_variables and sigma is unchanged, default is `np.ones(N)`',
#  'seed': 'time  # random number seed for `numpy.random`; `None` and `0` equate to `time`, `np.nan` means "do nothing", see also option "randn"',
#  'signals_filename': 'None  # cma_signals.in  # read versatile options from this file which contains a single options dict, e.g. ``{"timeout": 0}`` to stop, string-values are evaluated, e.g. "np.inf" is valid',
#  'termination_callback': 'None  #v a function returning True for termination, called in `stop` with `self` as argument, could be abused for side effects',
#  'timeout': 'inf  #v stop if timeout seconds are exceeded, the string "2.5 * 60**2" evaluates to 2 hours and 30 minutes',
#  'tolconditioncov': '1e14  #v stop if the condition of the covariance matrix is above `tolconditioncov`',
#  'tolfacupx': '1e3  #v termination when step-size increases by tolfacupx (diverges). That is, the initial step-size was chosen far too small and better solutions were found far away from the initial solution x0',
#  'tolfun': '1e-11  #v termination criterion: tolerance in function value, quite useful',
#  'tolfunhist': '1e-12  #v termination criterion: tolerance in function value history',
#  'tolstagnation': 'int(100 + 100 * N**1.5 / popsize)  #v termination if no improvement over tolstagnation iterations',
#  'tolupsigma': '1e20  #v sigma/sigma0 > tolupsigma * max(eivenvals(C)**0.5) indicates "creeping behavior" with usually minor improvements',
#  'tolx': '1e-11  #v termination criterion: tolerance in x-changes',
#  'transformation': 'None  # depreciated, use cma.fitness_transformations.FitnessTransformation instead.\n            [t0, t1] are two mappings, t0 transforms solutions from CMA-representation to f-representation (tf_pheno),\n            t1 is the (optional) back transformation, see class GenoPheno',
#  'typical_x': 'None  # used with scaling_of_variables',
#  'updatecovwait': 'None  #v number of iterations without distribution update, name is subject to future changes',
#  'verb_append': '0  # initial evaluation counter, if append, do not overwrite output files',
#  'verb_disp': '100  #v verbosity: display console output every verb_disp iteration',
#  'verb_filenameprefix': 'outcmaes  # output filenames prefix',
#  'verb_log': '1  #v verbosity: write data to files every verb_log iteration, writing can be time critical on fast to evaluate functions',
#  'verb_plot': '0  #v in fmin(): plot() is called every verb_plot iteration',
#  'verb_time': 'True  #v output timings on console',
#  'verbose': '3  #v verbosity e.g. of initial/final message, -1 is very quiet, -9 maximally quiet, may not be fully implemented',
#  'vv': '{}  #? versatile set or dictionary for hacking purposes, value found in self.opts["vv"]'}
